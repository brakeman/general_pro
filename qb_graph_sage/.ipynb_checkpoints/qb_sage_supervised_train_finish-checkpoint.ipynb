# %%
# 1. loss - nce; 直接元素相乘？
# 2. gcn; 没有利用到 GCN 做聚合，而是简单mean-pooling;  ！！！
# 3. neg_samples; 随机采样，并不一定是真负; ！！！
# 4. neg_samples 无论是batch_train 还是 big_valid 都是同等size.  FLAG.neg_sample_size = 20; ！！！
# 4搞不定， 我评估直接用监督损失了， 不用无监督损失做评估；

# %%
import pandas as pd
import networkx as nx
import numpy as np
import tensorflow as tf

# %%
def make_adj_list(path_array):
    '''
    para: path_array: df.values with shape:[nodes, 2]
    return: adj_list, userid2idx, node_degree
    '''
    G=nx.Graph()
    G.add_edges_from(path_array)
    adj_list = G.adjacency_list()
    userid2idx = {j:i for i,j in enumerate(G.nodes())}
    adj_list = construct_adj_list(G, userid2idx, max_degree=25)
    return G, adj_list, userid2idx, G.degree(), G.edges()

def make_fake_feat(nodes, emb_size):
    '''
    para: nodes: a list of user_id;
    return: fake fatures of all nodes;'''
    features = np.ones(shape = (len(nodes), emb_size))
    return features

def construct_adj_list(G, id2idx, max_degree):
    adj_list = len(id2idx)*np.ones((len(id2idx)+1, max_degree))
    for nodeid in G.nodes():
        neighbors = np.array([id2idx[neighbor] for neighbor in G.neighbors(nodeid)])
        if len(neighbors) == 0:
            continue
        if len(neighbors) > max_degree:
            neighbors = np.random.choice(neighbors, max_degree, replace=False)
        elif len(neighbors) < max_degree:
            neighbors = np.random.choice(neighbors, max_degree, replace=True)
        adj_list[id2idx[nodeid], :] = neighbors
    return adj_list.astype(int)

# %%
data = './data/col_4.csv'
df = pd.read_csv(data, header=None)
# 4元素
G, adj_list, userid2idx, degree, edges = make_adj_list(df.iloc[:,:2].values)
fake_feats = make_fake_feat(G.nodes(), 50)

# %%
import sys 
sys.path.append('/Users/cashbus/Documents/工作/任务5-图/graphsage-master/qb_graph_sage/aggregator') 
sys.path.append('/Users/cashbus/Documents/工作/任务5-图/graphsage-master/qb_graph_sage/sampler')
sys.path.append('/Users/cashbus/Documents/工作/任务5-图/graphsage-master/qb_graph_sage/minibatch')

from aggregator import MeanAggregator
from sampler import LayerNeighborSampler
from minibatch import EdgeMinibatchIter
import copy

# %%
class GraphSage:
    def __init__(self, features, edges, adj_list, degrees, id_map, bs, neg_samples):
        self.features = tf.Variable(tf.constant(features, dtype=tf.float32), trainable=False)
        self.adj_list = adj_list
        self.degrees = degrees  # a list of all nodes'degree; same order with id2nodes;
        self.sampler = LayerNeighborSampler(adj_list)
        self.agg = MeanAggregator()
        self.emb_size = features.shape[1]
        self.batch_size = bs
        self.neg_samples = neg_samples
        self.id2idx = id_map
        self.minibatch = EdgeMinibatchIter(id_map, adj_list, edges, batch_size=bs)

    def sample(self, inputs, layer_infos, batch_size=None):
        """ Sample neighbors to be the supportive fields for multi-layer convolutions.

        Args:
            layer_infos: [3, 2] # 第一层每个node采样3个， 第二层每个node采样2个
            inputs: batch nodes idx; # [bs]
            batch_size: the number of inputs (different for batch inputs and negative samples).
        """
        if batch_size is None:
            batch_size = self.batch_size
        samples = [inputs]
        support_size = 1
        support_sizes = [support_size]
        for k in range(len(layer_infos)):
            t = len(layer_infos) - k - 1
            support_size *= layer_infos[t]
            # samples[0] -- layers[1]
            # samples[1] -- layers[0]
            node = self.sampler.build((samples[k], layer_infos[t]))  # 从该layer nodes idx 关联到全局 adj_mat, 找到该层指定的邻居数；
            # 全域adj【num_nodes, max_sample_num], 如果不足，那么重复采样;
            # [layer_nodes, max_num_neighs];
            samples.append(tf.cast(tf.reshape(node, [support_size * batch_size]), tf.int32)) #emb_lookup 必须是int
            support_sizes.append(support_size)

        # samples: [bs*support_sizes[0], bs*support_sizes[1], bs*support_sizes[2], ...];
        # samples: [5个点， 10个点， 30个点];
        # layer_infos: [1, 2, 3];
        # support_sizes: [1, 2, 6];
        return samples, support_sizes

    def aggregate(self, samples, input_features, num_samples, support_sizes, batch_size=None):
        if batch_size is None:
            batch_size = self.batch_size
        # [5个点的emb, 10个点的emb, 30个点的emb]
        hidden = [tf.nn.embedding_lookup(self.features, node_samples) for node_samples in samples]
        # [3, 2]
        for layer in range(len(num_samples)):
            next_hidden = []
            # layer = 0, hop = 0, self_feats = 5个点emb, neigh_feats = [5, 2, emb], h = 5个点emb ];
            #            hop = 1, self_feats = 10个点emb, neigh_feats = [10, 3, emb], h = 10个点emb];
            # 更新 hidden = next_hidden;
            # layer = 1, hop = 0, self_feats = 新点5个点emb; neigh_feats = [5, 2, emb], h = 新点5个点emb;
            for hop in range(len(num_samples) - layer):
                neigh_dims = [batch_size * support_sizes[hop],
                              num_samples[len(num_samples) - hop - 1],
                              self.emb_size]
                self_feats = hidden[hop]
                neigh_feats = tf.reshape(hidden[hop + 1], neigh_dims)
                h = self.agg.bulid(self_feats, neigh_feats)
                next_hidden.append(h)
            hidden = next_hidden
        return hidden[0]  # [bs, new_emb];

    def nce_loss(self, inputs1, inputs2, neg_samples, neg_sample_weights):
        aff = tf.reduce_sum(inputs1 * inputs2, axis=1)
        neg_aff = tf.matmul(inputs1, tf.transpose(neg_samples))
        true_xent = tf.nn.sigmoid_cross_entropy_with_logits(labels=tf.ones_like(aff), logits=aff)
        negative_xent = tf.nn.sigmoid_cross_entropy_with_logits(labels=tf.zeros_like(neg_aff), logits=neg_aff)
        loss = tf.reduce_sum(true_xent) + neg_sample_weights * tf.reduce_sum(negative_xent)
        print('aff:{}\nneg_aff:{}\nloss:{}'.format(aff, neg_aff, loss))
        return loss

    def batch_feed_dict(self, batch_edges):
        batch1 = []
        batch2 = []
        for node1, node2 in batch_edges:
            batch1.append(self.id2idx[node1])
            batch2.append(self.id2idx[node2])
        return batch1, batch2, len(batch_edges)

    def get_ph(self):
        inp1_ph = tf.placeholder(tf.int32, shape=(None))
        inp2_ph = tf.placeholder(tf.int32, shape=(None))
        batch_size_ph = tf.placeholder(tf.int32)
        return inp1_ph, inp2_ph, batch_size_ph

    def main(self, settings=[(2,0.01)], layer_infos=[3, 2], neg_sample_size=4):
        '''function for graph, training, eval
        :layer_infos: num_neighs for each layer;
        :setting: training settting (epoch, lr);
        '''
        RESULT = []
        for (num_epochs, lr) in settings:
            train_loss_list, test_loss_list = [], []
            # tf.reset_default_graph()
            gb_step = tf.Variable(initial_value=0, trainable=False)
            inputs1, inputs2, batch_size = self.get_ph()  # [bs], [bs];
            samples1, support_sizes1 = self.sample(inputs1, layer_infos)  # [bs=5个点， 10个点， 30个点], [1, 2, 6] when layer_infos = [3, 2];
            samples2, support_sizes2 = self.sample(inputs2, layer_infos)  # [bs=5个点， 10个点， 30个点], [1, 2, 6] when layer_infos = [3, 2];

            outputs1 = self.aggregate(samples1, [self.features], layer_infos, support_sizes1)  # [bs, emb]
            outputs2 = self.aggregate(samples2, [self.features], layer_infos, support_sizes2)  # [bs, emb]

            labels = tf.reshape(tf.cast(inputs2, dtype=tf.int64), [self.batch_size, 1])
    
            neg_samples, _, _ = (tf.nn.fixed_unigram_candidate_sampler(
                true_classes=labels, num_true=1,
                num_sampled=neg_sample_size,
                unique=False,
                range_max=len(self.degrees), distortion=0.75,
                unigrams=list(self.degrees.values())))

            neg_samples = tf.cast(neg_samples, tf.int32)
            neg_samples, neg_support_sizes = self.sample(neg_samples, layer_infos, batch_size=neg_sample_size)
            neg_outputs = self.aggregate(neg_samples, [self.features], layer_infos, neg_support_sizes, batch_size=neg_sample_size)
            loss = self.nce_loss(outputs1, outputs2, neg_outputs, 1)
            optimizer = tf.contrib.layers.optimize_loss(loss=loss, learning_rate=lr, optimizer='Adam', global_step=gb_step)

            ########## graph finish, training start############
            with tf.Session() as sess:
                sess.run(tf.global_variables_initializer())
                epoch = 0
                while epoch < num_epochs:
                    epoch += 1
                    print('''epoch_{} start, end:{}?'''.format(epoch-1, self.minibatch.end()))
                    batch_idx = 0
                    while not self.minibatch.end():
                        batch_idx += 1
                        inp1, inp2, temp_bs = self.minibatch.next_minibatch_feed_dict()
                        sess.run(optimizer, feed_dict={inputs1: inp1, inputs2: inp2, batch_size: temp_bs})
                        if batch_idx % 50 == 0:
                            print('batch_idx_for_training:{}'.format(batch_idx))
#                             print('temp nce loss:{}'.format(sess.run(loss, feed_dict={inputs1:Val_inp1, inputs2:Val_inp2, batch_size:Val_bs})))
                            

class EdgeMinibatchIter(object):
    def __init__(self, id2idx, adj, context_pairs, batch_size, max_degree=25):
        self.id2idx = id2idx
        self.batch_size = batch_size
        self.max_degree = max_degree
        self.batch_num = 0
        self.adj = adj
        self.edges = context_pairs
        self.num_samples = len(self.edges)

    def end(self):
        return (self.batch_num +1)* self.batch_size >= len(self.edges)

    def next_minibatch_feed_dict(self):
        print('--')
        print('end:{}'.format(self.batch_num * self.batch_size))
        start_idx = self.batch_num * self.batch_size
        self.batch_num += 1
        end_idx = min(start_idx + self.batch_size, self.num_samples)
        batch_edges = self.edges[start_idx: end_idx]
        print('start_idx:{}, end_idx:{}'.format(start_idx, end_idx))
        return self.batch_feed_dict(batch_edges)

    def batch_feed_dict(self, batch_edges):
        batch1 = []
        batch2 = []
        for node1, node2 in batch_edges:
            batch1.append(self.id2idx[node1])
            batch2.append(self.id2idx[node2])
        return batch1, batch2, len(batch_edges)

# %%
qb_sage = GraphSage(fake_feats, edges, adj_list, degree, userid2idx, 200, 10)

# %%
qb_sage.main()
# Out:
# aff:Tensor("Sum_12:0", shape=(200,), dtype=float32)
# neg_aff:Tensor("MatMul_4:0", shape=(200, 4), dtype=float32)
# loss:Tensor("add_4:0", shape=(), dtype=float32)
# epoch_0 start, end:False?
# --
# end:0
# start_idx:0, end_idx:200
# --
# end:200
# start_idx:200, end_idx:400
# --
# end:400
# start_idx:400, end_idx:600
# --
# end:600
# start_idx:600, end_idx:800
# --
# end:800
# start_idx:800, end_idx:1000
# --
# end:1000
# start_idx:1000, end_idx:1200
# --
# end:1200
# start_idx:1200, end_idx:1400
# --
# end:1400
# start_idx:1400, end_idx:1600
# --
# end:1600
# start_idx:1600, end_idx:1800
# --
# end:1800
# start_idx:1800, end_idx:2000
# --
# end:2000
# start_idx:2000, end_idx:2200
# --
# end:2200
# start_idx:2200, end_idx:2400
# --
# end:2400
# start_idx:2400, end_idx:2600
# --
# end:2600
# start_idx:2600, end_idx:2800
# --
# end:2800
# start_idx:2800, end_idx:3000
# --
# end:3000
# start_idx:3000, end_idx:3200
# --
# end:3200
# start_idx:3200, end_idx:3400
# --
# end:3400
# start_idx:3400, end_idx:3600
# --
# end:3600
# start_idx:3600, end_idx:3800
# --
# end:3800
# start_idx:3800, end_idx:4000
# --
# end:4000
# start_idx:4000, end_idx:4200
# --
# end:4200
# start_idx:4200, end_idx:4400
# --
# end:4400
# start_idx:4400, end_idx:4600
# --
# end:4600
# start_idx:4600, end_idx:4800
# --
# end:4800
# start_idx:4800, end_idx:5000
# --
# end:5000
# start_idx:5000, end_idx:5200
# --
# end:5200
# start_idx:5200, end_idx:5400
# --
# end:5400
# start_idx:5400, end_idx:5600
# --
# end:5600
# start_idx:5600, end_idx:5800
# --
# end:5800
# start_idx:5800, end_idx:6000
# --
# end:6000
# start_idx:6000, end_idx:6200
# --
# end:6200
# start_idx:6200, end_idx:6400
# --
# end:6400
# start_idx:6400, end_idx:6600
# --
# end:6600
# start_idx:6600, end_idx:6800
# --
# end:6800
# start_idx:6800, end_idx:7000
# --
# end:7000
# start_idx:7000, end_idx:7200
# --
# end:7200
# start_idx:7200, end_idx:7400
# --
# end:7400
# start_idx:7400, end_idx:7600
# --
# end:7600
# start_idx:7600, end_idx:7800
# --
# end:7800
# start_idx:7800, end_idx:8000
# --
# end:8000
# start_idx:8000, end_idx:8200
# --
# end:8200
# start_idx:8200, end_idx:8400
# --
# end:8400
# start_idx:8400, end_idx:8600
# --
# end:8600
# start_idx:8600, end_idx:8800
# --
# end:8800
# start_idx:8800, end_idx:9000
# --
# end:9000
# start_idx:9000, end_idx:9200
# --
# end:9200
# start_idx:9200, end_idx:9400
# --
# end:9400
# start_idx:9400, end_idx:9600
# --
# end:9600
# start_idx:9600, end_idx:9800
# --
# end:9800
# start_idx:9800, end_idx:10000
# batch_idx_for_training:50
# --
# end:10000
# start_idx:10000, end_idx:10200
# --
# end:10200
# start_idx:10200, end_idx:10400
# --
# end:10400
# start_idx:10400, end_idx:10600
# --
# end:10600
# start_idx:10600, end_idx:10800
# --
# end:10800
# start_idx:10800, end_idx:11000
# --
# end:11000
# start_idx:11000, end_idx:11200
# --
# end:11200
# start_idx:11200, end_idx:11400
# --
# end:11400
# start_idx:11400, end_idx:11600
# --
# end:11600
# start_idx:11600, end_idx:11800
# --
# end:11800
# start_idx:11800, end_idx:12000
# --
# end:12000
# start_idx:12000, end_idx:12200
# --
# end:12200
# start_idx:12200, end_idx:12400
# --
# end:12400
# start_idx:12400, end_idx:12600
# --
# end:12600
# start_idx:12600, end_idx:12800
# --
# end:12800
# start_idx:12800, end_idx:13000
# --
# end:13000
# start_idx:13000, end_idx:13200
# --
# end:13200
# start_idx:13200, end_idx:13400
# --
# end:13400
# start_idx:13400, end_idx:13600
# --
# end:13600
# start_idx:13600, end_idx:13800
# --
# end:13800
# start_idx:13800, end_idx:14000
# --
# end:14000
# start_idx:14000, end_idx:14200
# --
# end:14200
# start_idx:14200, end_idx:14400
# --
# end:14400
# start_idx:14400, end_idx:14600
# --
# end:14600
# start_idx:14600, end_idx:14800
# --
# end:14800
# start_idx:14800, end_idx:15000
# --
# end:15000
# start_idx:15000, end_idx:15200
# --
# end:15200
# start_idx:15200, end_idx:15400
# --
# end:15400
# start_idx:15400, end_idx:15600
# --
# end:15600
# start_idx:15600, end_idx:15800
# --
# end:15800
# start_idx:15800, end_idx:16000
# --
# end:16000
# start_idx:16000, end_idx:16200
# --
# end:16200
# start_idx:16200, end_idx:16400
# --
# end:16400
# start_idx:16400, end_idx:16600
# --
# end:16600
# start_idx:16600, end_idx:16800
# --
# end:16800
# start_idx:16800, end_idx:17000
# --
# end:17000
# start_idx:17000, end_idx:17200
# --
# end:17200
# start_idx:17200, end_idx:17400
# --
# end:17400
# start_idx:17400, end_idx:17600
# --
# end:17600
# start_idx:17600, end_idx:17800
# --
# end:17800
# start_idx:17800, end_idx:18000
# --
# end:18000
# start_idx:18000, end_idx:18200
# --
# end:18200
# start_idx:18200, end_idx:18400
# --
# end:18400
# start_idx:18400, end_idx:18600
# --
# end:18600
# start_idx:18600, end_idx:18800
# --
# end:18800
# start_idx:18800, end_idx:19000
# --
# end:19000
# start_idx:19000, end_idx:19200
# --
# end:19200
# start_idx:19200, end_idx:19400
# --
# end:19400
# start_idx:19400, end_idx:19600
# --
# end:19600
# start_idx:19600, end_idx:19800
# --
# end:19800
# start_idx:19800, end_idx:20000
# batch_idx_for_training:100
# --
# end:20000
# start_idx:20000, end_idx:20200
# --
# end:20200
# start_idx:20200, end_idx:20400
# --
# end:20400
# start_idx:20400, end_idx:20600
# --
# end:20600
# start_idx:20600, end_idx:20800
# --
# end:20800
# start_idx:20800, end_idx:21000
# --
# end:21000
# start_idx:21000, end_idx:21200
# --
# end:21200
# start_idx:21200, end_idx:21400
# --
# end:21400
# start_idx:21400, end_idx:21600
# --
# end:21600
# start_idx:21600, end_idx:21800
# --
# end:21800
# start_idx:21800, end_idx:22000
# --
# end:22000
# start_idx:22000, end_idx:22200
# --
# end:22200
# start_idx:22200, end_idx:22400
# --
# end:22400
# start_idx:22400, end_idx:22600
# --
# end:22600
# start_idx:22600, end_idx:22800
# --
# end:22800
# start_idx:22800, end_idx:23000
# --
# end:23000
# start_idx:23000, end_idx:23200
# --
# end:23200
# start_idx:23200, end_idx:23400
# --
# end:23400
# start_idx:23400, end_idx:23600
# --
# end:23600
# start_idx:23600, end_idx:23800
# --
# end:23800
# start_idx:23800, end_idx:24000
# --
# end:24000
# start_idx:24000, end_idx:24200
# --
# end:24200
# start_idx:24200, end_idx:24400
# --
# end:24400
# start_idx:24400, end_idx:24600
# --
# end:24600
# start_idx:24600, end_idx:24800
# --
# end:24800
# start_idx:24800, end_idx:25000
# --
# end:25000
# start_idx:25000, end_idx:25200
# --
# end:25200
# start_idx:25200, end_idx:25400
# --
# end:25400
# start_idx:25400, end_idx:25600
# --
# end:25600
# start_idx:25600, end_idx:25800
# --
# end:25800
# start_idx:25800, end_idx:26000
# --
# end:26000
# start_idx:26000, end_idx:26200
# --
# end:26200
# start_idx:26200, end_idx:26400
# --
# end:26400
# start_idx:26400, end_idx:26600
# --
# end:26600
# start_idx:26600, end_idx:26800
# --
# end:26800
# start_idx:26800, end_idx:27000
# --
# end:27000
# start_idx:27000, end_idx:27200
# --
# end:27200
# start_idx:27200, end_idx:27400
# --
# end:27400
# start_idx:27400, end_idx:27600
# --
# end:27600
# start_idx:27600, end_idx:27800
# --
# end:27800
# start_idx:27800, end_idx:28000
# --
# end:28000
# start_idx:28000, end_idx:28200
# --
# end:28200
# start_idx:28200, end_idx:28400
# --
# end:28400
# start_idx:28400, end_idx:28600
# --
# end:28600
# start_idx:28600, end_idx:28800
# --
# end:28800
# start_idx:28800, end_idx:29000
# --
# end:29000
# start_idx:29000, end_idx:29200
# --
# end:29200
# start_idx:29200, end_idx:29400
# --
# end:29400
# start_idx:29400, end_idx:29600
# --
# end:29600
# start_idx:29600, end_idx:29800
# --
# end:29800
# start_idx:29800, end_idx:30000
# batch_idx_for_training:150
# --
# end:30000
# start_idx:30000, end_idx:30200
# --
# end:30200
# start_idx:30200, end_idx:30400
# --
# end:30400
# start_idx:30400, end_idx:30600
# --
# end:30600
# start_idx:30600, end_idx:30800
# --
# end:30800
# start_idx:30800, end_idx:31000
# --
# end:31000
# start_idx:31000, end_idx:31200
# --
# end:31200
# start_idx:31200, end_idx:31400
# --
# end:31400
# start_idx:31400, end_idx:31600
# --
# end:31600
# start_idx:31600, end_idx:31800
# --
# end:31800
# start_idx:31800, end_idx:32000
# --
# end:32000
# start_idx:32000, end_idx:32200
# --
# end:32200
# start_idx:32200, end_idx:32400
# --
# end:32400
# start_idx:32400, end_idx:32600
# --
# end:32600
# start_idx:32600, end_idx:32800
# --
# end:32800
# start_idx:32800, end_idx:33000
# --
# end:33000
# start_idx:33000, end_idx:33200
# --
# end:33200
# start_idx:33200, end_idx:33400
# --
# end:33400
# start_idx:33400, end_idx:33600
# --
# end:33600
# start_idx:33600, end_idx:33800
# --
# end:33800
# start_idx:33800, end_idx:34000
# --
# end:34000
# start_idx:34000, end_idx:34200
# --
# end:34200
# start_idx:34200, end_idx:34400
# --
# end:34400
# start_idx:34400, end_idx:34600
# --
# end:34600
# start_idx:34600, end_idx:34800
# --
# end:34800
# start_idx:34800, end_idx:35000
# --
# end:35000
# start_idx:35000, end_idx:35200
# --
# end:35200
# start_idx:35200, end_idx:35400
# --
# end:35400
# start_idx:35400, end_idx:35600
# --
# end:35600
# start_idx:35600, end_idx:35800
# --
# end:35800
# start_idx:35800, end_idx:36000
# --
# end:36000
# start_idx:36000, end_idx:36200
# --
# end:36200
# start_idx:36200, end_idx:36400
# --
# end:36400
# start_idx:36400, end_idx:36600
# --
# end:36600
# start_idx:36600, end_idx:36800
# --
# end:36800
# start_idx:36800, end_idx:37000
# --
# end:37000
# start_idx:37000, end_idx:37200
# --
# end:37200
# start_idx:37200, end_idx:37400
# --
# end:37400
# start_idx:37400, end_idx:37600
# --
# end:37600
# start_idx:37600, end_idx:37800
# --
# end:37800
# start_idx:37800, end_idx:38000
# --
# end:38000
# start_idx:38000, end_idx:38200
# --
# end:38200
# start_idx:38200, end_idx:38400
# --
# end:38400
# start_idx:38400, end_idx:38600
# --
# end:38600
# start_idx:38600, end_idx:38800
# --
# end:38800
# start_idx:38800, end_idx:39000
# --
# end:39000
# start_idx:39000, end_idx:39200
# --
# end:39200
# start_idx:39200, end_idx:39400
# --
# end:39400
# start_idx:39400, end_idx:39600
# --
# end:39600
# start_idx:39600, end_idx:39800
# --
# end:39800
# start_idx:39800, end_idx:40000
# batch_idx_for_training:200
# --
# end:40000
# start_idx:40000, end_idx:40200
# --
# end:40200
# start_idx:40200, end_idx:40400
# --
# end:40400
# start_idx:40400, end_idx:40600
# --
# end:40600
# start_idx:40600, end_idx:40800
# --
# end:40800
# start_idx:40800, end_idx:41000
# --
# end:41000
# start_idx:41000, end_idx:41200
# --
# end:41200
# start_idx:41200, end_idx:41400
# --
# end:41400
# start_idx:41400, end_idx:41600
# --
# end:41600
# start_idx:41600, end_idx:41800
# --
# end:41800
# start_idx:41800, end_idx:42000
# --
# end:42000
# start_idx:42000, end_idx:42200
# --
# end:42200
# start_idx:42200, end_idx:42400
# --
# end:42400
# start_idx:42400, end_idx:42600
# --
# end:42600
# start_idx:42600, end_idx:42800
# --
# end:42800
# start_idx:42800, end_idx:43000
# --
# end:43000
# start_idx:43000, end_idx:43200
# --
# end:43200
# start_idx:43200, end_idx:43400
# --
# end:43400
# start_idx:43400, end_idx:43600
# --
# end:43600
# start_idx:43600, end_idx:43800
# --
# end:43800
# start_idx:43800, end_idx:44000
# --
# end:44000
# start_idx:44000, end_idx:44200
# --
# end:44200
# start_idx:44200, end_idx:44400
# --
# end:44400
# start_idx:44400, end_idx:44600
# --
# end:44600
# start_idx:44600, end_idx:44800
# --
# end:44800
# start_idx:44800, end_idx:45000
# --
# end:45000
# start_idx:45000, end_idx:45200
# --
# end:45200
# start_idx:45200, end_idx:45400
# --
# end:45400
# start_idx:45400, end_idx:45600
# --
# end:45600
# start_idx:45600, end_idx:45800
# --
# end:45800
# start_idx:45800, end_idx:46000
# --
# end:46000
# start_idx:46000, end_idx:46200
# --
# end:46200
# start_idx:46200, end_idx:46400
# --
# end:46400
# start_idx:46400, end_idx:46600
# --
# end:46600
# start_idx:46600, end_idx:46800
# --
# end:46800
# start_idx:46800, end_idx:47000
# --
# end:47000
# start_idx:47000, end_idx:47200
# --
# end:47200
# start_idx:47200, end_idx:47400
# --
# end:47400
# start_idx:47400, end_idx:47600
# --
# end:47600
# start_idx:47600, end_idx:47800
# --
# end:47800
# start_idx:47800, end_idx:48000
# --
# end:48000
# start_idx:48000, end_idx:48200
# --
# end:48200
# start_idx:48200, end_idx:48400
# --
# end:48400
# start_idx:48400, end_idx:48600
# --
# end:48600
# start_idx:48600, end_idx:48800
# --
# end:48800
# start_idx:48800, end_idx:49000
# --
# end:49000
# start_idx:49000, end_idx:49200
# --
# end:49200
# start_idx:49200, end_idx:49400
# --
# end:49400
# start_idx:49400, end_idx:49600
# --
# end:49600
# start_idx:49600, end_idx:49800
# --
# end:49800
# start_idx:49800, end_idx:50000
# batch_idx_for_training:250
# --
# end:50000
# start_idx:50000, end_idx:50200
# --
# end:50200
# start_idx:50200, end_idx:50400
# --
# end:50400
# start_idx:50400, end_idx:50600
# --
# end:50600
# start_idx:50600, end_idx:50800
# --
# end:50800
# start_idx:50800, end_idx:51000
# --
# end:51000
# start_idx:51000, end_idx:51200
# --
# end:51200
# start_idx:51200, end_idx:51400
# --
# end:51400
# start_idx:51400, end_idx:51600
# --
# end:51600
# start_idx:51600, end_idx:51800
# --
# end:51800
# start_idx:51800, end_idx:52000
# --
# end:52000
# start_idx:52000, end_idx:52200
# --
# end:52200
# start_idx:52200, end_idx:52400
# --
# end:52400
# start_idx:52400, end_idx:52600
# --
# end:52600
# start_idx:52600, end_idx:52800
# --
# end:52800
# start_idx:52800, end_idx:53000
# --
# end:53000
# start_idx:53000, end_idx:53200
# --
# end:53200
# start_idx:53200, end_idx:53400
# --
# end:53400
# start_idx:53400, end_idx:53600
# --
# end:53600
# start_idx:53600, end_idx:53800
# --
# end:53800
# start_idx:53800, end_idx:54000
# --
# end:54000
# start_idx:54000, end_idx:54200
# --
# end:54200
# start_idx:54200, end_idx:54400
# --
# end:54400
# start_idx:54400, end_idx:54600
# --
# end:54600
# start_idx:54600, end_idx:54800
# --
# end:54800
# start_idx:54800, end_idx:55000
# --
# end:55000
# start_idx:55000, end_idx:55200
# --
# end:55200
# start_idx:55200, end_idx:55400
# --
# end:55400
# start_idx:55400, end_idx:55600
# --
# end:55600
# start_idx:55600, end_idx:55800
# --
# end:55800
# start_idx:55800, end_idx:56000
# --
# end:56000
# start_idx:56000, end_idx:56200
# --
# end:56200
# start_idx:56200, end_idx:56400
# --
# end:56400
# start_idx:56400, end_idx:56600
# --
# end:56600
# start_idx:56600, end_idx:56800
# --
# end:56800
# start_idx:56800, end_idx:57000
# --
# end:57000
# start_idx:57000, end_idx:57200
# --
# end:57200
# start_idx:57200, end_idx:57400
# --
# end:57400
# start_idx:57400, end_idx:57600
# --
# end:57600
# start_idx:57600, end_idx:57800
# --
# end:57800
# start_idx:57800, end_idx:58000
# --
# end:58000
# start_idx:58000, end_idx:58200
# --
# end:58200
# start_idx:58200, end_idx:58400
# --
# end:58400
# start_idx:58400, end_idx:58600
# --
# end:58600
# start_idx:58600, end_idx:58800
# --
# end:58800
# start_idx:58800, end_idx:59000
# --
# end:59000
# start_idx:59000, end_idx:59200
# --
# end:59200
# start_idx:59200, end_idx:59400
# --
# end:59400
# start_idx:59400, end_idx:59600
# --
# end:59600
# start_idx:59600, end_idx:59800
# --
# end:59800
# start_idx:59800, end_idx:60000
# batch_idx_for_training:300
# --
# end:60000
# start_idx:60000, end_idx:60200
# --
# end:60200
# start_idx:60200, end_idx:60400
# --
# end:60400
# start_idx:60400, end_idx:60600
# --
# end:60600
# start_idx:60600, end_idx:60800
# --
# end:60800
# start_idx:60800, end_idx:61000
# --
# end:61000
# start_idx:61000, end_idx:61200
# --
# end:61200
# start_idx:61200, end_idx:61400
# --
# end:61400
# start_idx:61400, end_idx:61600
# --
# end:61600
# start_idx:61600, end_idx:61800
# --
# end:61800
# start_idx:61800, end_idx:62000
# --
# end:62000
# start_idx:62000, end_idx:62200
# --
# end:62200
# start_idx:62200, end_idx:62400
# --
# end:62400
# start_idx:62400, end_idx:62600
# --
# end:62600
# start_idx:62600, end_idx:62800
# --
# end:62800
# start_idx:62800, end_idx:63000
# --
# end:63000
# start_idx:63000, end_idx:63200
# --
# end:63200
# start_idx:63200, end_idx:63400
# --
# end:63400
# start_idx:63400, end_idx:63600
# --
# end:63600
# start_idx:63600, end_idx:63800
# --
# end:63800
# start_idx:63800, end_idx:64000
# --
# end:64000
# start_idx:64000, end_idx:64200
# --
# end:64200
# start_idx:64200, end_idx:64400
# --
# end:64400
# start_idx:64400, end_idx:64600
# --
# end:64600
# start_idx:64600, end_idx:64800
# --
# end:64800
# start_idx:64800, end_idx:65000
# --
# end:65000
# start_idx:65000, end_idx:65200
# --
# end:65200
# start_idx:65200, end_idx:65400
# --
# end:65400
# start_idx:65400, end_idx:65600
# --
# end:65600
# start_idx:65600, end_idx:65800
# --
# end:65800
# start_idx:65800, end_idx:66000
# --
# end:66000
# start_idx:66000, end_idx:66200
# --
# end:66200
# start_idx:66200, end_idx:66400
# --
# end:66400
# start_idx:66400, end_idx:66600
# --
# end:66600
# start_idx:66600, end_idx:66800
# --
# end:66800
# start_idx:66800, end_idx:67000
# --
# end:67000
# start_idx:67000, end_idx:67200
# --
# end:67200
# start_idx:67200, end_idx:67400
# --
# end:67400
# start_idx:67400, end_idx:67600
# --
# end:67600
# start_idx:67600, end_idx:67800
# --
# end:67800
# start_idx:67800, end_idx:68000
# --
# end:68000
# start_idx:68000, end_idx:68200
# --
# end:68200
# start_idx:68200, end_idx:68400
# --
# end:68400
# start_idx:68400, end_idx:68600
# --
# end:68600
# start_idx:68600, end_idx:68800
# --
# end:68800
# start_idx:68800, end_idx:69000
# --
# end:69000
# start_idx:69000, end_idx:69200
# --
# end:69200
# start_idx:69200, end_idx:69400
# --
# end:69400
# start_idx:69400, end_idx:69600
# --
# end:69600
# start_idx:69600, end_idx:69800
# --
# end:69800
# start_idx:69800, end_idx:70000
# batch_idx_for_training:350
# --
# end:70000
# start_idx:70000, end_idx:70200
# --
# end:70200
# start_idx:70200, end_idx:70400
# --
# end:70400
# start_idx:70400, end_idx:70600
# --
# end:70600
# start_idx:70600, end_idx:70800
# --
# end:70800
# start_idx:70800, end_idx:71000
# --
# end:71000
# start_idx:71000, end_idx:71200
# --
# end:71200
# start_idx:71200, end_idx:71400
# --
# end:71400
# start_idx:71400, end_idx:71600
# --
# end:71600
# start_idx:71600, end_idx:71800
# --
# end:71800
# start_idx:71800, end_idx:72000
# --
# end:72000
# start_idx:72000, end_idx:72200
# --
# end:72200
# start_idx:72200, end_idx:72400
# --
# end:72400
# start_idx:72400, end_idx:72600
# --
# end:72600
# start_idx:72600, end_idx:72800
# --
# end:72800
# start_idx:72800, end_idx:73000
# --
# end:73000
# start_idx:73000, end_idx:73200
# --
# end:73200
# start_idx:73200, end_idx:73400
# --
# end:73400
# start_idx:73400, end_idx:73600
# --
# end:73600
# start_idx:73600, end_idx:73800
# --
# end:73800
# start_idx:73800, end_idx:74000
# --
# end:74000
# start_idx:74000, end_idx:74200
# --
# end:74200
# start_idx:74200, end_idx:74400
# --
# end:74400
# start_idx:74400, end_idx:74600
# --
# end:74600
# start_idx:74600, end_idx:74800
# --
# end:74800
# start_idx:74800, end_idx:75000
# --
# end:75000
# start_idx:75000, end_idx:75200
# --
# end:75200
# start_idx:75200, end_idx:75400
# --
# end:75400
# start_idx:75400, end_idx:75600
# --
# end:75600
# start_idx:75600, end_idx:75800
# --
# end:75800
# start_idx:75800, end_idx:76000
# --
# end:76000
# start_idx:76000, end_idx:76200
# --
# end:76200
# start_idx:76200, end_idx:76400
# --
# end:76400
# start_idx:76400, end_idx:76600
# --
# end:76600
# start_idx:76600, end_idx:76800
# --
# end:76800
# start_idx:76800, end_idx:77000
# --
# end:77000
# start_idx:77000, end_idx:77200
# --
# end:77200
# start_idx:77200, end_idx:77400
# --
# end:77400
# start_idx:77400, end_idx:77600
# --
# end:77600
# start_idx:77600, end_idx:77800
# --
# end:77800
# start_idx:77800, end_idx:78000
# --
# end:78000
# start_idx:78000, end_idx:78200
# --
# end:78200
# start_idx:78200, end_idx:78400
# --
# end:78400
# start_idx:78400, end_idx:78600
# --
# end:78600
# start_idx:78600, end_idx:78800
# --
# end:78800
# start_idx:78800, end_idx:79000
# --
# end:79000
# start_idx:79000, end_idx:79200
# --
# end:79200
# start_idx:79200, end_idx:79400
# --
# end:79400
# start_idx:79400, end_idx:79600
# --
# end:79600
# start_idx:79600, end_idx:79800
# --
# end:79800
# start_idx:79800, end_idx:80000
# batch_idx_for_training:400
# --
# end:80000
# start_idx:80000, end_idx:80200
# --
# end:80200
# start_idx:80200, end_idx:80400
# --
# end:80400
# start_idx:80400, end_idx:80600
# --
# end:80600
# start_idx:80600, end_idx:80800
# --
# end:80800
# start_idx:80800, end_idx:81000
# --
# end:81000
# start_idx:81000, end_idx:81200
# --
# end:81200
# start_idx:81200, end_idx:81400
# --
# end:81400
# start_idx:81400, end_idx:81600
# --
# end:81600
# start_idx:81600, end_idx:81800
# --
# end:81800
# start_idx:81800, end_idx:82000
# --
# end:82000
# start_idx:82000, end_idx:82200
# --
# end:82200
# start_idx:82200, end_idx:82400
# --
# end:82400
# start_idx:82400, end_idx:82600
# --
# end:82600
# start_idx:82600, end_idx:82800
# --
# end:82800
# start_idx:82800, end_idx:83000
# --
# end:83000
# start_idx:83000, end_idx:83200
# --
# end:83200
# start_idx:83200, end_idx:83400
# --
# end:83400
# start_idx:83400, end_idx:83600
# --
# end:83600
# start_idx:83600, end_idx:83800
# --
# end:83800
# start_idx:83800, end_idx:84000
# --
# end:84000
# start_idx:84000, end_idx:84200
# --
# end:84200
# start_idx:84200, end_idx:84400
# --
# end:84400
# start_idx:84400, end_idx:84600
# --
# end:84600
# start_idx:84600, end_idx:84800
# --
# end:84800
# start_idx:84800, end_idx:85000
# --
# end:85000
# start_idx:85000, end_idx:85200
# --
# end:85200
# start_idx:85200, end_idx:85400
# --
# end:85400
# start_idx:85400, end_idx:85600
# --
# end:85600
# start_idx:85600, end_idx:85800
# --
# end:85800
# start_idx:85800, end_idx:86000
# --
# end:86000
# start_idx:86000, end_idx:86200
# --
# end:86200
# start_idx:86200, end_idx:86400
# --
# end:86400
# start_idx:86400, end_idx:86600
# --
# end:86600
# start_idx:86600, end_idx:86800
# --
# end:86800
# start_idx:86800, end_idx:87000
# --
# end:87000
# start_idx:87000, end_idx:87200
# --
# end:87200
# start_idx:87200, end_idx:87400
# --
# end:87400
# start_idx:87400, end_idx:87600
# --
# end:87600
# start_idx:87600, end_idx:87800
# --
# end:87800
# start_idx:87800, end_idx:88000
# --
# end:88000
# start_idx:88000, end_idx:88200
# --
# end:88200
# start_idx:88200, end_idx:88400
# --
# end:88400
# start_idx:88400, end_idx:88600
# --
# end:88600
# start_idx:88600, end_idx:88800
# --
# end:88800
# start_idx:88800, end_idx:89000
# --
# end:89000
# start_idx:89000, end_idx:89200
# --
# end:89200
# start_idx:89200, end_idx:89400
# --
# end:89400
# start_idx:89400, end_idx:89600
# --
# end:89600
# start_idx:89600, end_idx:89800
# --
# end:89800
# start_idx:89800, end_idx:90000
# batch_idx_for_training:450
# --
# end:90000
# start_idx:90000, end_idx:90200
# --
# end:90200
# start_idx:90200, end_idx:90400
# --
# end:90400
# start_idx:90400, end_idx:90600
# --
# end:90600
# start_idx:90600, end_idx:90800
# --
# end:90800
# start_idx:90800, end_idx:91000
# --
# end:91000
# start_idx:91000, end_idx:91200
# --
# end:91200
# start_idx:91200, end_idx:91400
# --
# end:91400
# start_idx:91400, end_idx:91600
# --
# end:91600
# start_idx:91600, end_idx:91800
# --
# end:91800
# start_idx:91800, end_idx:92000
# --
# end:92000
# start_idx:92000, end_idx:92200
# --
# end:92200
# start_idx:92200, end_idx:92400
# --
# end:92400
# start_idx:92400, end_idx:92600
# --
# end:92600
# start_idx:92600, end_idx:92800
# --
# end:92800
# start_idx:92800, end_idx:93000
# --
# end:93000
# start_idx:93000, end_idx:93200
# --
# end:93200
# start_idx:93200, end_idx:93400
# --
# end:93400
# start_idx:93400, end_idx:93600
# --
# end:93600
# start_idx:93600, end_idx:93800
# --
# end:93800
# start_idx:93800, end_idx:94000
# --
# end:94000
# start_idx:94000, end_idx:94200
# --
# end:94200
# start_idx:94200, end_idx:94400
# --
# end:94400
# start_idx:94400, end_idx:94600
# --
# end:94600
# start_idx:94600, end_idx:94800
# --
# end:94800
# start_idx:94800, end_idx:95000
# --
# end:95000
# start_idx:95000, end_idx:95200
# --
# end:95200
# start_idx:95200, end_idx:95400
# --
# end:95400
# start_idx:95400, end_idx:95600
# --
# end:95600
# start_idx:95600, end_idx:95800
# --
# end:95800
# start_idx:95800, end_idx:96000
# --
# end:96000
# start_idx:96000, end_idx:96200
# --
# end:96200
# start_idx:96200, end_idx:96400
# --
# end:96400
# start_idx:96400, end_idx:96600
# --
# end:96600
# start_idx:96600, end_idx:96800
# --
# end:96800
# start_idx:96800, end_idx:97000
# --
# end:97000
# start_idx:97000, end_idx:97200
# --
# end:97200
# start_idx:97200, end_idx:97400
# --
# end:97400
# start_idx:97400, end_idx:97600
# --
# end:97600
# start_idx:97600, end_idx:97800
# --
# end:97800
# start_idx:97800, end_idx:98000
# --
# end:98000
# start_idx:98000, end_idx:98200
# --
# end:98200
# start_idx:98200, end_idx:98400
# --
# end:98400
# start_idx:98400, end_idx:98600
# --
# end:98600
# start_idx:98600, end_idx:98800
# --
# end:98800
# start_idx:98800, end_idx:99000
# --
# end:99000
# start_idx:99000, end_idx:99200
# --
# end:99200
# start_idx:99200, end_idx:99400
# --
# end:99400
# start_idx:99400, end_idx:99600
# --
# end:99600
# start_idx:99600, end_idx:99800
# --
# end:99800
# start_idx:99800, end_idx:100000
# batch_idx_for_training:500
# --
# end:100000
# start_idx:100000, end_idx:100200
# --
# end:100200
# start_idx:100200, end_idx:100400
# --
# end:100400
# start_idx:100400, end_idx:100600
# --
# end:100600
# start_idx:100600, end_idx:100800
# --
# end:100800
# start_idx:100800, end_idx:101000
# --
# end:101000
# start_idx:101000, end_idx:101200
# --
# end:101200
# start_idx:101200, end_idx:101400
# --
# end:101400
# start_idx:101400, end_idx:101600
# --
# end:101600
# start_idx:101600, end_idx:101800
# --
# end:101800
# start_idx:101800, end_idx:102000
# --
# end:102000
# start_idx:102000, end_idx:102200
# --
# end:102200
# start_idx:102200, end_idx:102400
# --
# end:102400
# start_idx:102400, end_idx:102600
# --
# end:102600
# start_idx:102600, end_idx:102800
# --
# end:102800
# start_idx:102800, end_idx:103000
# --
# end:103000
# start_idx:103000, end_idx:103200
# --
# end:103200
# start_idx:103200, end_idx:103400
# --
# end:103400
# start_idx:103400, end_idx:103600
# --
# end:103600
# start_idx:103600, end_idx:103800
# --
# end:103800
# start_idx:103800, end_idx:104000
# --
# end:104000
# start_idx:104000, end_idx:104200
# --
# end:104200
# start_idx:104200, end_idx:104400
# --
# end:104400
# start_idx:104400, end_idx:104600
# --
# end:104600
# start_idx:104600, end_idx:104800
# --
# end:104800
# start_idx:104800, end_idx:105000
# --
# end:105000
# start_idx:105000, end_idx:105200
# --
# end:105200
# start_idx:105200, end_idx:105400
# --
# end:105400
# start_idx:105400, end_idx:105600
# --
# end:105600
# start_idx:105600, end_idx:105800
# --
# end:105800
# start_idx:105800, end_idx:106000
# --
# end:106000
# start_idx:106000, end_idx:106200
# --
# end:106200
# start_idx:106200, end_idx:106400
# --
# end:106400
# start_idx:106400, end_idx:106600
# --
# end:106600
# start_idx:106600, end_idx:106800
# --
# end:106800
# start_idx:106800, end_idx:107000
# --
# end:107000
# start_idx:107000, end_idx:107200
# --
# end:107200
# start_idx:107200, end_idx:107400
# --
# end:107400
# start_idx:107400, end_idx:107600
# --
# end:107600
# start_idx:107600, end_idx:107800
# --
# end:107800
# start_idx:107800, end_idx:108000
# --
# end:108000
# start_idx:108000, end_idx:108200
# --
# end:108200
# start_idx:108200, end_idx:108400
# --
# end:108400
# start_idx:108400, end_idx:108600
# --
# end:108600
# start_idx:108600, end_idx:108800
# --
# end:108800
# start_idx:108800, end_idx:109000
# --
# end:109000
# start_idx:109000, end_idx:109200
# --
# end:109200
# start_idx:109200, end_idx:109400
# --
# end:109400
# start_idx:109400, end_idx:109600
# --
# end:109600
# start_idx:109600, end_idx:109800
# --
# end:109800
# start_idx:109800, end_idx:110000
# batch_idx_for_training:550
# --
# end:110000
# start_idx:110000, end_idx:110200
# --
# end:110200
# start_idx:110200, end_idx:110400
# --
# end:110400
# start_idx:110400, end_idx:110600
# --
# end:110600
# start_idx:110600, end_idx:110800
# --
# end:110800
# start_idx:110800, end_idx:111000
# --
# end:111000
# start_idx:111000, end_idx:111200
# --
# end:111200
# start_idx:111200, end_idx:111400
# --
# end:111400
# start_idx:111400, end_idx:111600
# --
# end:111600
# start_idx:111600, end_idx:111800
# --
# end:111800
# start_idx:111800, end_idx:112000
# --
# end:112000
# start_idx:112000, end_idx:112200
# --
# end:112200
# start_idx:112200, end_idx:112400
# --
# end:112400
# start_idx:112400, end_idx:112600
# --
# end:112600
# start_idx:112600, end_idx:112800
# --
# end:112800
# start_idx:112800, end_idx:113000
# --
# end:113000
# start_idx:113000, end_idx:113200
# --
# end:113200
# start_idx:113200, end_idx:113400
# --
# end:113400
# start_idx:113400, end_idx:113600
# --
# end:113600
# start_idx:113600, end_idx:113800
# --
# end:113800
# start_idx:113800, end_idx:114000
# --
# end:114000
# start_idx:114000, end_idx:114200
# --
# end:114200
# start_idx:114200, end_idx:114400
# --
# end:114400
# start_idx:114400, end_idx:114600
# --
# end:114600
# start_idx:114600, end_idx:114800
# --
# end:114800
# start_idx:114800, end_idx:115000
# --
# end:115000
# start_idx:115000, end_idx:115200
# --
# end:115200
# start_idx:115200, end_idx:115400
# --
# end:115400
# start_idx:115400, end_idx:115600
# --
# end:115600
# start_idx:115600, end_idx:115800
# --
# end:115800
# start_idx:115800, end_idx:116000
# --
# end:116000
# start_idx:116000, end_idx:116200
# --
# end:116200
# start_idx:116200, end_idx:116400
# --
# end:116400
# start_idx:116400, end_idx:116600
# --
# end:116600
# start_idx:116600, end_idx:116800
# --
# end:116800
# start_idx:116800, end_idx:117000
# --
# end:117000
# start_idx:117000, end_idx:117200
# --
# end:117200
# start_idx:117200, end_idx:117400
# --
# end:117400
# start_idx:117400, end_idx:117600
# --
# end:117600
# start_idx:117600, end_idx:117800
# --
# end:117800
# start_idx:117800, end_idx:118000
# --
# end:118000
# start_idx:118000, end_idx:118200
# --
# end:118200
# start_idx:118200, end_idx:118400
# --
# end:118400
# start_idx:118400, end_idx:118600
# --
# end:118600
# start_idx:118600, end_idx:118800
# --
# end:118800
# start_idx:118800, end_idx:119000
# --
# end:119000
# start_idx:119000, end_idx:119200
# --
# end:119200
# start_idx:119200, end_idx:119400
# --
# end:119400
# start_idx:119400, end_idx:119600
# --
# end:119600
# start_idx:119600, end_idx:119800
# --
# end:119800
# start_idx:119800, end_idx:120000
# batch_idx_for_training:600
# --
# end:120000
# start_idx:120000, end_idx:120200
# --
# end:120200
# start_idx:120200, end_idx:120400
# --
# end:120400
# start_idx:120400, end_idx:120600
# --
# end:120600
# start_idx:120600, end_idx:120800
# --
# end:120800
# start_idx:120800, end_idx:121000
# --
# end:121000
# start_idx:121000, end_idx:121200
# --
# end:121200
# start_idx:121200, end_idx:121400
# --
# end:121400
# start_idx:121400, end_idx:121600
# --
# end:121600
# start_idx:121600, end_idx:121800
# --
# end:121800
# start_idx:121800, end_idx:122000
# --
# end:122000
# start_idx:122000, end_idx:122200
# --
# end:122200
# start_idx:122200, end_idx:122400
# --
# end:122400
# start_idx:122400, end_idx:122600
# --
# end:122600
# start_idx:122600, end_idx:122800
# --
# end:122800
# start_idx:122800, end_idx:123000
# --
# end:123000
# start_idx:123000, end_idx:123200
# --
# end:123200
# start_idx:123200, end_idx:123400
# --
# end:123400
# start_idx:123400, end_idx:123600
# --
# end:123600
# start_idx:123600, end_idx:123800
# --
# end:123800
# start_idx:123800, end_idx:124000
# --
# end:124000
# start_idx:124000, end_idx:124200
# --
# end:124200
# start_idx:124200, end_idx:124400
# --
# end:124400
# start_idx:124400, end_idx:124600
# --
# end:124600
# start_idx:124600, end_idx:124800
# --
# end:124800
# start_idx:124800, end_idx:125000
# --
# end:125000
# start_idx:125000, end_idx:125200
# --
# end:125200
# start_idx:125200, end_idx:125400
# --
# end:125400
# start_idx:125400, end_idx:125600
# --
# end:125600
# start_idx:125600, end_idx:125800
# --
# end:125800
# start_idx:125800, end_idx:126000
# --
# end:126000
# start_idx:126000, end_idx:126200
# --
# end:126200
# start_idx:126200, end_idx:126400
# --
# end:126400
# start_idx:126400, end_idx:126600
# --
# end:126600
# start_idx:126600, end_idx:126800
# --
# end:126800
# start_idx:126800, end_idx:127000
# --
# end:127000
# start_idx:127000, end_idx:127200
# --
# end:127200
# start_idx:127200, end_idx:127400
# --
# end:127400
# start_idx:127400, end_idx:127600
# --
# end:127600
# start_idx:127600, end_idx:127800
# --
# end:127800
# start_idx:127800, end_idx:128000
# --
# end:128000
# start_idx:128000, end_idx:128200
# --
# end:128200
# start_idx:128200, end_idx:128400
# --
# end:128400
# start_idx:128400, end_idx:128600
# --
# end:128600
# start_idx:128600, end_idx:128800
# --
# end:128800
# start_idx:128800, end_idx:129000
# --
# end:129000
# start_idx:129000, end_idx:129200
# --
# end:129200
# start_idx:129200, end_idx:129400
# --
# end:129400
# start_idx:129400, end_idx:129600
# --
# end:129600
# start_idx:129600, end_idx:129800
# --
# end:129800
# start_idx:129800, end_idx:130000
# batch_idx_for_training:650
# --
# end:130000
# start_idx:130000, end_idx:130200
# --
# end:130200
# start_idx:130200, end_idx:130400
# --
# end:130400
# start_idx:130400, end_idx:130600
# --
# end:130600
# start_idx:130600, end_idx:130800
# --
# end:130800
# start_idx:130800, end_idx:131000
# --
# end:131000
# start_idx:131000, end_idx:131200
# --
# end:131200
# start_idx:131200, end_idx:131400
# --
# end:131400
# start_idx:131400, end_idx:131600
# --
# end:131600
# start_idx:131600, end_idx:131800
# --
# end:131800
# start_idx:131800, end_idx:132000
# --
# end:132000
# start_idx:132000, end_idx:132200
# --
# end:132200
# start_idx:132200, end_idx:132400
# --
# end:132400
# start_idx:132400, end_idx:132600
# --
# end:132600
# start_idx:132600, end_idx:132800
# --
# end:132800
# start_idx:132800, end_idx:133000
# --
# end:133000
# start_idx:133000, end_idx:133200
# --
# end:133200
# start_idx:133200, end_idx:133400
# --
# end:133400
# start_idx:133400, end_idx:133600
# --
# end:133600
# start_idx:133600, end_idx:133800
# --
# end:133800
# start_idx:133800, end_idx:134000
# --
# end:134000
# start_idx:134000, end_idx:134200
# --
# end:134200
# start_idx:134200, end_idx:134400
# --
# end:134400
# start_idx:134400, end_idx:134600
# --
# end:134600
# start_idx:134600, end_idx:134800
# --
# end:134800
# start_idx:134800, end_idx:135000
# --
# end:135000
# start_idx:135000, end_idx:135200
# --
# end:135200
# start_idx:135200, end_idx:135400
# --
# end:135400
# start_idx:135400, end_idx:135600
# --
# end:135600
# start_idx:135600, end_idx:135800
# --
# end:135800
# start_idx:135800, end_idx:136000
# --
# end:136000
# start_idx:136000, end_idx:136200
# --
# end:136200
# start_idx:136200, end_idx:136400
# --
# end:136400
# start_idx:136400, end_idx:136600
# --
# end:136600
# start_idx:136600, end_idx:136800
# --
# end:136800
# start_idx:136800, end_idx:137000
# --
# end:137000
# start_idx:137000, end_idx:137200
# --
# end:137200
# start_idx:137200, end_idx:137400
# --
# end:137400
# start_idx:137400, end_idx:137600
# --
# end:137600
# start_idx:137600, end_idx:137800
# --
# end:137800
# start_idx:137800, end_idx:138000
# --
# end:138000
# start_idx:138000, end_idx:138200
# --
# end:138200
# start_idx:138200, end_idx:138400
# --
# end:138400
# start_idx:138400, end_idx:138600
# --
# end:138600
# start_idx:138600, end_idx:138800
# --
# end:138800
# start_idx:138800, end_idx:139000
# --
# end:139000
# start_idx:139000, end_idx:139200
# --
# end:139200
# start_idx:139200, end_idx:139400
# --
# end:139400
# start_idx:139400, end_idx:139600
# --
# end:139600
# start_idx:139600, end_idx:139800
# --
# end:139800
# start_idx:139800, end_idx:140000
# batch_idx_for_training:700
# --
# end:140000
# start_idx:140000, end_idx:140200
# --
# end:140200
# start_idx:140200, end_idx:140400
# --
# end:140400
# start_idx:140400, end_idx:140600
# --
# end:140600
# start_idx:140600, end_idx:140800
# --
# end:140800
# start_idx:140800, end_idx:141000
# --
# end:141000
# start_idx:141000, end_idx:141200
# --
# end:141200
# start_idx:141200, end_idx:141400
# --
# end:141400
# start_idx:141400, end_idx:141600
# --
# end:141600
# start_idx:141600, end_idx:141800
# --
# end:141800
# start_idx:141800, end_idx:142000
# --
# end:142000
# start_idx:142000, end_idx:142200
# --
# end:142200
# start_idx:142200, end_idx:142400
# --
# end:142400
# start_idx:142400, end_idx:142600
# --
# end:142600
# start_idx:142600, end_idx:142800
# --
# end:142800
# start_idx:142800, end_idx:143000
# --
# end:143000
# start_idx:143000, end_idx:143200
# --
# end:143200
# start_idx:143200, end_idx:143400
# --
# end:143400
# start_idx:143400, end_idx:143600
# --
# end:143600
# start_idx:143600, end_idx:143800
# --
# end:143800
# start_idx:143800, end_idx:144000
# --
# end:144000
# start_idx:144000, end_idx:144200
# --
# end:144200
# start_idx:144200, end_idx:144400
# --
# end:144400
# start_idx:144400, end_idx:144600
# --
# end:144600
# start_idx:144600, end_idx:144800
# --
# end:144800
# start_idx:144800, end_idx:145000
# --
# end:145000
# start_idx:145000, end_idx:145200
# --
# end:145200
# start_idx:145200, end_idx:145400
# --
# end:145400
# start_idx:145400, end_idx:145600
# --
# end:145600
# start_idx:145600, end_idx:145800
# --
# end:145800
# start_idx:145800, end_idx:146000
# --
# end:146000
# start_idx:146000, end_idx:146200
# --
# end:146200
# start_idx:146200, end_idx:146400
# --
# end:146400
# start_idx:146400, end_idx:146600
# --
# end:146600
# start_idx:146600, end_idx:146800
# --
# end:146800
# start_idx:146800, end_idx:147000
# --
# end:147000
# start_idx:147000, end_idx:147200
# --
# end:147200
# start_idx:147200, end_idx:147400
# --
# end:147400
# start_idx:147400, end_idx:147600
# --
# end:147600
# start_idx:147600, end_idx:147800
# --
# end:147800
# start_idx:147800, end_idx:148000
# --
# end:148000
# start_idx:148000, end_idx:148200
# --
# end:148200
# start_idx:148200, end_idx:148400
# --
# end:148400
# start_idx:148400, end_idx:148600
# --
# end:148600
# start_idx:148600, end_idx:148800
# --
# end:148800
# start_idx:148800, end_idx:149000
# --
# end:149000
# start_idx:149000, end_idx:149200
# --
# end:149200
# start_idx:149200, end_idx:149400
# --
# end:149400
# start_idx:149400, end_idx:149600
# --
# end:149600
# start_idx:149600, end_idx:149800
# --
# end:149800
# start_idx:149800, end_idx:150000
# batch_idx_for_training:750
# --
# end:150000
# start_idx:150000, end_idx:150200
# --
# end:150200
# start_idx:150200, end_idx:150400
# --
# end:150400
# start_idx:150400, end_idx:150600
# --
# end:150600
# start_idx:150600, end_idx:150800
# --
# end:150800
# start_idx:150800, end_idx:151000
# --
# end:151000
# start_idx:151000, end_idx:151200
# --
# end:151200
# start_idx:151200, end_idx:151400
# --
# end:151400
# start_idx:151400, end_idx:151600
# --
# end:151600
# start_idx:151600, end_idx:151800
# --
# end:151800
# start_idx:151800, end_idx:152000
# --
# end:152000
# start_idx:152000, end_idx:152200
# --
# end:152200
# start_idx:152200, end_idx:152400
# --
# end:152400
# start_idx:152400, end_idx:152600
# --
# end:152600
# start_idx:152600, end_idx:152800
# --
# end:152800
# start_idx:152800, end_idx:153000
# --
# end:153000
# start_idx:153000, end_idx:153200
# --
# end:153200
# start_idx:153200, end_idx:153400
# --
# end:153400
# start_idx:153400, end_idx:153600
# --
# end:153600
# start_idx:153600, end_idx:153800
# --
# end:153800
# start_idx:153800, end_idx:154000
# --
# end:154000
# start_idx:154000, end_idx:154200
# --
# end:154200
# start_idx:154200, end_idx:154400
# --
# end:154400
# start_idx:154400, end_idx:154600
# --
# end:154600
# start_idx:154600, end_idx:154800
# --
# end:154800
# start_idx:154800, end_idx:155000
# --
# end:155000
# start_idx:155000, end_idx:155200
# --
# end:155200
# start_idx:155200, end_idx:155400
# --
# end:155400
# start_idx:155400, end_idx:155600
# --
# end:155600
# start_idx:155600, end_idx:155800
# --
# end:155800
# start_idx:155800, end_idx:156000
# --
# end:156000
# start_idx:156000, end_idx:156200
# --
# end:156200
# start_idx:156200, end_idx:156400
# --
# end:156400
# start_idx:156400, end_idx:156600
# --
# end:156600
# start_idx:156600, end_idx:156800
# --
# end:156800
# start_idx:156800, end_idx:157000
# --
# end:157000
# start_idx:157000, end_idx:157200
# --
# end:157200
# start_idx:157200, end_idx:157400
# --
# end:157400
# start_idx:157400, end_idx:157600
# --
# end:157600
# start_idx:157600, end_idx:157800
# --
# end:157800
# start_idx:157800, end_idx:158000
# --
# end:158000
# start_idx:158000, end_idx:158200
# --
# end:158200
# start_idx:158200, end_idx:158400
# --
# end:158400
# start_idx:158400, end_idx:158600
# --
# end:158600
# start_idx:158600, end_idx:158800
# --
# end:158800
# start_idx:158800, end_idx:159000
# --
# end:159000
# start_idx:159000, end_idx:159200
# --
# end:159200
# start_idx:159200, end_idx:159400
# --
# end:159400
# start_idx:159400, end_idx:159600
# --
# end:159600
# start_idx:159600, end_idx:159800
# --
# end:159800
# start_idx:159800, end_idx:160000
# batch_idx_for_training:800
# --
# end:160000
# start_idx:160000, end_idx:160200
# --
# end:160200
# start_idx:160200, end_idx:160400
# --
# end:160400
# start_idx:160400, end_idx:160600
# --
# end:160600
# start_idx:160600, end_idx:160800
# --
# end:160800
# start_idx:160800, end_idx:161000
# --
# end:161000
# start_idx:161000, end_idx:161200
# --
# end:161200
# start_idx:161200, end_idx:161400
# --
# end:161400
# start_idx:161400, end_idx:161600
# --
# end:161600
# start_idx:161600, end_idx:161800
# --
# end:161800
# start_idx:161800, end_idx:162000
# --
# end:162000
# start_idx:162000, end_idx:162200
# --
# end:162200
# start_idx:162200, end_idx:162400
# --
# end:162400
# start_idx:162400, end_idx:162600
# --
# end:162600
# start_idx:162600, end_idx:162800
# --
# end:162800
# start_idx:162800, end_idx:163000
# --
# end:163000
# start_idx:163000, end_idx:163200
# --
# end:163200
# start_idx:163200, end_idx:163400
# --
# end:163400
# start_idx:163400, end_idx:163600
# --
# end:163600
# start_idx:163600, end_idx:163800
# --
# end:163800
# start_idx:163800, end_idx:164000
# --
# end:164000
# start_idx:164000, end_idx:164200
# --
# end:164200
# start_idx:164200, end_idx:164400
# --
# end:164400
# start_idx:164400, end_idx:164600
# --
# end:164600
# start_idx:164600, end_idx:164800
# --
# end:164800
# start_idx:164800, end_idx:165000
# --
# end:165000
# start_idx:165000, end_idx:165200
# --
# end:165200
# start_idx:165200, end_idx:165400
# --
# end:165400
# start_idx:165400, end_idx:165600
# --
# end:165600
# start_idx:165600, end_idx:165800
# --
# end:165800
# start_idx:165800, end_idx:166000
# --
# end:166000
# start_idx:166000, end_idx:166200
# --
# end:166200
# start_idx:166200, end_idx:166400
# --
# end:166400
# start_idx:166400, end_idx:166600
# --
# end:166600
# start_idx:166600, end_idx:166800
# --
# end:166800
# start_idx:166800, end_idx:167000
# --
# end:167000
# start_idx:167000, end_idx:167200
# --
# end:167200
# start_idx:167200, end_idx:167400
# --
# end:167400
# start_idx:167400, end_idx:167600
# --
# end:167600
# start_idx:167600, end_idx:167800
# --
# end:167800
# start_idx:167800, end_idx:168000
# --
# end:168000
# start_idx:168000, end_idx:168200
# --
# end:168200
# start_idx:168200, end_idx:168400
# --
# end:168400
# start_idx:168400, end_idx:168600
# --
# end:168600
# start_idx:168600, end_idx:168800
# --
# end:168800
# start_idx:168800, end_idx:169000
# --
# end:169000
# start_idx:169000, end_idx:169200
# --
# end:169200
# start_idx:169200, end_idx:169400
# --
# end:169400
# start_idx:169400, end_idx:169600
# --
# end:169600
# start_idx:169600, end_idx:169800
# --
# end:169800
# start_idx:169800, end_idx:170000
# batch_idx_for_training:850
# --
# end:170000
# start_idx:170000, end_idx:170200
# --
# end:170200
# start_idx:170200, end_idx:170400
# --
# end:170400
# start_idx:170400, end_idx:170600
# --
# end:170600
# start_idx:170600, end_idx:170800
# --
# end:170800
# start_idx:170800, end_idx:171000
# --
# end:171000
# start_idx:171000, end_idx:171200
# --
# end:171200
# start_idx:171200, end_idx:171400
# --
# end:171400
# start_idx:171400, end_idx:171600
# --
# end:171600
# start_idx:171600, end_idx:171800
# --
# end:171800
# start_idx:171800, end_idx:172000
# --
# end:172000
# start_idx:172000, end_idx:172200
# --
# end:172200
# start_idx:172200, end_idx:172400
# --
# end:172400
# start_idx:172400, end_idx:172600
# --
# end:172600
# start_idx:172600, end_idx:172800
# --
# end:172800
# start_idx:172800, end_idx:173000
# --
# end:173000
# start_idx:173000, end_idx:173200
# --
# end:173200
# start_idx:173200, end_idx:173400
# --
# end:173400
# start_idx:173400, end_idx:173600
# --
# end:173600
# start_idx:173600, end_idx:173800
# --
# end:173800
# start_idx:173800, end_idx:174000
# --
# end:174000
# start_idx:174000, end_idx:174200
# --
# end:174200
# start_idx:174200, end_idx:174400
# --
# end:174400
# start_idx:174400, end_idx:174600
# --
# end:174600
# start_idx:174600, end_idx:174800
# --
# end:174800
# start_idx:174800, end_idx:175000
# --
# end:175000
# start_idx:175000, end_idx:175200
# --
# end:175200
# start_idx:175200, end_idx:175400
# --
# end:175400
# start_idx:175400, end_idx:175600
# --
# end:175600
# start_idx:175600, end_idx:175800
# --
# end:175800
# start_idx:175800, end_idx:176000
# --
# end:176000
# start_idx:176000, end_idx:176200
# --
# end:176200
# start_idx:176200, end_idx:176400
# --
# end:176400
# start_idx:176400, end_idx:176600
# --
# end:176600
# start_idx:176600, end_idx:176800
# --
# end:176800
# start_idx:176800, end_idx:177000
# --
# end:177000
# start_idx:177000, end_idx:177200
# --
# end:177200
# start_idx:177200, end_idx:177400
# --
# end:177400
# start_idx:177400, end_idx:177600
# --
# end:177600
# start_idx:177600, end_idx:177800
# --
# end:177800
# start_idx:177800, end_idx:178000
# --
# end:178000
# start_idx:178000, end_idx:178200
# --
# end:178200
# start_idx:178200, end_idx:178400
# --
# end:178400
# start_idx:178400, end_idx:178600
# --
# end:178600
# start_idx:178600, end_idx:178800
# --
# end:178800
# start_idx:178800, end_idx:179000
# --
# end:179000
# start_idx:179000, end_idx:179200
# --
# end:179200
# start_idx:179200, end_idx:179400
# --
# end:179400
# start_idx:179400, end_idx:179600
# --
# end:179600
# start_idx:179600, end_idx:179800
# --
# end:179800
# start_idx:179800, end_idx:180000
# batch_idx_for_training:900
# --
# end:180000
# start_idx:180000, end_idx:180200
# --
# end:180200
# start_idx:180200, end_idx:180400
# --
# end:180400
# start_idx:180400, end_idx:180600
# --
# end:180600
# start_idx:180600, end_idx:180800
# --
# end:180800
# start_idx:180800, end_idx:181000
# --
# end:181000
# start_idx:181000, end_idx:181200
# --
# end:181200
# start_idx:181200, end_idx:181400
# --
# end:181400
# start_idx:181400, end_idx:181600
# --
# end:181600
# start_idx:181600, end_idx:181800
# --
# end:181800
# start_idx:181800, end_idx:182000
# --
# end:182000
# start_idx:182000, end_idx:182200
# --
# end:182200
# start_idx:182200, end_idx:182400
# --
# end:182400
# start_idx:182400, end_idx:182600
# --
# end:182600
# start_idx:182600, end_idx:182800
# --
# end:182800
# start_idx:182800, end_idx:183000
# --
# end:183000
# start_idx:183000, end_idx:183200
# --
# end:183200
# start_idx:183200, end_idx:183400
# --
# end:183400
# start_idx:183400, end_idx:183600
# --
# end:183600
# start_idx:183600, end_idx:183800
# --
# end:183800
# start_idx:183800, end_idx:184000
# --
# end:184000
# start_idx:184000, end_idx:184200
# --
# end:184200
# start_idx:184200, end_idx:184400
# --
# end:184400
# start_idx:184400, end_idx:184600
# --
# end:184600
# start_idx:184600, end_idx:184800
# --
# end:184800
# start_idx:184800, end_idx:185000
# --
# end:185000
# start_idx:185000, end_idx:185200
# --
# end:185200
# start_idx:185200, end_idx:185400
# --
# end:185400
# start_idx:185400, end_idx:185600
# --
# end:185600
# start_idx:185600, end_idx:185800
# --
# end:185800
# start_idx:185800, end_idx:186000
# --
# end:186000
# start_idx:186000, end_idx:186200
# --
# end:186200
# start_idx:186200, end_idx:186400
# --
# end:186400
# start_idx:186400, end_idx:186600
# --
# end:186600
# start_idx:186600, end_idx:186800
# --
# end:186800
# start_idx:186800, end_idx:187000
# --
# end:187000
# start_idx:187000, end_idx:187200
# --
# end:187200
# start_idx:187200, end_idx:187400
# --
# end:187400
# start_idx:187400, end_idx:187600
# --
# end:187600
# start_idx:187600, end_idx:187800
# --
# end:187800
# start_idx:187800, end_idx:188000
# --
# end:188000
# start_idx:188000, end_idx:188200
# --
# end:188200
# start_idx:188200, end_idx:188400
# --
# end:188400
# start_idx:188400, end_idx:188600
# --
# end:188600
# start_idx:188600, end_idx:188800
# --
# end:188800
# start_idx:188800, end_idx:189000
# --
# end:189000
# start_idx:189000, end_idx:189200
# --
# end:189200
# start_idx:189200, end_idx:189400
# --
# end:189400
# start_idx:189400, end_idx:189600
# --
# end:189600
# start_idx:189600, end_idx:189800
# --
# end:189800
# start_idx:189800, end_idx:190000
# batch_idx_for_training:950
# --
# end:190000
# start_idx:190000, end_idx:190200
# --
# end:190200
# start_idx:190200, end_idx:190400
# --
# end:190400
# start_idx:190400, end_idx:190600
# --
# end:190600
# start_idx:190600, end_idx:190800
# --
# end:190800
# start_idx:190800, end_idx:191000
# --
# end:191000
# start_idx:191000, end_idx:191200
# --
# end:191200
# start_idx:191200, end_idx:191400
# --
# end:191400
# start_idx:191400, end_idx:191600
# --
# end:191600
# start_idx:191600, end_idx:191800
# --
# end:191800
# start_idx:191800, end_idx:192000
# --
# end:192000
# start_idx:192000, end_idx:192200
# --
# end:192200
# start_idx:192200, end_idx:192400
# --
# end:192400
# start_idx:192400, end_idx:192600
# --
# end:192600
# start_idx:192600, end_idx:192800
# --
# end:192800
# start_idx:192800, end_idx:193000
# --
# end:193000
# start_idx:193000, end_idx:193200
# --
# end:193200
# start_idx:193200, end_idx:193400
# --
# end:193400
# start_idx:193400, end_idx:193600
# --
# end:193600
# start_idx:193600, end_idx:193800
# --
# end:193800
# start_idx:193800, end_idx:194000
# --
# end:194000
# start_idx:194000, end_idx:194200
# --
# end:194200
# start_idx:194200, end_idx:194400
# --
# end:194400
# start_idx:194400, end_idx:194600
# --
# end:194600
# start_idx:194600, end_idx:194800
# --
# end:194800
# start_idx:194800, end_idx:195000
# --
# end:195000
# start_idx:195000, end_idx:195200
# --
# end:195200
# start_idx:195200, end_idx:195400
# --
# end:195400
# start_idx:195400, end_idx:195600
# --
# end:195600
# start_idx:195600, end_idx:195800
# --
# end:195800
# start_idx:195800, end_idx:196000
# --
# end:196000
# start_idx:196000, end_idx:196200
# --
# end:196200
# start_idx:196200, end_idx:196400
# --
# end:196400
# start_idx:196400, end_idx:196600
# --
# end:196600
# start_idx:196600, end_idx:196800
# --
# end:196800
# start_idx:196800, end_idx:197000
# --
# end:197000
# start_idx:197000, end_idx:197200
# --
# end:197200
# start_idx:197200, end_idx:197400
# --
# end:197400
# start_idx:197400, end_idx:197600
# --
# end:197600
# start_idx:197600, end_idx:197800
# --
# end:197800
# start_idx:197800, end_idx:198000
# --
# end:198000
# start_idx:198000, end_idx:198200
# --
# end:198200
# start_idx:198200, end_idx:198400
# --
# end:198400
# start_idx:198400, end_idx:198600
# --
# end:198600
# start_idx:198600, end_idx:198800
# epoch_1 start, end:True?
