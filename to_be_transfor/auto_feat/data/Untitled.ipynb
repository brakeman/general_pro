# %%
import pandas as pd
import numpy as np

# %%
tra_x = pd.read_csv('./train.csv').head(10000)

# %%
# handcraft pipeline

    # id 类 certId, dist, bankCard,
    # 时间类  certValidBegin, certValidStop，weekday，setupHour
        - 分箱子
        - 是否周末 weekday
        - 是否白天
    
    # rank类 age, lmt 
        - 严格分箱，弃旧不用；
        
    # 相似类 
        - certId, dist, residentAddr
        - certValidStop, certValidBegin
        - highestEdu, edu
        # DIFF, DIV, SUM, MULTIPLY

# %%
tra_x.iloc[:, 90:].head()
# Out:
#    certValidStop     bankCard  ethnic  residentAddr  highestEdu  linkRela  \
# 0   3.952714e+09       -999.0       0        640513        -999         0
# 1   4.371149e+09  622848079.0       0        621023          99        11
# 2   3.979066e+09       -999.0       0        641204          70         0
# 3   4.344538e+09       -999.0       0          -999        -999      -999
# 4   3.967834e+09  622700392.0       4        732628          99        11
#
#    setupHour  weekday  ncloseCreditCard  unpayIndvLoan  unpayOtherLoan  \
# 0          9        6                 1              0               1
# 1          6        5                 1              0               1
# 2          1        6                 0              0               0
# 3         13        6                 1              0               1
# 4          8        3                 1              0               1
#
#    unpayNormalLoan  5yearBadloan  isNew
# 0                0             0      1
# ...

# %%
tra_x.columns[88:]
# Out:
# Index(['x_78', 'certValidBegin', 'certValidStop', 'bankCard', 'ethnic',
#        'residentAddr', 'highestEdu', 'linkRela', 'setupHour', 'weekday',
#        'ncloseCreditCard', 'unpayIndvLoan', 'unpayOtherLoan',
#        'unpayNormalLoan', '5yearBadloan', 'isNew'],
#       dtype='object')

# %%
tra_x
# Out:
#          id  certId  loanProduct  gender  age    dist  edu  job     lmt  \
# 0         1  640582            1       2   27  640500    0    8   5.963
# 1         2  621023            2       2   25  640600    0    3   6.467
# 2         3  641283            1       2   37  641200   70    5   0.596
# 3         4  340821            3       2   29  340821    0    4   6.300
# 4         5  732628            2       2   22  732628    0    2   6.700
# 5         6  610221            3       2   27  610221    0    4   5.867
# 6         7  629004            1       1   31  620100    0    3  12.630
# 7         8  822223            1       2   32  822223    0    3   1.096
# 8         9  632503            1       2   27  640700    0    4   0.830
# 9        10  722323            2       2   37  722300    0    3   7.667
# 10       11  630724            1       2   28  630700    0    2   1.463
# 11       12  571326            3       2   19  571326    0    4   2.800
# ...
