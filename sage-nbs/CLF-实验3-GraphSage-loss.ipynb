# %% [raw]
# v1: 损失函数无监督(负采样loss)+监督分类；
# 实际上这个损失需要提供三个对象：
# 1. target_node
# 2. one neigh node
# 3. a batch of neg sampled nodes（比如500个无关类点；);

# %%
import torch as t
import torch.nn as nn
from torch.autograd import Variable
from torch.nn import Parameter
import numpy as np

class NEG_loss(nn.Module):
    def __init__(self, num_classes, embed_size, weights=None):
        """
        :param num_classes: An int. The number of possible classes.
        :param embed_size: An int. EmbeddingLockup size
        :param num_sampled: An int. The number of sampled from noise examples
        :param weights: A list of non negative floats. Class weights. None if
            using uniform sampling. The weights are calculated prior to
            estimation and can be of any form, e.g equation (5) in [1]
        """
        super(NEG_loss, self).__init__()

        self.num_classes = num_classes
        self.embed_size = embed_size

        self.out_embed = nn.Embedding(self.num_classes, self.embed_size, sparse=True)
        self.out_embed.weight = Parameter(t.FloatTensor(self.num_classes, self.embed_size).uniform_(-1, 1))

        self.in_embed = nn.Embedding(self.num_classes, self.embed_size, sparse=True)
        self.in_embed.weight = Parameter(t.FloatTensor(self.num_classes, self.embed_size).uniform_(-1, 1))

        self.weights = weights
        if self.weights is not None:
            assert min(self.weights) >= 0, "Each weight should be >= 0"

            self.weights = Variable(t.from_numpy(weights)).float()

            
    def sample(self, num_sample):
        """
        draws a sample from classes based on weights
        """
        return t.multinomial(self.weights, num_sample, True)

    
    def forward(self, input_labes, out_labels, num_sampled):
        """
        :param input_labes: Tensor with shape of [batch_size] of Long type
        :param out_labels: Tensor with shape of [batch_size, window_size] of Long type
        :param num_sampled: An int. The number of sampled from noise examples
        :return: Loss estimation with shape of [1]
            loss defined in Mikolov et al. Distributed Representations of Words and Phrases and their Compositionality
            papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf
        """

        use_cuda = self.out_embed.weight.is_cuda
        [batch_size, window_size] = out_labels.size()
        input = self.in_embed(input_labes.repeat(1, window_size).contiguous().view(-1))
        output = self.out_embed(out_labels.contiguous().view(-1))

        if self.weights is not None:
            noise_sample_count = batch_size * window_size * num_sampled
            draw = self.sample(noise_sample_count)
            noise = draw.view(batch_size * window_size, num_sampled)
        else:
            noise = Variable(t.Tensor(batch_size * window_size, num_sampled).
                             uniform_(0, self.num_classes - 1).long())

        if use_cuda:
            noise = noise.cuda()
        noise = self.out_embed(noise).neg()

        log_target = (input * output).sum(1).squeeze().sigmoid().log()

        ''' ∑[batch_size * window_size, num_sampled, embed_size] * [batch_size * window_size, embed_size, 1] ->
            ∑[batch_size, num_sampled, 1] -> [batch_size] '''
        sum_log_sampled = t.bmm(noise, input.unsqueeze(2)).sigmoid().log().sum(1).squeeze()
        loss = log_target + sum_log_sampled
        return -loss.sum() / batch_size

    
    def input_embeddings(self):
        return self.in_embed.weight.data.cpu().numpy()

# %%
class NegativeSamplingLoss(nn.Module):
    def __init__(self):
        super().__init__()

    def forward(self, input_vectors, output_vectors, noise_vectors):
        batch_size, embed_size = input_vectors.shape
        # Input vectors should be a batch of column vectors
        input_vectors = input_vectors.view(batch_size, embed_size, 1)
        
        # Output vectors should be a batch of row vectors
        output_vectors = output_vectors.view(batch_size, 1, embed_size)
        
        # bmm = batch matrix multiplication
        # correct log-sigmoid loss
        out_loss = torch.bmm(output_vectors, input_vectors).sigmoid().log()
        out_loss = out_loss.squeeze()
        
        # incorrect log-sigmoid loss
        noise_loss = torch.bmm(noise_vectors.neg(), input_vectors).sigmoid().log()
        noise_loss = noise_loss.squeeze().sum(1)  # sum the losses over the sample of noise vectors

        # negate and sum correct and noisy log-sigmoid losses
        # return average batch loss
        return -(out_loss + noise_loss).mean()

# %%
import networkx as nx
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer,TfidfVectorizer
from numpy import dot
from numpy.linalg import norm
from sklearn.metrics.pairwise import cosine_similarity
import torch
import torch.nn as nn
import copy
# from graphviz import Digraph
from torch.nn import init
from torch.autograd import Variable
import torch.nn.functional as F
import time
import random
from sklearn.metrics import f1_score
from collections import defaultdict
from ClfTemplates import get_all_template_path, sample_template, sample_template_path
from ClfUse import showClfResult, get_samples, labeledDataFromJson
from Ner_model import get_X_Y, lstm_crf, predict, preprocess
from Ner_data_make import create_fake_label, fake2real
from keras.preprocessing.sequence import pad_sequences

from keras.models import Model, Input, Sequential
from keras.layers import LSTM, Embedding, SpatialDropout1D,concatenate, Dense, TimeDistributed, Dropout, Bidirectional
from keras_contrib.layers import CRF
from keras_contrib.losses import crf_loss
from keras.utils import to_categorical
import keras
from collections import Iterable 
import pandas as pd
import numpy as np
import random
import re
import warnings
warnings.filterwarnings("ignore")


# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
# Out:
# Using TensorFlow backend.

# %%
import pandas as pd
import random

def gen_new(ori_str):
    return ''.join([str(random.randint(0,9)) if i.isdigit() else i for i in list(ori_str)])

def create_fake_label(DF, fake_times):
    DF2 = DF.copy()
    for i in range(fake_times):
        col = DF2.apply(lambda x: gen_new(x.token) if x.lable!='other' else x.token, axis=1)
        DF2['new_tokens_{}'.format(i)] = col
    return DF2

def generate_sent_id(sent_id_list, origin_sent_id):
    dic = {}
    for k in origin_sent_id:
        tmp = 'send_id_' + str(sent_id_list[-1])
        sent_id_list.pop()
        dic.setdefault(k, tmp)
    return sent_id_list, dic

def fake2real(df, fake_times):
    '''label 写错了，将错就错'''
    lis = []
    sent_id_list = list(range(len(df.sent_id.unique()) * fake_times))
    origin_sent_id = df.sent_id.unique()
    for i in range(fake_times):
        tmp_df = df[['new_tokens_{}'.format(i), 'lable', 'sent_id']]
        tmp_df.columns = ['token', 'lable', 'sent_id']
        sent_id_list, dic = generate_sent_id(sent_id_list, origin_sent_id)
        tmp_df.sent_id = tmp_df.sent_id.map(dic)
        lis.append(tmp_df)
    return pd.concat(lis)

def fake2real_v2(df, fake_times):
    lis = []
    sent_id_list = list(range(len(df.sent_id.unique()) * fake_times))
    origin_sent_id = df.sent_id.unique()
    for i in range(fake_times):
        tmp_df = df[['new_tokens_{}'.format(i), 'sent_id', 'cls']]
        tmp_df.columns = ['token', 'sent_id', 'cls']
        sent_id_list, dic = generate_sent_id(sent_id_list, origin_sent_id)
        tmp_df.sent_id = tmp_df.sent_id.map(dic)
        lis.append(tmp_df)
    return pd.concat(lis)

# %% [markdown]
# ### 1. sms 文件

# %%
import pickle
import os
from IPython.display import display
import itertools
# /home/qibo/sms_nlp
res_root = '/home/qibo/sms_nlp/annotation_results/round_2_results_bank/'
# res_root = '/home/qibo/work_notebooks/sms_nlp/annotation_results/round_2_results_loan/'
ALL = []
for idx,fn in enumerate(os.listdir(res_root)):
    print(fn)
    despatcher = fn.split('.')[0]
    print(despatcher)
    with open(os.path.join(res_root, fn), 'rb') as fin:
        tasks = pickle.load(fin)

    for key, group in itertools.groupby(tasks, key=lambda x:x.output[0]):
#         print(list(group)[-2].output)
#         print('##############################')
#         print(list(group)[-1].output)
        regex_id = key
        to_display = None
        sms_type = None
        fields = []
        field_types = []
        for t in list(group):
            output = t.output
            val = t.value
            regex_id = output[0]
            group_id = output[1]
            gened_regex = output[2]
            box_markups = output[3]
            if group_id == 0:
                sms_type = val
                if sms_type:
                    print(regex_id, gened_regex)
                    print('短信类型: ', sms_type)
                to_display = box_markups[0][0]
                text = box_markups[0][0].text
#                 print('text :', text)
                spans = box_markups[0][0].spans
                for s in spans:
                    fields.append(text[s.start : s.stop])
            else:
                field_types.append(val)
        print(field_types)
        if None not in field_types:
            tem = {}
            for i , j in zip(fields, field_types):
                tem[i] = j
            new_text = 'Reg_id_' + str(regex_id) + ' ' + text
#             print(cluster_id)
            ALL.append([text, fields ,field_types, tem, sms_type])
        print('------------------------------------------------------')
# Out:
# indusb.pkl
# indusb
# 3764 ^Dear Customer Txn on IndusInd Bank Credit Card no .* for INR .* on .* at .* is .* call 18602677777 for query\.Click on http\:\/\/bit\.ly\/2B8nSNl to update your Aadhaar Number\, ignore if already done\.$
# 短信类型:  交易流水＿转账
# ['银行卡号＿自己', '金额＿转出', '日期＿交易时间', '机构＿交易平台', 'other']
# ------------------------------------------------------
# 3765 ^Your IndusInd Bank A\/C .* has been debited for .* towards your Debit Card purchase\.The available Balance is .*$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转出', '金额＿余额']
# ------------------------------------------------------
# 3766 ^Your a\/c no\. .* is credited by .* on .* by a\/c linked to mobile .* \(IMPS Ref no .*$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转入', '日期＿交易时间', '账户账号＿他人', 'other']
# ------------------------------------------------------
# 3767 ^Your IndusInd Bank A\/C .* has been debited for .* towards an ATM Cash Withdrawal Transaction\. Available Balance is .*$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转出', '金额＿余额']
# ------------------------------------------------------
# 3768 ^Your a\/c no\. .* is debited for .* on .* and a\/c .* credited \(IMPS Ref no .*$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转出', '日期＿交易时间', '账户账号＿他人', 'other']
# ------------------------------------------------------
# 3772 ^Dear Customer\, Your account no .* has been Credited for INR .* towards .* Your combine balance is INR .*$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转入', 'other', '金额＿余额']
# ------------------------------------------------------
# 3773 ^Dear Customer\, thank you for your .* Payment of INR .* towards your IndusInd Bank Credit Card .* Your payment is credited to your Credit Card a\/c on .*$
# 短信类型:  交易流水＿转账
# ['other', '金额＿转出', '银行卡号＿自己', '日期＿交易时间']
# ------------------------------------------------------
# [None, None, None, None]
# ------------------------------------------------------
# 3776 ^Dear Customer\, statement for your IndusInd Bank Credit Card \# .* dated .* due .* will be delivered shortly\. Total Amount Due is INR .* and Minimum Amount Due is INR .* keep track of your Credit Card outstanding and view statements\, download the IndusMobile App now\: http\:\/\/goo\.gl\/zQM2Yl$
# 短信类型:  信用卡＿还款提醒
# ['银行卡号＿自己', '日期＿还款日期', 'other', '金额＿应还金额', '金额＿最小应还金额']
# ------------------------------------------------------
# 3777 ^Your curr loan EMI .* for .* due on .* Pls pay or ensure suff bal on presentation\. Ignore if paid already\. For Queries call .* mail us in reach4loan\@indusind\.com$
# 短信类型:  贷后提醒＿逾期催收
# ['金额＿应还金额', 'other', '日期＿还款日期', 'other']
# ------------------------------------------------------
# 3778 ^Your a\/c no\. .* is credited for Rs\. .* on .* and debited from .* \(UPI Ref no .*$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转入', '日期＿交易时间', '账户账号＿他人', 'other']
# ------------------------------------------------------
# [None, None, None, None, None]
# ------------------------------------------------------
# 3781 ^Dear Customer\, as per the last statement generated for your IndusInd Bank Credit Card ending \# .* total \& minimum amounts due are .* \& .* respectively\. We request you to make the payment by the due date ie .* You can use any of our convenient online payment options\:http\:\/\/bit\.ly\/2B2fkmj or download the all new IndusMobile App to make your Credit Card payment\: http\:\/\/goo\.gl\/zQM2Yl \. Please ignore if paid already\.$
# 短信类型:  信用卡＿逾期警告
# ['银行卡号＿自己', '金额＿应还金额', '金额＿最小应还金额', '日期＿还款日期']
# ------------------------------------------------------
# 3783 ^Dear Customer\, Your account no .* has been Debited for INR .* towards .* Your .* balance is INR .* Get mobile banking\@ https\:\/\/tinyurl\.com\/y94zzu8k$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转出', 'other', 'other', '金额＿余额']
# ------------------------------------------------------
# 3784 ^Ur curr loan EMI Rs\. .* for .* due on .* Pls pay or ensure suff bal on or before presentation in ur bank acc\. Ignore if paid already\. Qrs call 18001023333 mail us reach4loan\@indusind\.com\.$
# 短信类型:  贷后提醒＿到期提醒
# ['金额＿应还金额', 'other', '日期＿还款日期']
# ------------------------------------------------------
# 3787 ^Dear Customer\, the payment on your IndusInd Bank Credit Card \# .* is overdue\. The minimum amount due is INR .* We request you to make the payment immediately using any of our convenient online payment options\: http\:\/\/bit\.ly\/2B2fkmj or download the all new IndusMobile App to make your Credit Card payment\: http\:\/\/goo\.gl\/zQM2Yl Please ignore if paid already or if you have provided a standing instruction to debit your account\.$
# 短信类型:  信用卡＿逾期警告
# ['银行卡号＿自己', '金额＿应还金额']
# ------------------------------------------------------
# 3789 ^Your IndusInd Bank A\/C .* has been credited by .* towards cash deposit\. The available Balance is .*$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转入', '金额＿余额']
# ------------------------------------------------------
# 3790 ^Your IndusInd Bank A\/C No\. .* has been debited for Rs\. .* towards INDUSMOBILE\-RECHARGE on .* The available balance is Rs\. .*$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转出', '日期＿交易时间', 'other']
# ------------------------------------------------------
# 3791 ^Dear Customer\, your Savings Account A\/C .* has been credited with INR .* towards Interest Credit for the quarter ending .*$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转入', 'other']
# ------------------------------------------------------
# 3792 ^Dear Customer\, Txn on IndusInd Bank Credit Card .* for INR .* on .* at .* is Approved\. Pls call 18602677777 for query\.$
# 短信类型:  交易流水＿转账
# ['银行卡号＿自己', '金额＿转出', '日期＿交易时间', '机构＿交易平台']
# ------------------------------------------------------
# 3801 ^Dear Customer\, the .* Statement for your IndusInd Bank credit card no\. .* is delivered to your mailing address\. The total and minimum amount due are INR .* and INR .* respectively\. To view or request for your Credit Card e\-Statement\, login\/download the IndusMobile App\: http\:\/\/goo\.gl\/zQM2Yl$
# 短信类型:  信用卡＿还款提醒
# ['日期＿还款日期', '银行卡号＿自己', '金额＿应还金额', '金额＿最小应还金额']
# ------------------------------------------------------
# 3805 ^Bal of INR .* on .* AM in A\/C .* will earn 6\% pa on bal above 10cr\,5\.5\% pa on balance above 1cr\,5\% pa above 10lac\,4\%pa upto 10lac\.For Balance details call 18002741000\. Get mobile banking\@ .*$
# 短信类型:  交易流水＿余额
# ['金额＿余额', '日期＿交易时间', '账户账号＿自己', 'other']
# ------------------------------------------------------
# 3818 ^Dear Customer\, In your account .* the amount of Rs\. .* which was hold marked is now released\. Your available combined balance is .* Please contact to branch \\ Contact Center for any further queries\.$
# 短信类型:  sms_other
# [None, None, None]
# ------------------------------------------------------
# 3819 ^Sorry\! The balance available in your IndusInd Bank A\/C .* is not sufficient to process your transaction\. Your balance is Rs\. .*$
# 短信类型:  账号异常＿余额不足
# ['账户账号＿自己', '金额＿余额']
# ------------------------------------------------------
# 3822 ^Dear Cust\, Thanks for your Cash payment of .* dtd .* towards your Loan acct vide rpt\# .* For queries call 18001023333 mail us in reach4loan\@indusind\.com$
# 短信类型:  交易流水＿转账
# ['金额＿转出', '日期＿交易时间', 'other']
# ------------------------------------------------------
# 3829 ^IndusInd bank A\/c .* has been credited for .* towards a NEFT Credit from .* with Transaction Reference Number .* Available balance is .* Get mobile banking\@ bit\.ly\/IndusM$
# 短信类型:  账户账号＿自己
# ['金额＿转入', 'other', 'other', 'other', '金额＿余额']
# ------------------------------------------------------
# 3832 ^Your Bank A\/C .* has been debited for INR .* towards IndusMobile .* Transfer on .* Avl Bal is INR .*$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转出', 'other', '日期＿交易时间', '金额＿余额']
# ------------------------------------------------------
# 3842 ^Your fund transfer for Rs\. .* on .* is declined as the beneficiary Account no or IFS Code is invalid \(IMPS Ref no\. .*$
# 短信类型:  账号异常＿扣款失败
# ['金额＿转出', '日期＿交易时间', 'other']
# ------------------------------------------------------
# 3845 ^The balance in your a\/c .* has been below the min\. balance requirement .* Please maintain .* balance in .* to avoid .*$
# 短信类型:  账号异常＿余额不足
# ['账户账号＿自己', '日期＿交易时间', 'other', 'other', 'other']
# ------------------------------------------------------
# 3847 ^Your one time password for PIN Generation on IVR is .* \.The password would expire by .* If you have not requested this please contact 18605005004 urgently\. Please do not share the OTP with anyone for security reasons\.$
# 短信类型:  sms_other
# ['other', 'other']
# ------------------------------------------------------
# 3849 ^IndusInd Bank A\/C .* has been debited for .* towards IndusMobile NEFT transfer with UTR Number .* Available balance is .*$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转出', 'other', '金额＿余额']
# ------------------------------------------------------
# [None, None, None]
# ------------------------------------------------------
# 3857 ^The balance in your a\/c .* has been below the min\. balance requirement in .* Please fund the a\/c to maintain balance in .* to avoid .*$
# 短信类型:  账号异常＿余额不足
# ['账户账号＿自己', 'other', '日期＿交易时间', 'other']
# ------------------------------------------------------
# ['other', '账户账号＿自己', '金额＿转出', None, None]
# ------------------------------------------------------
# 3871 ^Cheque No\. .* issued by you for .* in A\/C .* is returned\.Transfer funds online with ease\. Get mobile banking\@ .*$
# 短信类型:  交易流水＿转账
# ['other', '金额＿转出', '账户账号＿自己', 'other']
# ------------------------------------------------------
# 3873 ^Thanks for availing 2WHEELER Loan .* from IBL\. Pls note the same for future correspondence\. EMI Due Date \: .* of every month\, EMI .* For queries pls call 18001023333 mail us in reach4loan\@indusind\.com$
# 短信类型:  贷前申请＿申请交互
# ['other', 'other', '金额＿应还金额']
# ------------------------------------------------------
# 3879 ^Your Bank A\/C .* has been Dr for INR .* towards IndusMobile NEFT transfer with UTR .* Avl Bal is INR .*$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转出', 'other', '金额＿余额']
# ------------------------------------------------------
# 3884 ^Dear Customer\, Your NEFT Transaction with ref\. number .* for Rs .* has been credited to the beneficiary\. Thank You\. Get mobile banking\@ .*$
# 短信类型:  交易流水＿转账
# ['other', '金额＿转入', 'other']
# ------------------------------------------------------
# 3888 ^Cheque No\. .* for .* issued from your Indusind Bank A\/C .* has been dishonoured\.Transfer funds with IndusMobile\. Get mobile banking\@ .*$
# 短信类型:  账号异常＿扣款失败
# ['other', '金额＿转出', '账户账号＿自己', 'other']
# ------------------------------------------------------
# [None, None, None, None]
# ------------------------------------------------------
# 3892 ^Your IndusInd Bank A\/C .* has been debited for .* towards .* Recharge via IndusMobile on .* The available Balance is .*$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转出', 'other', '日期＿交易时间', '金额＿余额']
# ------------------------------------------------------
# ['other', None, 'other', 'other', 'other', 'other', 'other']
# ------------------------------------------------------
# 3896 ^Your fund transfer for Rs\. .* on .* is declined\. Please refer to the beneficiary \(IMPS Ref no\. .*$
# 短信类型:  账号异常＿扣款失败
# ['金额＿转出', '日期＿交易时间', 'other']
# ------------------------------------------------------
# 3907 ^Bal of INR .* on .* AM in A\/C .* will earn 6\% pa on bal above 10cr\,5\.5\% pa on balance above 1cr\,5\% pa above 10lac\,4\%pa upto 10lac\.For .* details call .*$
# 短信类型:  交易流水＿余额
# ['金额＿余额', '日期＿交易时间', '账户账号＿自己', 'other', 'other']
# ------------------------------------------------------
# ['other', 'other', 'other']
# ------------------------------------------------------
# 3909 ^The balance in your a\/c .* has been below the min\. balance requirement .* Please maintain balance in .* to avoid charges\.$
# 短信类型:  账号异常＿余额不足
# ['账户账号＿自己', 'other', '日期＿交易时间']
# ------------------------------------------------------
# sbipsg.pkl
# sbipsg
# 2084 ^INR .* credited to your A\/c No .* on .* through NEFT with UTR .* by .*$
# 短信类型:  交易流水＿转账
# ['金额＿转入', '账户账号＿自己', '日期＿交易时间', 'other', 'other']
# ------------------------------------------------------
# 2086 ^Your A\/c .* has been debited with INR .* on .* towards NEFT with UTR .* sent to .*$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转出', '日期＿交易时间', 'other', 'other']
# ------------------------------------------------------
# 2087 ^Your NEFT of Rs .* with UTR .* DTD .* credited to Beneficiary AC NO\. .* at .* on .* at .*$
# 短信类型:  交易流水＿转账
# ['金额＿转出', 'other', '日期＿交易时间', '账户账号＿他人', 'other', 'other', 'other']
# ------------------------------------------------------
# 2088 ^INR .* credited to your A\/c No .* on .* through NEFT with UTR .* by .* PVT LTD$
# 短信类型:  交易流水＿转账
# ['金额＿转入', '账户账号＿自己', '日期＿交易时间', 'other', 'other']
# ------------------------------------------------------
# [None, None, None]
# ------------------------------------------------------
# 2106 ^As per your request received at Contact Centre\,Card No ending with .* is Blocked\.Ticket .*$
# 短信类型:  账号异常＿卡号冻结
# ['银行卡号＿自己', 'other']
# ------------------------------------------------------
# [None, None, None]
# ------------------------------------------------------
# idbibk.pkl
# idbibk
# [None, None, None, None, None, None]
# ------------------------------------------------------
# [None, None, None, None]
# ------------------------------------------------------
# 882 ^Your a\/c no\. .* is debited for .* on .* and credited to a\/c no\. .* \(UPI Ref no .*$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转出', '日期＿交易时间', '账户账号＿他人', 'other']
# ------------------------------------------------------
# [None, None, None, None, None]
# ------------------------------------------------------
# 884 ^A\/c .* debited for INR .* ATM WDL\. A\/c Bal INR .* \(incl\. of uncleared chqs\) as of .* Call 1800226999 if card not used by you\.$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转出', '金额＿余额', '日期＿交易时间']
# ------------------------------------------------------
# 885 ^A\/c .* credited for .* through .* Banking\. A\/c Bal .* \(incl\. of uncleared chqs\) as of .* hrs\.$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转入', 'other', '金额＿余额', '日期＿交易时间']
# ------------------------------------------------------
# [None, None, None, None]
# ------------------------------------------------------
# 888 ^Dear Customer\, Your a\/c no\. .* is credited by .* on .* by a\/c linked to mobile .* \(IMPS Ref no .*$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转入', '日期＿交易时间', '账户账号＿他人', 'other']
# ------------------------------------------------------
# 890 ^A\/c .* debited for Rs .* thru Net\/Mob Bkg\. A\/c Bal Rs .* \(incl\. of uncleared chqs\) as of .* If not used by you\, call 18002001947$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转出', '金额＿余额', '日期＿交易时间']
# ------------------------------------------------------
# 892 ^Dear Customer\, Your a\/c no\. .* is debited for .* on .* and a\/c .* credited \(IMPS Ref no .*$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转出', '日期＿交易时间', '账户账号＿他人', 'other']
# ------------------------------------------------------
# 898 ^A\/c .* debited for Rs .* thru .* Bkg\. A\/c Bal Rs .* \(incl\. of uncleared chqs\) as of .* If not used by you\, call 18002001947$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转出', 'other', '金额＿余额', '日期＿交易时间']
# ------------------------------------------------------
# 900 ^Your IDBI Bk A\/c .* credited by Rs .* for Cash Deposit\. A\/c Bal\(sub to chq realisation\) Rs .* as of .* hrs\.$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转入', '金额＿余额', '日期＿交易时间']
# ------------------------------------------------------
# 901 ^Dear Customer\, The Available Balance in account .* is INR .* as of .* hrs$
# 短信类型:  交易流水＿余额
# ['账户账号＿自己', '金额＿余额', '日期＿交易时间']
# ------------------------------------------------------
# 902 ^The Monthly Avg bal\(MAB\) in your .* in .* was Rs\. .* and the deficit is Rs .* Restore MAB by .* to avoid penal charges\.$
# 短信类型:  信用卡＿还款提醒
# ['账户账号＿自己', 'other', 'other', '金额＿应还金额', '日期＿还款日期']
# ------------------------------------------------------
# 903 ^IDBI Bk A\/c\. .* credited Rs .* twds .* A\/c Bal Rs .* on .* hrs\.\(subject to chq realisation\)$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转入', 'other', '金额＿余额', '日期＿交易时间']
# ------------------------------------------------------
# 906 ^Dear Customer\, Amount of .* towards your unsuccessful .* transaction has been reversed\.$
# 短信类型:  账号异常＿扣款失败
# ['金额＿转出', 'other']
# ------------------------------------------------------
# 913 ^Your IDBI Bk A\/c\. .* debited Rs .* on .* Details\: .* A\/c Bal Rs .* as of .* hrs\.$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转出', '日期＿交易时间', 'other', '金额＿余额', 'other']
# ------------------------------------------------------
# 917 ^Rs .* has been spent on your Credit Card ending .* on .* at .* AVL bal .* call customer care 18004257600 if not used\.$
# 短信类型:  交易流水＿转账
# ['金额＿转出', '银行卡号＿自己', '日期＿交易时间', '机构＿交易平台', '金额＿余额']
# ------------------------------------------------------
# [None, None, None, None]
# ------------------------------------------------------
# [None, None, None, None, None, None, None]
# ------------------------------------------------------
# 921 ^Your chq .* for Rs\. .* from .* is Returned with Reason\-FUNDS INSUFFICIENT\.$
# 短信类型:  账号异常＿余额不足
# ['other', '金额＿转出', '账户账号＿自己']
# ------------------------------------------------------
# 925 ^Your a\/c no\. .* is credited for .* on .* for reversal of transaction \(UPI Ref no .*$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转入', '日期＿交易时间', 'other']
# ------------------------------------------------------
# 948 ^Penalty of Rs .* applied on your saving account .* for shortfall of MAB in .* having not restored MAB in .* after giving one month notice\.$
# 短信类型:  账号异常＿余额不足
# ['金额＿逾期罚金', '账户账号＿自己', '日期＿交易时间', 'other']
# ------------------------------------------------------
# 952 ^Your OTP for applying loan is .*$
# 短信类型:  贷前申请＿申请交互
# ['other']
# ------------------------------------------------------
# 959 ^Penal chgs of .* applied to Current A\/c .* Non\-maintenance of MAB\. MAB maintained for .* is .* as against the stipulated of .*$
# 短信类型:  账号异常＿余额不足
# ['金额＿逾期罚金', '账户账号＿自己', '日期＿交易时间', 'other', 'other']
# ------------------------------------------------------
# 961 ^Mini statement for Credit Card .* Total Due Rs\. .* Minimum Due Rs\. .* Payment Due Date\: .* Refer statement for more details$
# 短信类型:  信用卡＿还款提醒
# ['银行卡号＿自己', '金额＿应还金额', '金额＿最小应还金额', '日期＿还款日期']
# ------------------------------------------------------
# [None, None]
# ------------------------------------------------------
# 964 ^Your debit mandate for .* for Max .* is registered with us upto .* in your A\/c .* Customer Care for more details\.$
# 短信类型:  sms_other
# ['other', 'other', 'other', None]
# ------------------------------------------------------
# axicicib.pkl
# axicicib
# ['账户账号＿自己', '金额＿转出', '日期＿交易时间', 'other', None]
# ------------------------------------------------------
# 9351 ^Dear Customer\, Your a\/c no\. .* is debited for .* on .* and a\/c .* credited \(IMPS Ref no .*$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转出', '日期＿交易时间', '账户账号＿他人', 'other']
# ------------------------------------------------------
# 9352 ^Dear Customer\, Your a\/c no\. .* is credited by .* on .* by a\/c linked to mobile .* \(IMPS Ref no .*$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转入', '日期＿交易时间', '账户账号＿他人', 'other']
# ------------------------------------------------------
# 9353 ^You have initiated a txn of INR .* at .* on ICICI Bank Card .* OTP is .* DONT SHARE WITH ANYONE\. BANK NEVER CALLS TO VERIFY OTP\.$
# 短信类型:  交易流水＿转账
# ['金额＿转出', '机构＿交易平台', '银行卡号＿自己', 'other']
# ------------------------------------------------------
# 9354 ^Dear Customer\, your Account .* has been credited with INR .* on .* Info\: .* The Available Balance is INR .*$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转入', '日期＿交易时间', 'other', '金额＿余额']
# ------------------------------------------------------
# [None, None, None, None]
# ------------------------------------------------------
# 9356 ^Dear Customer\, acct .* has been debited for .* on .* towards linked .* UPI Ref no .*$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转出', '日期＿交易时间', '机构＿交易平台', 'other']
# ------------------------------------------------------
# ['账户账号＿自己', '金额＿转出', None, None]
# ------------------------------------------------------
# 9358 ^Dear Customer\, acct .* is credited with .* on .* from .* UPI Ref no .*$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转入', '日期＿交易时间', 'other', 'other']
# ------------------------------------------------------
# 9359 ^Dear Customer\, txn of INR .* using Credit Card .* done at .* on .* Avbl Cr lmt\:INR .* For dispute\,call 04033667777\.$
# 短信类型:  交易流水＿转账
# ['金额＿转出', '银行卡号＿自己', '机构＿交易平台', '日期＿交易时间', '金额＿信用额度']
# ------------------------------------------------------
# 9360 ^You have initiated a txn of INR .* at .* on ICICI Bank Card .* OTP is .* DONT SHARE IT WITH ANYONE\. BANK NEVER CALLS TO VERIFY OTP\.$
# 短信类型:  交易流水＿转账
# ['金额＿转出', '机构＿交易平台', '银行卡号＿自己', 'other']
# ------------------------------------------------------
# [None, None, None]
# ------------------------------------------------------
# 9363 ^Dear Customer\, you have a collect request for .* from vpa .* Login to your mobile application to authorise the transaction\.$
# 短信类型:  交易流水＿转账
# ['金额＿转出', '机构＿交易平台']
# ------------------------------------------------------
# [None, None, None, None]
# ------------------------------------------------------
# 9365 ^Dear Customer\, stmt for Credit Card .* has been sent to .* Total amt of Rs\. .* or Min\. amt of Rs\. .* is due by .*$
# 短信类型:  信用卡＿还款提醒
# ['银行卡号＿自己', 'other', '金额＿应还金额', '金额＿最小应还金额', '日期＿还款日期']
# ------------------------------------------------------
# 9368 ^Cash deposit transaction of Rs\. .* for Account .* has been completed on .* vide transaction reference .*$
# 短信类型:  交易流水＿转账
# ['金额＿转出', '账户账号＿自己', '日期＿交易时间', 'other']
# ------------------------------------------------------
# 9373 ^Dear Customer\, Total Amount of INR .* and Minimum Amount of INR .* is due by .* on your Credit Card .* Please ignore if already paid\.$
# 短信类型:  信用卡＿还款提醒
# ['金额＿应还金额', '金额＿最小应还金额', '日期＿还款日期', '银行卡号＿自己']
# ------------------------------------------------------
# 9374 ^Dear Customer\, the Available Balance for your ICICI Bank Account .* is INR .* as on .*$
# 短信类型:  交易流水＿余额
# ['账户账号＿自己', '金额＿余额', '日期＿交易时间']
# ------------------------------------------------------
# 9375 ^Dear Customer\, acct .* has been debited for .* on .* and Acct .* is credited\. UPI Ref no .*$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转出', '日期＿交易时间', '账户账号＿他人', 'other']
# ------------------------------------------------------
# 9376 ^Dear Customer\,ECS transaction of Rs\. .* towards .* from Account .* has been returned due to reason \- .* on .*$
# 短信类型:  账号异常＿余额不足
# ['金额＿转出', '机构＿交易平台', '账户账号＿自己', 'other', '日期＿交易时间']
# ------------------------------------------------------
# 9377 ^Dear Customer\, You have a collect request for .* from .* To authorise\, login to iMobile app or click bit\.ly\/UPI\-Collectrequest$
# 短信类型:  交易流水＿转账
# ['金额＿转入', '机构＿交易平台']
# ------------------------------------------------------
# 9378 ^Dear Customer\,Your transaction of INR .* on Credit Card .* declined due to insufficient limit\.Limit available\: INR .*$
# 短信类型:  账号异常＿扣款失败
# ['金额＿转出', '银行卡号＿自己', '金额＿信用额度']
# ------------------------------------------------------
# 9380 ^Dear Customer\, .* of Rs\. .* to Account .* has been initiated through INSTA Banking\. Please quote Reference .* at the counter\. You will get another SMS confirming the completion of transaction\. Request for a hard copy receipt\, if you do not receive the confirmation SMS\.$
# 短信类型:  交易流水＿转账
# ['other', '金额＿转入', 'other', 'other']
# ------------------------------------------------------
# 9385 ^Dear Customer\,EMI of Rs\. .* towards ICICI Bank Loan Account .* is due on .*$
# 短信类型:  贷后提醒＿到期提醒
# ['金额＿应还金额', '账号＿借款编号', '日期＿还款日期']
# ------------------------------------------------------
# 9386 ^Dear Customer\, your Account .* has been credited with salary of INR .* on .* Info\: .* The Available Balance is INR .*$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿薪资', '日期＿交易时间', 'other', '金额＿余额']
# ------------------------------------------------------
# 9389 ^Dear Customer\, Refund of INR .* from .* has been credited to your Credit Card .* on .* For details\, please call our Customer Care\.$
# 短信类型:  交易流水＿转账
# ['金额＿转入', 'other', '银行卡号＿自己', '日期＿交易时间']
# ------------------------------------------------------
# 9393 ^Payment overdue on your Credit Card .* is affecting your credit history with CIBIL\. This may prevent you from getting a loan or a credit card from any bank in future\. To avoid further damage to your credit .* pay the total amt due .* or the min amt .* imm\.Pl ignore if .*$
# 短信类型:  信用卡＿还款提醒
# ['银行卡号＿自己', 'other', '金额＿应还金额', '金额＿最小应还金额', 'other']
# ------------------------------------------------------
# [None, None, None]
# ------------------------------------------------------
# 9402 ^Dear Customer\, Your fund transfer request for .* on .* could not be processed\. Please try later\. \(IMPS Ref no\. .*$
# 短信类型:  账号异常＿扣款失败
# ['金额＿转出', '日期＿交易时间', 'other']
# ------------------------------------------------------
# [None, None]
# ------------------------------------------------------
# [None, None, None, None]
# ------------------------------------------------------
# 9408 ^Dear Customer\, you have made a payment of Rs\. .* to ARTHASHASTRA FINTECH PRIVATE LIMITED vide eazypay reference ID .*$
# 短信类型:  交易流水＿转账
# ['金额＿转出', 'other']
# ------------------------------------------------------
# 9409 ^Dear Customer\, .* Amount Due on Credit Card .* is INR .* Amt will be debited from your bank account on or before .* Pls ignore if paid\.$
# 短信类型:  信用卡＿还款提醒
# ['other', '银行卡号＿自己', '金额＿应还金额', '日期＿还款日期']
# ------------------------------------------------------
# 9411 ^You have initiated a txn of INR .* at .* on ICICI Bank Card 4005\. OTP is .* DONT SHARE IT WITH ANYONE\. BANK NEVER CALLS TO VERIFY OTP\.$
# 短信类型:  交易流水＿转账
# ['金额＿转出', '机构＿交易平台', 'other']
# ------------------------------------------------------
# 9412 ^Dispatched\: Dear Customer\, Credit Card Statement for your Account .* has been sent by .* AWB .* on .* Track status at bit\.ly\/2prKKli\.$
# 短信类型:  sms_other
# ['账户账号＿自己', '机构＿交易平台', 'other', '日期＿交易时间']
# ------------------------------------------------------
# icicib.pkl
# icicib
# [None, None, None, None]
# ------------------------------------------------------
# ['账户账号＿自己', '金额＿转出', '日期＿交易时间', 'other', None]
# ------------------------------------------------------
# 11107 ^Dear Customer\, acct .* has been debited for .* on .* towards linked .* UPI Ref no .*$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转出', '日期＿交易时间', 'other', 'other']
# ------------------------------------------------------
# 11108 ^Dear Customer\, Your a\/c no\. .* is credited by .* on .* by a\/c linked to mobile .* \(IMPS Ref no .*$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转入', '日期＿交易时间', '账户账号＿他人', 'other']
# ------------------------------------------------------
# ['账户账号＿自己', '金额＿转出', None, None]
# ------------------------------------------------------
# 11110 ^Dear Customer\, your Account .* has been credited with INR .* on .* Info\: .* The Available Balance is INR .*$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转入', '日期＿交易时间', 'other', '金额＿余额']
# ------------------------------------------------------
# 11112 ^Dear Customer\, Your a\/c no\. .* is debited for .* on .* and a\/c .* credited \(IMPS Ref no .*$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转出', '日期＿交易时间', '账户账号＿他人', 'other']
# ------------------------------------------------------
# 11113 ^Dear Customer\, txn of INR .* using Credit Card .* done at .* on .* Avbl Cr lmt\:INR .* For dispute\,call 04033667777\.$
# 短信类型:  交易流水＿转账
# ['金额＿转出', '银行卡号＿自己', '机构＿交易平台', '日期＿交易时间', '金额＿信用额度']
# ------------------------------------------------------
# 11114 ^You have initiated a txn of INR .* at .* on ICICI Bank Card .* OTP is .* DONT SHARE WITH ANYONE\. BANK NEVER CALLS TO VERIFY OTP\.$
# 短信类型:  交易流水＿转账
# ['金额＿转出', '机构＿交易平台', '银行卡号＿自己', 'other']
# ------------------------------------------------------
# 11115 ^You have initiated a txn of INR .* at .* on ICICI Bank Card .* OTP is .* DONT SHARE IT WITH ANYONE\. BANK NEVER CALLS TO VERIFY OTP\.$
# 短信类型:  交易流水＿转账
# ['金额＿转出', '机构＿交易平台', '银行卡号＿自己', 'other']
# ------------------------------------------------------
# [None, None, None, None, None]
# ------------------------------------------------------
# 11118 ^Dear Customer\, acct .* has been debited for .* on .* and Acct .* is credited\. UPI Ref no .*$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转出', '日期＿交易时间', '账户账号＿他人', 'other']
# ------------------------------------------------------
# 11119 ^Dear Customer\, Purchase of INR .* has been made on Debit Card linked to Acct .* on .* Info\: .* The Available Balance is INR .*$
# 短信类型:  交易流水＿转账
# ['金额＿转出', '账户账号＿自己', '日期＿交易时间', 'other', '金额＿余额']
# ------------------------------------------------------
# ['金额＿转出', None, None]
# ------------------------------------------------------
# 11121 ^Dear Customer\, stmt for Credit Card .* has been sent to .* Total amt of Rs\. .* or Min\. amt of Rs\. .* is due by .*$
# 短信类型:  信用卡＿还款提醒
# ['银行卡号＿自己', 'other', '金额＿应还金额', '金额＿最小应还金额', '日期＿交易时间']
# ------------------------------------------------------
# 11123 ^Dear Customer\, the Available Balance for your ICICI Bank Account .* is INR .* as on .*$
# 短信类型:  交易流水＿余额
# ['账户账号＿自己', '金额＿余额', '日期＿交易时间']
# ------------------------------------------------------
# 11124 ^Dear Customer\, cash deposit of Rs\. .* to Account .* has been initiated through INSTA Banking\. Please quote Reference .* at the counter\. You will get another SMS confirming the completion of transaction\. Request for a hard copy receipt\, if you do not receive the confirmation SMS\.$
# 短信类型:  交易流水＿转账
# ['金额＿转入', '账户账号＿自己', 'other']
# ------------------------------------------------------
# 11125 ^Dear Customer\, Your a\/c no\. .* is credited by .* on .* by a\/c .* \(IMPS Ref no .*$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转入', '日期＿交易时间', 'other', 'other']
# ------------------------------------------------------
# 11129 ^To make online payment of Rs\. .* you will need a One Time Password\(OTP\)\. NEVER SHARE THE OTP WITH ANYONE\. BANK NEVER CALLS TO VERIFY IT\. The OTP is .*$
# 短信类型:  交易流水＿转账
# ['金额＿转出', 'other']
# ------------------------------------------------------
# 11130 ^Dear Customer\, Total Amount of INR .* and Minimum Amount of INR .* is due by .* on your Credit Card .* Please ignore if already paid\.$
# 短信类型:  信用卡＿还款提醒
# ['金额＿应还金额', '金额＿最小应还金额', '日期＿还款日期', '银行卡号＿自己']
# ------------------------------------------------------
# 11133 ^Dear Customer\, you have a collect request for .* from vpa .* Login to your mobile application to authorise the transaction\.$
# 短信类型:  交易流水＿转账
# ['金额＿应还金额', 'other']
# ------------------------------------------------------
# 11135 ^Dear Customer\, your Account .* has been credited with salary of INR .* on .* Info\: .* The Available Balance is INR .*$
# 短信类型:  交易流水＿余额
# ['账户账号＿自己', '金额＿薪资', '日期＿交易时间', 'other', '金额＿余额']
# ------------------------------------------------------
# 11138 ^Dear Customer\, Your fund transfer request for .* on .* could not be processed\. Please try later\. \(IMPS Ref no\. .*$
# 短信类型:  账号异常＿扣款失败
# ['金额＿转出', '日期＿交易时间', 'other']
# ------------------------------------------------------
# 11141 ^Dear Customer\, Refund of INR .* from .* has been credited to your Credit Card .* on .* For details\, please call our Customer Care\.$
# 短信类型:  交易流水＿转账
# ['金额＿转入', 'other', '银行卡号＿自己', '日期＿交易时间']
# ------------------------------------------------------
# 11144 ^Dear Customer\,ECS transaction of Rs\. .* towards .* from Account .* has been returned due to reason \- INSUFFICIENT .* on .*$
# 短信类型:  账号异常＿余额不足
# ['金额＿转出', '机构＿交易平台', '账户账号＿自己', 'other', '日期＿交易时间']
# ------------------------------------------------------
# 11145 ^Cash deposit transaction of Rs\. .* for Account .* has been completed on .* vide transaction reference .*$
# 短信类型:  交易流水＿转账
# ['金额＿转入', '账户账号＿自己', '日期＿交易时间', 'other']
# ------------------------------------------------------
# 11156 ^Dear Customer\, Your fund transfer request for .* on .* is declined as beneficiary account no\. or IFSC code is invalid \(IMPS Ref no\. .*$
# 短信类型:  交易流水＿转账
# ['金额＿转出', '日期＿交易时间', 'other']
# ------------------------------------------------------
# [None, None, None, None, None]
# ------------------------------------------------------
# 11160 ^Dear Customer\, you have made a payment of Rs\. .* to ARTHASHASTRA FINTECH PRIVATE LIMITED vide eazypay reference ID .*$
# 短信类型:  交易流水＿转账
# ['金额＿转出', 'other']
# ------------------------------------------------------
# [None, None, None, None]
# ------------------------------------------------------
# 11163 ^Dear Customer\, Total Amount Due on Credit Card .* is INR .* Amt will be debited from your bank account on or before .* Pls ignore if paid\.$
# 短信类型:  信用卡＿还款提醒
# ['银行卡号＿自己', '金额＿应还金额', '日期＿还款日期']
# ------------------------------------------------------
# 11166 ^Payment overdue on your Credit Card .* is affecting your credit history with CIBIL\. This may prevent you from getting a loan or a credit card from any bank in future\. To avoid further damage to your credit .* pay the total amt due .* or the min amt .* imm\.Pl ignore if .*$
# 短信类型:  信用卡＿逾期警告
# ['银行卡号＿自己', 'other', '金额＿应还金额', '金额＿最小应还金额', 'other']
# ------------------------------------------------------
# ['账户账号＿自己', None, None, None, None]
# ------------------------------------------------------
# [None, None, None, None]
# ------------------------------------------------------
# 11172 ^NEFT Transaction with reference number .* for .* has been credited to the beneficiary account on .* at .*$
# 短信类型:  交易流水＿转账
# ['other', '金额＿转入', '日期＿交易时间', 'other']
# ------------------------------------------------------
# 11176 ^Dear Customer\, Cheque .* for INR .* issued from your Account .* has returned on .* due to reason \- .*$
# 短信类型:  账号异常＿扣款失败
# ['other', '金额＿转出', '账户账号＿自己', '日期＿交易时间', 'other']
# ------------------------------------------------------
# 11177 ^Dear Customer\,transaction of INR .* on Credit Card .* has declined due to incorrect CVV or expiry date of the card\. Pls retry with correct details\.$
# 短信类型:  账号异常＿扣款失败
# ['金额＿转出', '银行卡号＿自己']
# ------------------------------------------------------
# [None, None, None, None]
# ------------------------------------------------------
# 11181 ^You have initiated a txn of USD .* at .* on ICICI Bank Card .* OTP is .* DONT SHARE WITH ANYONE\. BANK NEVER CALLS TO VERIFY OTP\.$
# 短信类型:  交易流水＿转账
# ['金额＿转出', 'other', '银行卡号＿自己', 'other']
# ------------------------------------------------------
# [None]
# ------------------------------------------------------
# 11187 ^Dear Customer\, Total Amount Due of Rs\. .* on Credit Card .* was due on .* Please pay the Minimum Amount Due of Rs\. .* immediately for uninterrupted usage of the card\. For payment options\, visit www\.icicibank\.com\/pay \. Please ignore if already paid\.$
# 短信类型:  信用卡＿逾期警告
# ['金额＿应还金额', '银行卡号＿自己', '日期＿还款日期', '金额＿最小应还金额']
# ------------------------------------------------------
# 11188 ^Dear Customer\, Payment of your ICICI Bank Credit card .* is still pending\. We send this message\, as we are not able to reach you\. Pls pay the total overdue of .* imm\, and avoid adverse impact on your track record with credit bureaus\. For payment pickup pl call us at .* Ignore if already paid\.$
# 短信类型:  信用卡＿逾期警告
# ['银行卡号＿自己', '金额＿应还金额', 'other']
# ------------------------------------------------------
# 11191 ^Reference .* for Cash withdrawal of Rs\. .* from Acct .* has been initiated through INSTA Banking\. Pls quote this ref no\. to the Cash Teller\.$
# 短信类型:  交易流水＿转账
# ['other', '金额＿转出', '账户账号＿自己']
# ------------------------------------------------------
# 11193 ^Dear Customer\, Payment of INR .* has been received towards your ICICI Bank Credit Card .* on .* through NEFT\. Thank you\.$
# 短信类型:  交易流水＿转账
# ['金额＿转出', '银行卡号＿自己', '日期＿交易时间']
# ------------------------------------------------------
# 11194 ^.* Dear Customer\,As requested by you\,your transaction of INR .* on ICICI Bank Credit Card .* has been converted into .* EMIs on .*$
# 短信类型:  交易流水＿转账
# ['other', '金额＿转出', '银行卡号＿自己', 'other', '日期＿交易时间']
# ------------------------------------------------------
# [None, None, None, None]
# ------------------------------------------------------
# [None, None, None, None]
# ------------------------------------------------------
# [None, None, None, None, None]
# ------------------------------------------------------
# 11216 ^You have initiated a txn of .* at Skrill .* on ICICI Bank Card .* OTP is .* DONT SHARE WITH ANYONE\. BANK NEVER CALLS TO VERIFY OTP\.$
# 短信类型:  交易流水＿转账
# ['金额＿转出', 'other', '银行卡号＿自己', 'other']
# ------------------------------------------------------
# [None, None, None, None]
# ------------------------------------------------------
# 11221 ^Dear Customer\, The credit limit for your ICICI Bank Credit Card .* has been changed from INR .* to INR .* on .*$
# 短信类型:  交易流水＿余额
# ['银行卡号＿自己', 'other', '金额＿信用额度', '日期＿交易时间']
# ------------------------------------------------------
# 11228 ^Dear Customer\,your Account .* has been credited with INR .* on .* Info\. Aadhaar Payment Bridge System APBS\/IOC Ref .*$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转入', '日期＿交易时间', 'other']
# ------------------------------------------------------
# 11234 ^\(1\/2\) Dear Customer\, your Account .* has been credited with INR .* on .* Info\: .* The Available Balance is INR$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转入', '日期＿交易时间', 'other']
# ------------------------------------------------------
# 11240 ^To recharge your .* for Rs\. .* you will need an OTP\. NEVER SHARE .* WITH ANYONE\. BANK NEVER CALLS TO VERIFY IT\. The OTP is .*$
# 短信类型:  交易流水＿转账
# ['other', '金额＿转出', 'other', 'other']
# ------------------------------------------------------
# ['other', 'other']
# ------------------------------------------------------
# ['other', 'other', 'other']
# ------------------------------------------------------
# ['other', 'other', 'other', 'other']
# ------------------------------------------------------
# ['other', 'other', 'other', None]
# ------------------------------------------------------
# [None, None, None, None, None, None]
# ------------------------------------------------------
# 11258 ^Dear Customer\, Overdraft .* for .* against Deposit\(s\) with ICICI Bank has been .* on .* For dtls\, pls call our .*$
# 短信类型:  账号异常＿扣款失败
# ['交易流水＿转账', '金额＿转出', 'other', '日期＿交易时间', 'other']
# ------------------------------------------------------
# unionb.pkl
# unionb
# ['账户账号＿自己', None, None, None, None]
# ------------------------------------------------------
# [None, None, None, None, None, None]
# ------------------------------------------------------
# [None, None, None, None, None]
# ------------------------------------------------------
# 5108 ^Your a\/c no\. .* is credited for .* on .* by a\/c linked to mobile .* \(IMPS Ref no .*$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转入', '日期＿交易时间', '账户账号＿他人', 'other']
# ------------------------------------------------------
# [None, None, None, None, None, None]
# ------------------------------------------------------
# [None, None, None, None]
# ------------------------------------------------------
# 5112 ^Avl Bal in Your A\/c .* is INR Cr .* as on .* IST \.$
# 短信类型:  交易流水＿余额
# ['账户账号＿自己', '金额＿余额', '日期＿交易时间']
# ------------------------------------------------------
# [None, None, None, None, None, None]
# ------------------------------------------------------
# 5123 ^Your .* A\/c .* is debited .* Rs\. .* on .* for .* a\/c credited vide UTR no\. .*$
# 短信类型:  交易流水＿转账
# ['other', '账户账号＿自己', 'other', '金额＿转出', '日期＿交易时间', '机构＿交易平台', 'other']
# ------------------------------------------------------
# 5128 ^Transaction for .* to .* has been completed successfully with reference id .*$
# 短信类型:  交易流水＿转账
# ['金额＿转出', 'other', 'other']
# ------------------------------------------------------
# 5133 ^Cheque .* is Lodged through clearing in your .* A\/c .* to credit Rs\. .* on .*$
# 短信类型:  信用卡＿还款提醒
# ['other', 'other', '账户账号＿自己', '金额＿应还金额', '日期＿还款日期']
# ------------------------------------------------------
# 5134 ^Avl Bal in Your A\/c .* is INR Dr .* as on .* IST \.$
# 短信类型:  交易流水＿余额
# ['账户账号＿自己', '金额＿余额', '日期＿交易时间']
# ------------------------------------------------------
# 5138 ^OTP for your txn for Rs .* towards PMT is .* Cross check OTP Ref Id .* on screen\. Do not share OTP with anyone\. Union Bank\.$
# 短信类型:  交易流水＿转账
# ['金额＿转出', 'other', 'other']
# ------------------------------------------------------
# 5140 ^Dear Customer\,Your SB Account No .* is credited by LPG subsidy Rs .* on .* Avbl Bal .* APPLY DEBITCARD ONLINE .*$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转入', '日期＿交易时间', '金额＿余额', 'other']
# ------------------------------------------------------
# ['账户账号＿自己', None, None, None]
# ------------------------------------------------------
# 5147 ^Dear Customer\,Your SB Account No .* is credited by LPG subsidy Rs .* on .* Avbl Bal .* DISCOUNT CODE FNP15UBI FOR FERNSNPETALS$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转入', '日期＿交易时间', '金额＿余额']
# ------------------------------------------------------
# [None, None, None, None, None, None, None, None]
# ------------------------------------------------------
# 5150 ^Dear customer\,perhaps you have missed payment of your installment of .* in your A\/c .* with Union Bank\.Kindly ignore if already paid$
# 短信类型:  sms_other
# ['other', 'other']
# ------------------------------------------------------
# 5151 ^Dear Customer\,Please make Payment of Rs\. .* due in your A\/c .* with Union Bank at Branch .* immediately\.Kindly Ignore .*$
# 短信类型:  信用卡＿逾期警告
# ['金额＿应还金额', '账户账号＿自己', 'other', 'other']
# ------------------------------------------------------
# 5153 ^Bank is replacing your existing magstripe debit card with EMV card\. Please collect your new debit card from the branch .* as old card will be blocked on .*$
# 短信类型:  账号异常＿卡号冻结
# ['other', '日期＿交易时间']
# ------------------------------------------------------
# 5154 ^Your a\/c no\. .* is debited for .* on .* and a\/c .* credited \(IMPS Ref no .*$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转出', '日期＿交易时间', '账户账号＿他人', 'other']
# ------------------------------------------------------
# 5156 ^Your .* A\/c .* in .* Clg\. Credited Rs\. .* on .* by Clearing\. Bal is Rs\. .* Subject To Chq .* CODE FNP15UBI FOR FERNSNPETALS$
# 短信类型:  交易流水＿转账
# ['other', '账户账号＿自己', '机构＿交易平台', '金额＿转入', '日期＿交易时间', '金额＿余额', 'other']
# ------------------------------------------------------
# 5157 ^Your .* claim for .* \/\- dated .* lodged successfully\. Reference no\. .*$
# 短信类型:  交易流水＿转账
# ['other', '金额＿转出', '日期＿交易时间', 'other']
# ------------------------------------------------------
# ['other', 'other', 'other', 'other']
# ------------------------------------------------------
# ['other', 'other']
# ------------------------------------------------------
# scisms.pkl
# scisms
# 11664 ^Dear SBI UPI User\, your account is debited INR .* on Date .* by UPI Ref No .* YONO \@ www\.yonosbi\.com$
# 短信类型:  交易流水＿转账
# ['金额＿转出', '日期＿交易时间', 'other']
# ------------------------------------------------------
# [None, None, None, None]
# ------------------------------------------------------
# 11666 ^Your a\/c no\. .* is credited by .* on .* by a\/c linked to mobile .* \(IMPS Ref no .* Download YONO \@ www\.yonosbi\.com\.$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转入', '日期＿交易时间', '账户账号＿他人', 'other']
# ------------------------------------------------------
# [None, None, None, None]
# ------------------------------------------------------
# [None]
# ------------------------------------------------------
# 11669 ^Your A\/C .* Credited INR .* on .* \-Deposit of Cash at .* ATM\. A\/c Balance INR .*$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转入', '日期＿交易时间', 'other', '金额＿余额']
# ------------------------------------------------------
# 11670 ^Your A\/C .* has a credit by Transfer of Rs .* on .* Avl Bal Rs .* Download YONO \@ www\.yonosbi\.com$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转出', '日期＿交易时间', '金额＿余额']
# ------------------------------------------------------
# 11671 ^Your A\/C .* Credited INR .* on .* \-Deposit by transfer from .* A\/C Bal INR .*$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转入', '日期＿交易时间', '机构＿交易平台', '金额＿余额']
# ------------------------------------------------------
# 11672 ^Dear customer\,your transaction at .* has been declined due to insufficient fund in your account\.$
# 短信类型:  账号异常＿余额不足
# ['other']
# ------------------------------------------------------
# 11673 ^Your a\/c no\. .* is debited for .* on .* and a\/c .* credited \(IMPS Ref no .* Download YONO \@ www\.yonosbi\.com\.$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转出', '日期＿交易时间', '账户账号＿他人', 'other']
# ------------------------------------------------------
# 11674 ^INR .* credited to your A\/c No .* on .* through NEFT with UTR .* by .*$
# 短信类型:  交易流水＿转账
# ['金额＿转入', '账户账号＿自己', '日期＿交易时间', 'other', 'other']
# ------------------------------------------------------
# 11675 ^Your A\/C .* Debited INR .* on .* \-Transferred to INVESTMENT INTERMEDI\. A\/C Balance INR .*$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转出', '日期＿交易时间', '金额＿余额']
# ------------------------------------------------------
# 11676 ^Your A\/C .* Credited INR .* on .* \-Deposited by Cash by .* \. A\/C Bal INR .*$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转入', '日期＿交易时间', 'other', '金额＿余额']
# ------------------------------------------------------
# 11677 ^Your A\/C .* has a debit by transfer of Rs .* on .* Avl Bal Rs .*$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转出', '日期＿交易时间', '金额＿余额']
# ------------------------------------------------------
# [None, None, None]
# ------------------------------------------------------
# 11679 ^Thank you for using State Bank Internet Banking\. Reference No\. for transaction of Rs\. .* from A\/c ending .* on .* at .* is .* Download YONO \@ www\.yonosbi\.com$
# 短信类型:  交易流水＿转账
# ['金额＿转出', '账户账号＿自己', '日期＿还款日期', 'other', 'other']
# ------------------------------------------------------
# 11680 ^Dear SBI UPI User\, you have received .* of INR .* from .* on Date .* \(Ref No .*$
# 短信类型:  交易流水＿转账
# ['other', '金额＿转入', 'other', '日期＿交易时间', 'other']
# ------------------------------------------------------
# 11681 ^Dear SBI UPI User\, Your a\/c no\. .* is credited with INR .* on .* for reversal of transaction \(UPI Ref no .*$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转入', '日期＿交易时间', 'other']
# ------------------------------------------------------
# 11682 ^Your A\/C .* Debited INR .* on .* \-Transferred to .* A\/C Balance INR .*$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转出', '日期＿交易时间', 'other', '金额＿余额']
# ------------------------------------------------------
# ['金额＿转入', '账户账号＿自己', None]
# ------------------------------------------------------
# 11684 ^Hold for INR .* created in your AC .* on .* Download YONO \@ www\.yonosbi\.com$
# 短信类型:  交易流水＿转账
# ['金额＿转入', '账户账号＿自己', '日期＿交易时间']
# ------------------------------------------------------
# ['账户账号＿自己', '金额＿转入', '日期＿交易时间', 'other', None]
# ------------------------------------------------------
# 11689 ^Mandate Registration\- UMRN .* for Rs .* issued to .* received today\.In case of any issues pls contact branch$
# 短信类型:  交易流水＿转账
# ['other', '金额＿转出', 'other']
# ------------------------------------------------------
# 11690 ^INR .* credited to your A\/c No .* on .* through NEFT with UTR .* by .* PVT LTD$
# 短信类型:  交易流水＿转账
# ['金额＿转入', '账户账号＿自己', '日期＿交易时间', 'other', 'other']
# ------------------------------------------------------
# 11691 ^Your NEFT of Rs .* with UTR .* DTD .* credited to Beneficiary AC NO\. .* at .* on .* at .*$
# 短信类型:  交易流水＿转账
# ['金额＿转入', 'other', '日期＿交易时间', '账户账号＿他人', 'other', 'other', 'other']
# ------------------------------------------------------
# ['账户账号＿自己', '金额＿转出', None, None]
# ------------------------------------------------------
# 11693 ^INR .* credited to your A\/c No .* on .* through NEFT with UTR .* by SMARTCOIN FINANCIALS$
# 短信类型:  交易流水＿转账
# ['金额＿转入', '账户账号＿自己', '日期＿交易时间', 'other']
# ------------------------------------------------------
# 11694 ^Dear customer\,your txn at .* declined due to incorrect PIN\.Please enter .* correct PIN\.$
# 短信类型:  账号异常＿扣款失败
# ['other', 'other']
# ------------------------------------------------------
# [None, None, None, None]
# ------------------------------------------------------
# 11699 ^Your A\/C .* has a credit by Cheque of Rs .* on .* Avl Bal Rs .* Download YONO \@ www\.yonosbi\.com$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转入', '日期＿交易时间', '金额＿余额']
# ------------------------------------------------------
# 11700 ^Dear customer\,your txn at ATM .* declined as your daily withdrawal limit will exceed with the requested amount\.$
# 短信类型:  账号异常＿扣款失败
# ['other']
# ------------------------------------------------------
# 11702 ^Your A\/C .* has a Cash withdrawal of Rs .* on .* \. Avl Bal Rs .* Download YONO \@ www\.yonosbi\.com$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转出', '日期＿交易时间', '金额＿余额']
# ------------------------------------------------------
# 11705 ^Your AC .* Debited INR .* on .* \-Towards cash payment by Cheque .* Avl Bal INR .*$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转出', '日期＿交易时间', 'other', '金额＿余额']
# ------------------------------------------------------
# 11708 ^PFMS generated payment\/DBT of Rs\. .* credited to your .* on .*$
# 短信类型:  交易流水＿转账
# ['金额＿转入', '账户账号＿自己', '日期＿交易时间']
# ------------------------------------------------------
# [None, None, None]
# ------------------------------------------------------
# 11710 ^Chq No .* for INR .* issued frm AC .* dishonoured\.Chrg INR .* deducted\.$
# 短信类型:  sms_other
# ['other', 'other', 'other', 'other']
# ------------------------------------------------------
# ...
# ------------------------------------------------------
# 2912 ^Dear Customer cash withdrawal limit on your Credit Card ending .* has been disabled as per internal guidelines \-T\&C apply$
# 短信类型:  账号异常＿卡号冻结
# ['银行卡号＿自己']
# ------------------------------------------------------
# [None, None, None, None, None]
# ------------------------------------------------------
# 2920 ^Dear Customer\, We acknowledge receipt of Payment by Cash via Receipt No\. .* for Rs\. .* \/\- towards Loan A\/c No\. .* \.$
# 短信类型:  交易流水＿转账
# ['other', '金额＿转出', 'other']
# ------------------------------------------------------
# [None, None]
# ------------------------------------------------------
# [None, None, None]
# ------------------------------------------------------
# 2935 ^Dear Customer\,Payments on your HDFC Bank \-Consumer Durable Life Style .* are overdue\.Please pay .* towards pending EMI\.Timely payments will help you avoid levy of fees and charges\.Check your score at https\:\/\/goo\.gl\/tM76D4\.Please ignore if you have already paid$
# 短信类型:  信用卡＿还款提醒
# ['other', '金额＿应还金额']
# ------------------------------------------------------
# 2939 ^Payment of .* on your HDFC Bank Card .* has been declined\. This type of transaction is not allowed as per regulatory guidelines\.$
# 短信类型:  账号异常＿扣款失败
# ['金额＿转出', '银行卡号＿自己']
# ------------------------------------------------------
# 2947 ^Copy of RC Book\, Invoice\, Ins Policy for vehicle loan .* with HDFC Bank has not been submitted yet\.Pls submit at the earliest at any Loan Service centre\.$
# 短信类型:  贷前申请＿申请交互
# ['账号＿借款编号']
# ------------------------------------------------------
# 2948 ^Dear HdfcBank Cardmember\, Lien Marked for .* on .* in acct ending .* due to autopay return for card .*$
# 短信类型:  信用卡＿还款提醒
# ['金额＿应还金额', '日期＿还款日期', '账户账号＿自己', '账户账号＿他人']
# ------------------------------------------------------
# 2949 ^Dear cardmember\, Total outstanding on ur HDFCBank card ending .* is .* Estmt alone is sent to ur Email ID for .* Pls refer the same for details$
# 短信类型:  信用卡＿还款提醒
# ['银行卡号＿自己', '金额＿余额', '日期＿还款日期']
# ------------------------------------------------------
# [None, None]
# ------------------------------------------------------
# 2953 ^Dear Customer\, Your ACH mandate form submitted towards repayment of your Loan No\. .* with HDFC Bank has been returned by .* BANK due to \" .* \" \.Request you to access the fresh ACH Mandate form from our website link http\:\/\/www\.hdfcbank\.com\/assets\/pdf\/ACH\-Mandate\-Format\.pdf and submit at our Retail Loan Service Centre http\:\/\/bit\.ly\/29z1UV4 at the earliest for seamless loan repayment\.$
# 短信类型:  贷前申请＿审核拒绝
# ['other', 'other', 'other']
# ------------------------------------------------------
# [None]
# ------------------------------------------------------
# 2957 ^Dear Customer\, Your bank has returned the .* EMI of .* thru ECS Debit for Loan No .* reason ECS MANDATE NOT .* Please visit your Bank Branch urgently for registering the ECS Mandate\.$
# 短信类型:  贷前申请＿审核拒绝
# ['日期＿交易时间', '金额＿放款金额', '账号＿借款编号', 'other']
# ------------------------------------------------------
# 2958 ^Your current payment record is\: May OK Jun OK Jul OK Aug .* XX \.You have missed a payment for your HDFCBank CreditCard ending in .* Revert to your non\-defaulting status by clicking https\:\/\/goo\.gl\/pE0b71 if you are a HDFC customer or https\:\/\/goo\.gl\/yvUayf for other banks and making a payment of Rs\. .*$
# 短信类型:  信用卡＿还款提醒
# [None, '银行卡号＿自己', '金额＿应还金额']
# ------------------------------------------------------
# 2959 ^Your current payment record is\: Jun OK Jul OK Aug .* XX \.You have missed a payment for your HDFCBank CreditCard ending in .* Revert to your non\-defaulting status by clicking https\:\/\/goo\.gl\/pE0b71 if you are a HDFC customer or https\:\/\/goo\.gl\/yvUayf for other banks and making a payment of Rs\. .*$
# 短信类型:  信用卡＿还款提醒
# ['other', '银行卡号＿自己', '金额＿应还金额']
# ------------------------------------------------------
# albank.pkl
# albank
# 2270 ^Your a\/c no\. .* is debited by .* on .* and credited to .* Ref no .*$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转出', '日期＿交易时间', 'other', 'other']
# ------------------------------------------------------
# 2271 ^Your A\/c .* is debited through ATM Card by Rs\. .* Total Bal \: Rs\. .* CR Clr Bal \: Rs\. .* CR .* \-\- .* \- ALB$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转出', '金额＿余额', '金额＿余额', '日期＿交易时间', '日期＿交易时间']
# ------------------------------------------------------
# 2273 ^Your a\/c no\. .* is credited by .* on .* sent by .* Ref no .*$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转入', '日期＿交易时间', 'other', 'other']
# ------------------------------------------------------
# [None, None, None, None, None, None, None]
# ------------------------------------------------------
# 2275 ^Your A\/c .* is debited through ATM by Rs\. .* Total Bal \: Rs\. .* CR Clr Bal \: Rs\. .* CR .* \-\- .* \- ALB$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转出', '金额＿余额', '金额＿余额', '日期＿交易时间', '日期＿交易时间']
# ------------------------------------------------------
# 2276 ^Your A\/c .* is debited by Rs\. .* Bal after Debit is Rs\. .* CR .* MINIMUM BAL NOT MAINTAINED\.PL FUND YOUR A\/C\. \-\- .* \- ALB$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转出', '金额＿余额', '日期＿交易时间', '日期＿交易时间']
# ------------------------------------------------------
# [None, None]
# ------------------------------------------------------
# 2282 ^Your a\/c no\. .* is credited by .* on .* sent by goog\-payment\@okaxis\-GOOGLEPAY\(UPI Ref no .*$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转入', '日期＿交易时间', 'other']
# ------------------------------------------------------
# [None, None, None, None, None, None, None]
# ------------------------------------------------------
# [None, None, None, None, None, None]
# ------------------------------------------------------
# 2289 ^Your Account .* has been debited with Rs\. .* for Online E\-Payment through Internet Banking\. \-\- .* \- ALB$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转出', '日期＿交易时间']
# ------------------------------------------------------
# 2292 ^Your a\/c no\. .* is credited for .* on .* for reversal of unsuccessful transaction \(UPI Ref no .*$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转入', '日期＿交易时间', 'other']
# ------------------------------------------------------
# 2293 ^Your A\/c .* is debited by Rs\. .* through .* txn using Aadhaar No\. .* on .* \-\- .* \- ALB$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转出', '机构＿交易平台', 'other', '日期＿交易时间', '日期＿交易时间']
# ------------------------------------------------------
# 2294 ^Rs\. .* deducted as penal charges for fall in minimum balance of previous quarter \-\- .* \- ALB$
# 短信类型:  交易流水＿转账
# ['金额＿转出', '日期＿交易时间']
# ------------------------------------------------------
# 2298 ^Your a\/c no\. .* is credited by .* on .* sent by .* Ref no .* Fight Against Corruption\. Take e\-pledge on www\.pledge\.cvc\.nic\.in$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转入', '日期＿交易时间', 'other', 'other']
# ------------------------------------------------------
# 2300 ^LPG Subsidy of Rs\. .* has been credited in your Account No\. .* \-\- .* \- ALB$
# 短信类型:  交易流水＿转账
# ['金额＿转入', '账户账号＿自己', '日期＿交易时间']
# ------------------------------------------------------
# [None, None, None, None, None, None]
# ------------------------------------------------------
# [None, None, None, None, None]
# ------------------------------------------------------
# 2304 ^Your A\/c .* is debited by Rs\. .* Bal after Debit is Rs\. .* CR .* MINIMUM BAL NOT MAINTAINED\.PL FUND YOUR .* \-\- .* \- ALB$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转出', '金额＿余额', '日期＿交易时间', 'other', '日期＿还款日期']
# ------------------------------------------------------
# [None, None, None]
# ------------------------------------------------------
# 2308 ^NEFT transfer of Rs\. .* to .* BANK will be effected subject to realisation\. Ref No \: .* \-\- .* \- ALB$
# 短信类型:  交易流水＿转账
# ['金额＿转出', '机构＿交易平台', 'other', '日期＿交易时间']
# ------------------------------------------------------
# corpbk.pkl
# corpbk
# [None, None, None, None, None]
# ------------------------------------------------------
# [None, None, None, None, None, None, None]
# ------------------------------------------------------
# 5801 ^Your a\/c no .* is debited for .* on .* and a\/c .* of .* is credited \(IMPS Ref no .* \)\.$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转出', '日期＿交易时间', '账户账号＿他人', 'other', 'other']
# ------------------------------------------------------
# 5803 ^Dear Customer\, Your request for IMPS payment of Rs\. .* for the beneficiary IFSC .* a\/c .* has been .* From CorpBank$
# 短信类型:  交易流水＿转账
# ['金额＿转出', 'other', '账户账号＿自己', 'other']
# ------------------------------------------------------
# 5805 ^Your A\/c .* in .* credited INR .* on .* by CASH\. Avl Bal is .*$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '机构＿交易平台', '金额＿转入', '日期＿交易时间', '金额＿余额']
# ------------------------------------------------------
# [None, None, None, None, None]
# ------------------------------------------------------
# 5814 ^Your A\/c .* in .* debited INR .* on .* by CASH\. Avl Bal is .*$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '机构＿交易平台', '金额＿转出', '日期＿交易时间', '金额＿余额']
# ------------------------------------------------------
# 5816 ^An amount of Rs\. .* has been debited from your A\/C .* for an online transaction done at .* using CorpNet banking\, Ref No\: .* From CorpBank$
# 短信类型:  交易流水＿转账
# ['金额＿转出', '账户账号＿自己', 'other', 'other']
# ------------------------------------------------------
# [None, None, None]
# ------------------------------------------------------
# 5821 ^Your A\/c .* debited .* on .* by NEFT with UTR No \: .* \. Avl bal is .*$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转出', '日期＿交易时间', 'other', '金额＿余额']
# ------------------------------------------------------
# [None, None, None]
# ------------------------------------------------------
# 5826 ^Returned\, .* for .* fvg .* rcvd for Db in ur A\/c .* in Clg\. Contact Branch\.$
# 短信类型:  sms_other
# ['other', 'other', 'other', 'other']
# ------------------------------------------------------
# ['other', 'other', 'other', 'other']
# ------------------------------------------------------
# ['other', 'other', 'other', 'other', 'other']
# ------------------------------------------------------
# 5833 ^INR .* debited to a\/c .* from ATM On .* \.Avl Bal .* \.Reversal in 2days for tech failure\.Call 18004252407 for help$
# 短信类型:  交易流水＿转账
# ['金额＿转出', '账户账号＿自己', '日期＿交易时间', '金额＿余额']
# ------------------------------------------------------
# ['账户账号＿自己', None, None, None, None, None]
# ------------------------------------------------------
# 5835 ^Your a\/c no\. .* is credited for .* on .* for reversal of transaction \(UPI Ref no .*$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转入', '日期＿交易时间', 'other']
# ------------------------------------------------------
# [None, None, None, None]
# ------------------------------------------------------
# 5838 ^Your a\/c no\. .* is credited for .* on .* for reversal of transaction \(IMPS Ref no .* \)\.$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转入', '日期＿交易时间', 'other']
# ------------------------------------------------------
# [None]
# ------------------------------------------------------
# [None, None, None, None]
# ------------------------------------------------------
# 5845 ^Inward Clg Cheque\: .* for .* fvg .* presented in A\/c\: .* Contact your Branch if there is any discrepancy\.$
# 短信类型:  交易流水＿转账
# ['other', '金额＿转出', 'other', '账户账号＿自己']
# ------------------------------------------------------
# 5846 ^Your request for the payment Rs\. .* has been executed successfully\. Ref No\: .* From CorpBank$
# 短信类型:  交易流水＿转账
# ['金额＿转出', 'other']
# ------------------------------------------------------
# 5847 ^Dear Customer\, your account .* has been credited INR .* through NPCI Clearing on .* \. Avl Balance is INR .*$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转入', '日期＿交易时间', '金额＿余额']
# ------------------------------------------------------
# 5849 ^Due\, .* towards your loan A\/c .* inclusive of instalment\, payable on .* Contact branch for any clarification\. Pls ignore if paid$
# 短信类型:  贷后提醒＿到期提醒
# ['金额＿应还金额', '账号＿借款编号', '日期＿交易时间']
# ------------------------------------------------------
# 5853 ^Your A\/c .* in credited INR .* on .* by \. Avl Bal is .*$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转入', '日期＿交易时间', '金额＿余额']
# ------------------------------------------------------
# iobchn.pkl
# iobchn
# [None, None, None, None, False]
# ------------------------------------------------------
# [None, None, None, None, None]
# ------------------------------------------------------
# 4531 ^Your a\/c no\. .* is credited by .* on .* by a\/c linked to mobile .* Ref no .*$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转入', '日期＿交易时间', '账户账号＿他人', 'other']
# ------------------------------------------------------
# 4532 ^Your a\/c no\. .* is debited for Rs\. .* on .* and a\/c .* credited \(IMPS Ref no .*$
# 短信类型:  交易流水＿转账
# ['账户账号＿自己', '金额＿转出', '日期＿交易时间', '账户账号＿他人', 'other']
# ------------------------------------------------------
# [None, None, None, None, None]
# ------------------------------------------------------
# 4534 ^You have done a Transaction .* IOB internet banking on .* for .* from A\/c no .*$
# 短信类型:  交易流水＿转账
# ['other', '日期＿交易时间', '金额＿转出', '账户账号＿自己']
# ------------------------------------------------------
# 4535 ^Your Avl Balance Acct \: .* is Rs .*$
# 短信类型:  交易流水＿余额
# ['账户账号＿自己', '金额＿余额']
# ------------------------------------------------------
# [None, None, None, None]
# ------------------------------------------------------
# [None, None, None, None]
# ------------------------------------------------------
# 4539 ^You have done a Tax\/Bill payment through IOB internet banking on .* for .* from A\/c no .*$
# 短信类型:  交易流水＿转账
# ['日期＿交易时间', '金额＿转出', '账户账号＿自己']
# ------------------------------------------------------
# 4540 ^Your IOB Cheque No\. .* for Rs\. .* is presented today for clearing in your A\/C .* \.\.\.\.\.$
# 短信类型:  信用卡＿还款提醒
# ['other', '金额＿转出', '账户账号＿自己']
# ------------------------------------------------------
# [None, None, None, None]
# ------------------------------------------------------
# [None, None, None, None]
# ------------------------------------------------------
# [None, None, None, None]
# ------------------------------------------------------
# [None, None, None, None, None]
# ------------------------------------------------------
# 4546 ^Dear Customer\,Your Loan A\/c .* with IOB is Overdue for .* days by .* as on .* \[SMA\-2\]\.Regularize to avoid punitive action\.$
# 短信类型:  贷后提醒＿逾期催收
# ['账号＿借款编号', '天数＿逾期天数', '金额＿应还金额', '日期＿还款日期']
# ------------------------------------------------------
# [None, None, None, None]
# ------------------------------------------------------
# [None, None, None, None]
# ------------------------------------------------------
# [None, None, None, None]
# ------------------------------------------------------
# [None, None, None, None]
# ------------------------------------------------------
# 4553 ^Mandate\(Ref No\: .* issued to .* for Rs .* and frequency .* is received for processing\. In case of any issue please contact your branch$
# 短信类型:  账号异常＿扣款失败
# ['other', 'other', '金额＿转出', 'other']
# ------------------------------------------------------
# [None, None, None, None]
# ------------------------------------------------------
# [None, None, None]
# ------------------------------------------------------
# 4560 ^Mandate\(Ref No\: .* issued to .* for Rs .* and frequency Monthly is accepted\. Applicable charges will be collected$
# 短信类型:  sms_other
# ['other', 'other', 'other']
# ------------------------------------------------------
# 4564 ^You have done a Transaction through IOB internet banking to Other Bank Account on .* for .* from A\/c no .*$
# 短信类型:  交易流水＿转账
# ['日期＿交易时间', '金额＿转出', '账户账号＿自己']
# ------------------------------------------------------
# [None, None, None, None]
# ------------------------------------------------------
# [None, None, None, None]
# ------------------------------------------------------
# [None, None, None]
# ------------------------------------------------------
# [None, None, None]
# ------------------------------------------------------
# axismr.pkl
# axismr
# 3400 ^Dear Customer\,in order to serve you better\, Axis Bank offers you an enhanced limit of .* on your Credit Card\.To avail SMS CLE .* to 5676782 by .*$
# 短信类型:  交易流水＿余额
# ['金额＿信用额度', 'other', 'other']
# ------------------------------------------------------
# 3404 ^Hi\, the .* in your current a\/c .* for the first 20 days of this month is .* Please fund your A\/c to avoid charges on MAB shortfall\. T\&C apply$
# 短信类型:  sms_other
# [None, None, None]
# ------------------------------------------------------

# %%
DF = pd.DataFrame()
for tt in ALL:
    DF_tmp = pd.DataFrame()
    length = len(tt[0].split(' '))
    DF_tmp['token'] = tt[0].split(' ')
    DF_tmp['lable'] = DF_tmp.token.apply(lambda x: tt[3][x] if x in tt[3] else np.nan)
    DF_tmp['sent_id'] = [tt[0].split(' ')[i] if i==0 else np.nan for i in range(len(DF_tmp))]
    DF_tmp['cls'] = [tt[4]]*length
    DF_tmp.sent_id=DF_tmp.sent_id.fillna(method='ffill')
    DF = DF.append(DF_tmp)
    DF = DF[~DF.cls.isnull()]
DF = DF.fillna(value='other')

DF['sent_id'] = ['sent_' if i == 0 else np.nan for i in DF.index]
DF['idx_num'] = range(DF.shape[0])
DF['sent_id'] = DF.apply(lambda x: str(x.sent_id) + str(x.idx_num), axis=1)
DF['sent_id'] = DF.sent_id.apply(lambda x: x if x.startswith('sent') else np.nan)
DF.sent_id = DF.sent_id.fillna(method='ffill')
DF = DF.drop(['idx_num'], axis=1)
DF = DF[DF.cls != False]
DF.shape
# Out:
# (29300, 4)

# %% [raw]
# DF.to_csv('gsm_ALL.csv', header=False)

# %% [markdown]
# ### 唯一测试集；

# %%
Test_DF = pd.read_csv('gsmTst100.csv', header=None).iloc[:,1:]
Test_DF.columns = ['token', 'lable', 'sent_id', 'cls']

sms_te = Test_DF.groupby('sent_id').apply(lambda x: ' '.join(x.token.tolist()).lower())
cls_te = Test_DF.groupby('sent_id').apply(lambda x: x.cls.tolist()[0])
df3_te = pd.DataFrame(columns=['sms', 'cls'])
df3_te.sms = sms_te
df3_te.cls = cls_te

df3_te.shape
# Out:
# (100, 2)

# %%
DF = DF[~DF.sent_id.isin(Test_DF.sent_id)]
DF.shape
# Out:
# (26883, 4)

# %%
## 造假n倍
dupli = 10
DF = DF[DF.cls != False]
df = create_fake_label(DF, dupli)
df2 = fake2real_v2(df, dupli)

# %%
# 过采样欠采样；2bDone

# %%
def get_cos_similarity(sms, templates):
    '''计算一条新sms 与 每个 template 相似度;'''
    def cos_sim(a, b):
        return dot(a, b) / (norm(a) * norm(b))
    return [cos_sim(i, sms) for i in templates]


def tfIdfVector(corpus):
    '''
    corpus is a list of sentences:
    ['This is an example', 'hello world', ...]
    '''
    vectorizer = CountVectorizer()
    transformer = TfidfTransformer()
    x = vectorizer.fit_transform(corpus)
    tfidf = transformer.fit_transform(x)
    return tfidf.toarray()

# def newAndTemplate(template_df, new_sms, thresh=None):
#     '''
#     new_sms: test samples
#     '''
#     corpus, labels = template_df.sms.tolist(), template_df.label.tolist()
#     num_sms = len(new_sms)
#     for single in new_sms:
#         corpus.append(single.lower())
#     all_tfidf = tfIdfVector(corpus)
#     template_tfidf = all_tfidf[:-num_sms]
#     instances_tfidf = all_tfidf[-num_sms:]
#     adj_mat = cosine_similarity(all_tfidf)
#     print('adj mat shape:{}'.format(adj_mat.shape))
#     if thresh:
#         print('thresh:{}'.format(thresh))
#         adj_mat-=np.identity(len(adj_mat))
#         G2 = nx.from_numpy_matrix((adj_mat > thresh)*1)
#     else:
#         G2 = nx.from_numpy_matrix(adj_mat)
#     print(G2.number_of_edges())
#     for i in range(len(G2.nodes())):
#         G2.node[i]['vec'] =  all_tfidf[i]
#         G2.node[i]['text'] = corpus[i]
#         temp_label = labels[i] if i < len(labels) else 0
#         G2.node[i]['label'] = temp_label
#     return G2

def GraphBuild(template_df, new_sms, K=10, thresh=None):
    '''
    之前版本没考虑到采样需要全图遍历；故在入图过程就把K_nerghs当作点属性加进去；
    new_sms: test samples, df type;
    
    '''
    def findNeighsK(arr, K):
        K+=1 #入图时neighs 不包括自己，故这里先加一个保证去除自己之后仍然有K neighs;
        idx=np.argpartition(arr, -K)[-K:]
        return idx

    corpus, labels = template_df.sms.tolist(), template_df.cls.tolist()
    new_labels = new_sms.cls.tolist()
    new_sms = new_sms.sms.tolist()
    num_sms = len(new_sms)
    for single in new_sms:
        corpus.append(single.lower())
    for single in new_labels:
        labels.append(single)
    all_tfidf = tfIdfVector(corpus)
    adj_mat = cosine_similarity(all_tfidf)
    print('adj mat shape:{}'.format(adj_mat.shape))
    G = nx.Graph()
    G.add_nodes_from(range(len(adj_mat)))
    for i in range(len(G.nodes())):
        G.node[i]['vec'] =  all_tfidf[i]
        G.node[i]['text'] = corpus[i]
        G.node[i]['label'] = labels[i]
        G.node[i]['neighs_k'] = set(findNeighsK(adj_mat[i], K)) - set([i])
    return G

# %% [raw]
# # graphsage 怎么设计盲测？
# 首先必须要有相似度关联；
# 故，盲测集必须入图；
# 只要保证盲测集不参与训练即可，无需mask
# 什么时候需要mask? 当你要半监督的时候，只有node & path
# 没label,通过mask不参与反向传播；
# 既然如此，我何必需要这些 ‘无label node’ 入图呢？
# 首先，这些node 提供了边点信息，为有label node 的 agg&enc；
# 所以虽然这些点不作为target参与BP,
# 但是作为target的邻居，参与了BP;
# 盲测集入图，半监督设置，盲测点不提供label;

# %%
# df2 = DF

# %%
sms = df2.groupby('sent_id').apply(lambda x: ' '.join(x.token.tolist()).lower())
cls = df2.groupby('sent_id').apply(lambda x: x.cls[0])
df3 = pd.DataFrame(columns=['sms', 'cls'])
df3.sms = sms
df3.cls = cls

# %%
g4 = GraphBuild(df3, df3_te)
# Out:
# adj mat shape:(11050, 11050)

# %%
"""
Set of modules for aggregating embeddings of neighbors.
"""
class MeanAggregator_QBv2(nn.Module):
    """
    adjMat@embMat: [bs, uniqueNode]@[uniqueNode, F]=[bs, F]
    
    要改，之前没注意每次采样全图遍历；
    如无必要，不要让一个实例挂一个毒瘤: G (20G内存)
    """
    def __init__(self, features, cuda=False, gcn=False): 
        """
        Initializes the aggregator for a specific graph.
        features -- function mapping LongTensor of node ids to FloatTensor of feature values.
        cuda -- whether to use GPU;
        gcn --- whether to perform concatenation GraphSAGE-style, or add self-loops GCN-style
        """
        super(MeanAggregator_QBv2, self).__init__()
        self.features = features
        self.cuda = cuda
        self.gcn = gcn
        
    def forward(self, nodes, to_neighs, num_sample=10):
        """
        nodes --- list of nodes in a batch, [bs]
        to_neighs --- list of sets, 
                      each set is the set of neighbors for node in batch
        num_sample --- number of neighbors to sample. 
        """
        _set = set
        if not num_sample is None:
            _sample = random.sample
            samp_neighs = [_set(_sample(to_neigh, num_sample))
                           if len(to_neigh) >= num_sample else to_neigh 
                           for to_neigh in to_neighs]
        else:
            samp_neighs = to_neighs
    
        # 纳入target idx;
        if self.gcn:
            samp_neighs = [set.union(samp_neigh, set([nodes[i]])) for i, samp_neigh in enumerate(samp_neighs)]
        unique_nodes_list = list(set.union(*samp_neighs))
        unique_nodes = {n:i for i,n in enumerate(unique_nodes_list)}
        mask = Variable(torch.zeros(len(samp_neighs), len(unique_nodes)))
        column_indices = [unique_nodes[n] for samp_neigh in samp_neighs for n in samp_neigh]   
        row_indices = [i for i in range(len(samp_neighs)) for j in range(len(samp_neighs[i]))]
        mask[row_indices, column_indices] = 1
        if self.cuda:
            mask = mask.cuda()
        num_neigh = mask.sum(1, keepdim=True)
        mask = mask.div(num_neigh)
        if self.cuda:
            embed_matrix = self.features(torch.LongTensor(unique_nodes_list).cuda())
        else:
            embed_matrix = self.features(torch.LongTensor(unique_nodes_list))
        to_feats = mask.mm(embed_matrix)
        return to_feats

    
class Encoder_QBv2(nn.Module):
    """
    ([cls, 2f]@[2f, bs]).T = [bs, cls] 
    Encodes a node's using 'convolutional' GraphSage approach
    """
    def __init__(self, features, feature_dim, 
            embed_dim, adj_lists, aggregator,
            num_sample=10,
            base_model=None, gcn=False, cuda=False, 
            feature_transform=False): 
        super(Encoder_QBv2, self).__init__()

        self.features = features
        self.feat_dim = feature_dim
        self.adj_lists = adj_lists
        self.aggregator = aggregator
        self.num_sample = num_sample
        if base_model != None:
            self.base_model = base_model

        self.gcn = gcn
        self.embed_dim = embed_dim
        self.cuda = cuda
        self.aggregator.cuda = cuda
        self.weight = nn.Parameter(
                torch.FloatTensor(embed_dim, self.feat_dim if self.gcn else 2 * self.feat_dim))
        init.xavier_uniform(self.weight)


    def forward(self, nodes):
        """
        Generates embeddings for a batch of nodes.
        nodes     -- list of nodes; [bs]
        operations: 已知self_feat: [bs, F]
                    再agg_feat: [bs, F]
                    然后concat([agg_feat, self_feat]): [bs, 2F]
                    然后W:[F2, 2F] 
                    relu(W @[bs,2F].T) : [F2, bs] 
        """
        neigh_feats = self.aggregator.forward(nodes, [self.adj_lists[int(node)] for node in nodes], 
                self.num_sample)
        if not self.gcn:
            if self.cuda:
                self_feats = self.features(torch.LongTensor(nodes).cuda())
            else:
                self_feats = self.features(torch.LongTensor(nodes))
            combined = torch.cat([self_feats, neigh_feats], dim=1)
        else:
            combined = neigh_feats
        combined = F.relu(self.weight.mm(combined.t()))
        return combined



class SupervisedGraphSage_QB(nn.Module):
    def __init__(self, num_classes, enc):
        super(SupervisedGraphSage_QB, self).__init__()
        self.enc = enc
        self.weight = nn.Parameter(torch.FloatTensor(num_classes, enc.embed_dim))
        init.xavier_uniform(self.weight)
        self.loss = nn.NLLLoss(reduce=False)
        self.logsoftmax = nn.LogSoftmax(dim=-1)
        self.softmax = nn.Softmax(dim=-1)

    def forward(self, nodes, softmax=False):
        embeds = self.enc(nodes)
        scores = self.weight.mm(embeds)
        if softmax:
            return self.softmax(scores.t())
        return scores.t()

    def loss_softmax_mask(self, nodes, labels, mask=None):
        '''
        nodes shape: [N];
        labels shape: [N];
        mask shape: [N];
        '''
        if mask is None:
            mask = torch.ones(len(labels))
        logits = self.forward(nodes)
        A_soft = self.logsoftmax(logits)
        output = self.loss(A_soft, labels.squeeze())
        loss = output*mask.type(torch.float)
        loss = sum(loss)/sum(mask)
        return loss
    
    
def result(G, output, label_idx, idx2label):
    score, pred = output.max(dim=-1)
    sms = [G.node[i]['text'] for i in label_idx]
    df = pd.DataFrame()
    df['sms']= sms
    df['score']=score.data
    df['pred']=[idx2label[i] for i in pred.numpy()]
    df['label']=[g4.node[i]['label'] for i in label_idx]
    return df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-ca4785af278f> in <module>
#       2 Set of modules for aggregating embeddings of neighbors.
#       3 """
# ----> 4 class MeanAggregator_QBv2(nn.Module):
#       5     """
#       6     adjMat@embMat: [bs, uniqueNode]@[uniqueNode, F]=[bs, F]
#
# NameError: name 'nn' is not defined

# %%
def load_india_sms(G):
    feat_data = [G.node[i]['vec'] for i in G.nodes]
    labels = [G.node[i]['label'] for i in G.nodes]
    adj_lists = [G.node[i]['neighs_k'] for i in G.nodes]
    return feat_data, labels, adj_lists

# %%
len(feat_data)
# Out:
# 11050

# %%
np.random.seed(1)
random.seed(1)
feat_data, labels, adj_lists = load_india_sms(g4)
idx2label = {i:j for i, j in enumerate(np.unique(labels))}
label2idx = {j:i for i,j in idx2label.items()}
labels = np.array([label2idx[i] for i in labels])
num_cls = len(np.unique(labels))
features = nn.Embedding(len(feat_data), len(feat_data[0]))
features.weight = nn.Parameter(torch.FloatTensor(feat_data), requires_grad=False)

agg1 = MeanAggregator_QBv2(features, cuda=False, gcn=True)
enc1 = Encoder_QBv2(features, node_F, 128, adj_lists, agg1, num_sample=5, gcn=True, cuda=False)
agg2 = MeanAggregator_QBv2(lambda nodes : enc1(nodes).t(), cuda=False, gcn=True)
enc2 = Encoder_QBv2(lambda nodes : enc1(nodes).t(), 
               enc1.embed_dim, node_F, adj_lists, agg2, num_sample=5, gcn=True, cuda=False)

# %%
graphsage = SupervisedGraphSage_QB(num_cls, enc2)
#graphsage.cuda()
#rand_indices = np.random.permutation(len(node_list))
nodes = list(g4.nodes)
val = nodes[:50]
test_nodes = list(g4.nodes)[-df3_te.shape[0]:]
train = nodes[50:-len(test_nodes)]
optimizer = torch.optim.SGD(filter(lambda p : p.requires_grad, graphsage.parameters()), lr = 0.05)
times = []
Loss = []
print('GO')
for batch in range(4000):
    batch_nodes2 = train[:100]
    batch_idx = copy.copy(train[:100])
    random.shuffle(train)
    start_time = time.time()
    optimizer.zero_grad()
    loss = graphsage.loss_softmax_mask(batch_nodes2,
            Variable(torch.tensor(labels[np.array(batch_idx)])))
    loss.backward()
    optimizer.step()
    end_time = time.time()
    times.append(end_time - start_time)
    if batch%100 == 0:
        train_loss = graphsage.loss_softmax_mask(train,
            Variable(torch.tensor(labels[np.array(train)])))
        val_loss = graphsage.loss_softmax_mask(val,
            Variable(torch.tensor(labels[np.array(val)])))
        print('batch:{}; train_loss:{}; val_loss:{}'.format(batch, train_loss.data, val_loss.data))
    Loss.append(loss.data)
# Out:
# GO
# batch:0; train_loss:2.8286921977996826; val_loss:2.8306429386138916
# batch:100; train_loss:2.155996561050415; val_loss:2.4689207077026367
# batch:200; train_loss:1.787720799446106; val_loss:2.303647518157959
# batch:300; train_loss:1.6322472095489502; val_loss:2.2604198455810547
# batch:400; train_loss:1.5698705911636353; val_loss:2.2569632530212402
# batch:500; train_loss:1.537320852279663; val_loss:2.2695255279541016
# batch:600; train_loss:1.5167006254196167; val_loss:2.2765228748321533
# batch:700; train_loss:1.5000903606414795; val_loss:2.258310556411743
# batch:800; train_loss:1.4885119199752808; val_loss:2.243403434753418
# batch:900; train_loss:1.4737707376480103; val_loss:2.2367095947265625
# batch:1000; train_loss:1.4626046419143677; val_loss:2.2238497734069824
# batch:1100; train_loss:1.4515964984893799; val_loss:2.19577693939209
# batch:1200; train_loss:1.440972924232483; val_loss:2.2087111473083496
# batch:1300; train_loss:1.4311469793319702; val_loss:2.183877944946289
# batch:1400; train_loss:1.4212106466293335; val_loss:2.170334815979004
# batch:1500; train_loss:1.4122437238693237; val_loss:2.1757657527923584
# batch:1600; train_loss:1.4051635265350342; val_loss:2.151268482208252
# batch:1700; train_loss:1.3976855278015137; val_loss:2.1503467559814453
# batch:1800; train_loss:1.389241337776184; val_loss:2.1453781127929688
# batch:1900; train_loss:1.382856011390686; val_loss:2.1350150108337402
# batch:2000; train_loss:1.3774021863937378; val_loss:2.131286382675171
# batch:2100; train_loss:1.3694924116134644; val_loss:2.1219513416290283
# batch:2200; train_loss:1.363814353942871; val_loss:2.103285789489746
# batch:2300; train_loss:1.3567205667495728; val_loss:2.103365421295166
# batch:2400; train_loss:1.354137897491455; val_loss:2.104318618774414
# batch:2500; train_loss:1.3465793132781982; val_loss:2.105426073074341
# batch:2600; train_loss:1.3415169715881348; val_loss:2.0811667442321777
# batch:2700; train_loss:1.3378725051879883; val_loss:2.0900206565856934
# batch:2800; train_loss:1.3319308757781982; val_loss:2.0841503143310547
# batch:2900; train_loss:1.3292644023895264; val_loss:2.088449716567993
# batch:3000; train_loss:1.3224583864212036; val_loss:2.079435348510742
# batch:3100; train_loss:1.317812442779541; val_loss:2.0719945430755615
# batch:3200; train_loss:1.3136705160140991; val_loss:2.058504343032837
# batch:3300; train_loss:1.3094079494476318; val_loss:2.0506882667541504
# batch:3400; train_loss:1.3062783479690552; val_loss:2.0617876052856445
# batch:3500; train_loss:1.301182746887207; val_loss:2.0506725311279297
# batch:3600; train_loss:1.2969356775283813; val_loss:2.074856758117676
# batch:3700; train_loss:1.292730689048767; val_loss:2.0457515716552734
# batch:3800; train_loss:1.2913061380386353; val_loss:2.053514242172241
# batch:3900; train_loss:1.2855197191238403; val_loss:2.0472936630249023

# %%
val_output = graphsage.forward(val)

result(g4, val_output, val, idx2label)
# Out:
#                                                   sms     score      pred  \
# 0   dear customer,in order to serve you better, ax...  3.777260   交易流水＿转账
# 1   you have done a transaction through iob intern...  3.523083   交易流水＿转账
# 2   due, rs.0643 towards your loan a/c x..x6323 in...  2.223659   交易流水＿转账
# 3   a charge of rs. 340.22 has been initiated on y...  4.740955   交易流水＿转账
# 4   dear customer, you have made a payment of rs. ...  4.337186   交易流水＿转账
# 5   rs. 183.02 spent on card xx2186 on 00-40-9641,...  4.178057   交易流水＿转账
# 6   namaskar! your transaction has been declined d...  3.257231   交易流水＿转账
# 7   rs. 533.69 was spent on your debit card 7073xx...  3.464867   交易流水＿转账
# 8   your a/c no. xxxxxxxxxx7910 is debited for rs....  4.715461   交易流水＿转账
# 9   rs. 367.30 spent on card xx0956 on 34-89-9890,...  3.652866   交易流水＿转账
# 10  epf balance in a/c no. py/krp/0015848/000/0002...  3.140730   交易流水＿转账
# 11  your transfer claim ( kdmal825960409639 ) has ...  1.885930   交易流水＿转账
# 12  your claim ( kdmal572634591154 ) has been appr...  3.024846   交易流水＿转账
# 13  form 10c (withdrawal benefit) claim id:bgbng17...  3.123465   交易流水＿转账
# 14  your claim form-31 ( ththa18088311 ) has been ...  3.621298   交易流水＿转账
# 15  dear customer, your fund transfer request for ...  4.855626   交易流水＿转账
# 16  your online claim form-31 ( ngaur18095755 ) ha...  1.142754   交易流水＿转账
# 17  dear employer pykrp2115077322 the contribution...  1.618223   交易流水＿转账
# 18  dear member (uan :100220372181), rs. 234 for 6...  4.247353   交易流水＿转账
# 19  your online claim ( kdmal084880714911 ) has be...  2.867152   交易流水＿转账
# 20  dear member, your uan : 100463443315,name :rac...  2.725597   交易流水＿转账
# 21  your claim ththa18088311, settled for rs. 9451...  3.266170   交易流水＿转账
# 22  dear member, your uan : 100654667735,name :man...  3.556721   交易流水＿转账
# 23  hey mazhar uddin khan, your emi of ₹07 is due ...  2.991451   交易流水＿转账
# 24  hey mazhar uddin khan, your emi of ₹35 is due ...  2.952571   交易流水＿转账
# 25  hey kamalesh kumar jain, emi of ₹0671 is due o...  1.748722  信用卡＿还款提醒
# 26  cash deposit transaction of rs. 3828 for accou...  3.383659   交易流水＿转账
# 27  hey deepak bhardwaj, emi of ₹8007 is due on 55...  1.586621   交易流水＿转账
# 28  congratulation lalit sharma, we've processed y...  2.469073   交易流水＿转账
# 29  hey mazhar uddin khan, your emi of ₹76 is due ...  2.994664   交易流水＿转账
# 30  hey caroline hanif shaikh, it's repay day! emi...  1.952073   交易流水＿转账
# 31  hey mazhar uddin khan, your emi of ₹66 is due ...  2.997585   交易流水＿转账
# 32  congrats penta raju, your emi plan for loan #5...  1.688842   交易流水＿转账
# 33  manjunath.h.m ., you are the best. the payment...  3.325642   交易流水＿转账
# 34  hi, your zestmoney emi application for amazon ...  2.149982   交易流水＿转账
# 35  hey manjunath.h.m, emi of ₹3959 is due on 4240...  2.331566   交易流水＿转账
# 36  hey manjunath.h.m, emi of ₹0885 is due on 4658...  1.840082   交易流水＿转账
# 37  dear customer,ecs transaction of rs. 1256 towa...  3.779416   交易流水＿转账
# 38  dear diners cardmember, payment of rs 11603 wa...  2.353389   交易流水＿转账
# 39  your a/c no. xxxxxxxxxx6356 is debited for inr...  5.164538   交易流水＿转账
# 40  reminder! your bill of bharti airtel limited, ...  2.401281   交易流水＿转账
# 41  dear customer. greetings from hdfc bank. we wi...  1.746881   交易流水＿转账
# 42  dear cust, ecs for hdfc bank auto loan#5490701...  3.268580   交易流水＿转账
# 43  dear smartpay customer, please have adequate l...  3.308259   交易流水＿转账
# 44  your a/c no. xxxxxxxxxx7627 is credited by inr...  3.455245   交易流水＿转账
# 45  dear customer, e-stmt for hdfcbank creditcard ...  1.710295   交易流水＿转账
# 46  thank you for using debit card ending 4409 for...  3.707088   交易流水＿转账
# 47  update: your salary of inr 1,624.37 is credite...  4.183961   交易流水＿转账
# 48  dear customer, refund of inr 5.24 from maheshw...  3.564489   交易流水＿转账
# 49  thank you for using debit card ending 5061 for...  2.873762   交易流水＿转账
#
#         label
# 0     交易流水＿余额
# 1     交易流水＿转账
# 2   贷后提醒＿到期提醒
# 3     交易流水＿转账
# 4     交易流水＿转账
# 5     交易流水＿转账
# 6   账号异常＿余额不足
# 7     交易流水＿转账
# 8     交易流水＿转账
# 9     交易流水＿转账
# 10    交易流水＿余额
# 11  贷前申请＿审核通过
# 12  贷前申请＿审核通过
# 13  贷前申请＿审核通过
# 14  贷前申请＿审核通过
# 15    交易流水＿转账
# 16  贷前申请＿审核拒绝
# 17  贷后提醒＿到期提醒
# 18    交易流水＿转账
# 19  贷后提醒＿成功放款
# 20    交易流水＿余额
# 21  贷后提醒＿成功放款
# 22    交易流水＿余额
# 23   信用卡＿还款提醒
# 24   信用卡＿还款提醒
# 25   信用卡＿还款提醒
# 26    交易流水＿转账
# 27   信用卡＿还款提醒
# 28  贷后提醒＿成功放款
# 29   信用卡＿还款提醒
# 30    交易流水＿转账
# 31   信用卡＿还款提醒
# 32  贷前申请＿审核通过
# 33    交易流水＿转账
# 34  贷前申请＿审核拒绝
# 35   信用卡＿还款提醒
# 36   信用卡＿还款提醒
# 37  账号异常＿余额不足
# 38    交易流水＿转账
# 39    交易流水＿转账
# 40   信用卡＿还款提醒
# 41  贷后提醒＿到期提醒
# 42  sms_other
# 43  sms_other
# 44    交易流水＿转账
# 45   信用卡＿还款提醒
# 46    交易流水＿转账
# 47    交易流水＿转账
# 48    交易流水＿转账
# 49    交易流水＿转账

# %%
te_output = graphsage.forward(test_nodes)
result(g4, te_output, test_nodes, idx2label)
# Out:
#                                                   sms     score      pred  \
# 0   thank you for payment of inr.6000.00 on your c...  4.708610   交易流水＿转账
# 1   dear customer,your transaction at atm 1cn04401...  3.009799   交易流水＿转账
# 2   your a/c no. xxxxxxx7494 is debited for inr 2,...  3.527857   交易流水＿转账
# 3   your a/c xxxxxxx5273 has been debited with inr...  3.611550   交易流水＿转账
# 4   your a/c no. ***********5885 is credited for r...  4.313889   交易流水＿转账
# 5   inr 9,400.00 credited to your a/c no xxxxxxx49...  3.559350   交易流水＿转账
# 6   dear boi customer, a/c xxxxxxxxxxx6116 charged...  3.883627   交易流水＿转账
# 7   rs.30 has been debited from your kotak account...  4.075966   交易流水＿转账
# 8   a/c nn4214 debited for inr 24; atm wdl. a/c ba...  4.320962   交易流水＿转账
# 9   dear customer, refund of rs .82 from hpcl 0.75...  2.716831   交易流水＿转账
# 10  your a/c no. xxxxxxxx1061 is debited for rs.3....  5.463014   交易流水＿转账
# 11  dear customer, payment received for amount of ...  2.909450   交易流水＿转账
# 12  your profile password for username xxxaan has ...  1.707579   交易流水＿转账
# 13  bill payment for ketaki has been made successf...  3.996866   交易流水＿转账
# 14  your a/c no. xxxxxx1711 is credited for rs.20....  3.978328   交易流水＿转账
# 15  pos tran of rs.1522.00 is done on card xx0742 ...  3.529921   交易流水＿转账
# 16  idbi bk a/c. nnnnn64164 credited rs 8000.00 tw...  4.031664   交易流水＿转账
# 17  your a/c no. xxxx651 is debited with rs 199.00...  5.814308   交易流水＿转账
# 18  a/c 3xxxxx6226 debited by rs. 1,500 total bal:...  4.577692   交易流水＿转账
# 19  your a/c no. xxxxxxxxxxx8248 is debited for rs...  4.213027   交易流水＿转账
# 20  hello! your a/c no 60313147 has been credited ...  3.560099   交易流水＿转账
# 21  dear customer, your a/c no. xxxxxxxx9939 is de...  5.573156   交易流水＿转账
# 22  your debit card ending 1471 has been blocked. ...  1.196336   交易流水＿转账
# 23  your fund transfer request for rs. 1000.0 on 2...  3.122385   交易流水＿转账
# 24  you have initiated a txn of inr 415.68 at irct...  4.344860   交易流水＿转账
# 25  your ac xxxxx774561 debited inr 60,000.00 on 3...  3.355263   交易流水＿转账
# 26  hold for inr 10,000.00 created in your ac xxxx...  3.067825   交易流水＿转账
# 27  dear customer, hold has been placed on your ac...  4.709334   交易流水＿转账
# 28  loan of rs. 75000.00 disbursed from loan a/c n...  3.437422   交易流水＿转账
# 29  tds of inr 332.00 deducted for interest paid o...  3.404083   交易流水＿转账
# ..                                                ...       ...       ...
# 70  dear customer, a/c xxx1662 charged rs.600 for ...  3.887988   交易流水＿转账
# 71  ur transaction on hdfc bank credit card ending...  3.290191   交易流水＿转账
# 72  update: inr 25,000.00 debited from a/c xx0830 ...  3.714029   交易流水＿转账
# 73  dear customer.thank you for your recent paymen...  1.378495  信用卡＿还款提醒
# 74  dear customer,we regret to note that payments ...  1.350435  信用卡＿还款提醒
# 75  dear customer, total amount due on credit card...  1.742367   交易流水＿转账
# 76  your a/c xxxxxxx4289 is debited through atm by...  4.678297   交易流水＿转账
# 77  your a/c xxxx8575 debited rs.149000.00 on 19-0...  4.765475   交易流水＿转账
# 78  returned, chq:940102 for rs.15431.00 fvg capit...  1.992944   交易流水＿转账
# 79  your a/c ...162 in credited inr 21000.00 on 21...  3.462333   交易流水＿转账
# 80  dear customer,your loan a/c 1441***121 with io...  2.720026   交易流水＿转账
# 81  dear customer, cheque 995044 for inr 43000 iss...  3.382704   交易流水＿转账
# 82  dear customer,your account xx7410 has been cre...  4.066733   交易流水＿转账
# 83  bank is replacing your existing magstripe debi...  1.787973   交易流水＿转账
# 84  inr 5,400.00 credited to your a/c no xxxxxxx84...  2.758463   交易流水＿转账
# 85  your indusind bank a/c no.200***439985 has bee...  4.376480   交易流水＿转账
# 86  your a/c no. xxxxxxxx862071 is credited by rs....  4.257130   交易流水＿转账
# 87  dear customer - your neft payment with utr bdb...  4.972787   交易流水＿转账
# 88  your a/c no. xxxx914167 is credited rs.3000.00...  5.483266   交易流水＿转账
# 89  transaction of rs 5000 has been made on kotak ...  4.294423   交易流水＿转账
# 90  inr 1.00 is credited to your a/c xxxx9121 on 1...  4.235332   交易流水＿转账
# 91  you have successfully done a vodafone prepaid ...  5.973451   交易流水＿转账
# 92  hello! you have received refund of transaction...  4.080817   交易流水＿转账
# 93  thanks for applying loan through hdb. your loa...  1.056628  信用卡＿还款提醒
# 94  dear customer, emi of rs 3594 of your cd loan ...  1.898740   交易流水＿转账
# 95  your a/c no. xxxxxxxxxxx1608 is debited for rs...  4.632315   交易流水＿转账
# 96  your fund transfer for rs. 6500 on 21-09-18 co...  2.995504   交易流水＿转账
# 97  dear customer, your username avxxxxxh9553 is l...  1.780033   交易流水＿转账
# 98  thanks for rs.4,500.00 received via neft for c...  4.517948   交易流水＿转账
# 99  your debit card 5497xxxxxxxx0600 has been used...  3.257238   交易流水＿转账
#
#         label
# 0     交易流水＿转账
# 1   账号异常＿余额不足
# 2     交易流水＿转账
# 3     交易流水＿转账
# 4     交易流水＿转账
# 5     交易流水＿转账
# 6     交易流水＿转账
# 7     交易流水＿转账
# 8     交易流水＿转账
# 9     交易流水＿转账
# 10    交易流水＿转账
# 11    交易流水＿转账
# 12  账号异常＿卡号冻结
# 13    交易流水＿转账
# 14    交易流水＿转账
# 15    交易流水＿转账
# 16    交易流水＿转账
# 17    交易流水＿转账
# 18    交易流水＿转账
# 19    交易流水＿转账
# 20    交易流水＿转账
# 21    交易流水＿转账
# 22  账号异常＿卡号冻结
# 23  账号异常＿扣款失败
# 24    交易流水＿转账
# 25    交易流水＿转账
# 26    交易流水＿转账
# 27  账号异常＿卡号冻结
# 28  贷后提醒＿到期提醒
# 29    交易流水＿转账
# ..        ...
# 70  sms_other
# 71    交易流水＿转账
# 72    交易流水＿转账
# 73  贷后提醒＿到期提醒
# 74   信用卡＿还款提醒
# 75   信用卡＿还款提醒
# 76    交易流水＿转账
# 77    交易流水＿转账
# 78  sms_other
# 79    交易流水＿转账
# 80  贷后提醒＿逾期催收
# 81  账号异常＿扣款失败
# 82    交易流水＿转账
# 83  账号异常＿卡号冻结
# 84    交易流水＿转账
# 85    交易流水＿转账
# 86    交易流水＿转账
# 87    交易流水＿转账
# 88    交易流水＿转账
# 89    交易流水＿转账
# 90    交易流水＿转账
# 91    交易流水＿转账
# 92    交易流水＿转账
# 93  贷前申请＿申请交互
# 94  贷后提醒＿到期提醒
# 95    交易流水＿转账
# 96  账号异常＿扣款失败
# 97  账号异常＿卡号冻结
# 98    交易流水＿转账
# 99    交易流水＿转账
#
# [100 rows x 4 columns]

# %%
tra_output = graphsage.forward(train)
result(g4, tra_output, train, idx2label)
# Out:
#                                                      sms     score      pred  \
# 0      it's done! we've transfered rs.2 from your acc...  2.704044   交易流水＿转账
# 1      payment overdue on your credit card xx4129 is ...  1.810211  信用卡＿还款提醒
# 2      txn of rs.966.19 made on sbi card xx5453 at am...  1.876180   交易流水＿转账
# 3      dear customer, your transaction decline for de...  2.855015   交易流水＿转账
# 4      your a/c no. xxxx8393 is debited for rs.1.83 o...  4.074343   交易流水＿转账
# 5      dear hdfc bank card member, rs 6.39 has been c...  3.999855   交易流水＿转账
# 6      dear customer, total amount of inr 18120.80 an...  1.551628  信用卡＿还款提醒
# 7      top up of rs.18,503.83 is successfully receive...  5.671163   交易流水＿转账
# 8      dear customer, transaction of rs.282.2 from an...  5.043914   交易流水＿转账
# 9      your a/c xxxx8264 has been credited by rs. 9.5...  4.644256   交易流水＿转账
# 10     your a/c xx0915 is debited with rs. 88.33 on 7...  3.354889   交易流水＿转账
# 11     your a/c no. xxxxxxxx366 is credited by rs.643...  4.803290   交易流水＿转账
# 12     avbl bal for a/c xxxx0328 as on 31-60-8332 is ...  3.148188   交易流水＿转账
# 13     greetings from rbl bank! latest transaction do...  2.695565   交易流水＿转账
# 14     mobile imps transaction of rs 8018.58 to anoop...  5.324256   交易流水＿转账
# 15     your a/c xxxxxxx8642 is debited by rs. 3,327 b...  6.100919   交易流水＿转账
# 16     your a/c no. xxxxxx1713 is credited for rs. 8....  3.358128   交易流水＿转账
# 17     chq no 173893 dt 48-59-28 of your ac no xxxxxx...  3.588377   交易流水＿转账
# 18     payment for your rbl bank credit card is overd...  2.252861   交易流水＿转账
# 19     sep-18 stmt for kotak credit card xxxx6285 has...  1.905354   交易流水＿转账
# 20     dear hdfc bank customer, payment of rs 0029 wa...  3.006023   交易流水＿转账
# 21     dear customer,ecs transaction of rs. 5103 towa...  4.001629   交易流水＿转账
# 22     hi amit bhardwaj, your payment of rs. 193.7 fo...  2.802837   交易流水＿转账
# 23     thank you for using debit card ending 6795 for...  3.860362   交易流水＿转账
# 24     dear customer, total amount of inr 81819.94 an...  1.538942  信用卡＿还款提醒
# 25     your debit card x5214 used on ecom at dream11 ...  3.296205   交易流水＿转账
# 26     your a/c no. xxxxxxxx8103 is debited for rs. 0...  5.145452   交易流水＿转账
# 27     invalid denomination oxitransid payment of rs....  3.505932   交易流水＿转账
# 28     dear moneytap user, statement for your rbl ban...  2.571185   交易流水＿转账
# 29     dear customer, for your citibank a/c ending xx...  3.913748   交易流水＿转账
# ...                                                  ...       ...       ...
# 10870  use 789078 as otp for your loan application at...  2.683998   交易流水＿转账
# 10871  withdrawal of inr 39,287 ac xxx113182 drawn th...  4.479510   交易流水＿转账
# 10872  cheque no 13 for rs.63271 is debited to a/c .....  3.045369   交易流水＿转账
# 10873  rs. 89 deducted as penal charges for fall in m...  3.713236   交易流水＿转账
# 10874  sb/ca accountxxxxxxxxx8292 has gone below mini...  3.564506   交易流水＿转账
# 10875  we have processed your emi request, the transa...  2.532948   交易流水＿转账
# 10876  rs.089 is credited to your a/c xx9222 on 10-09...  4.358974   交易流水＿转账
# 10877  an amount of 03 inr has been debited to a/c no...  4.206563   交易流水＿转账
# 10878  your a/c no. xxxxxxxxx6899 is debited for rs. ...  4.622807   交易流水＿转账
# 10879  dear customer your emi amt overdue of rs 4081 ...  2.403512   交易流水＿转账
# 10880  rs 7531 withdrawn from a/c xxxx 1156 on 040717...  3.702212   交易流水＿转账
# 10881  your a/c xxxxx736632 has a debit by transfer o...  3.093270   交易流水＿转账
# 10882  dear customer, cheque book for your a/c.no. xx...  3.169852   交易流水＿转账
# 10883  thank you for using debit card ending 6843 for...  3.160665   交易流水＿转账
# 10884  successful transfer of rs 2656 to brajesh ar u...  3.162939   交易流水＿转账
# 10885  dear customer, txn of inr 8,410.10 using credi...  4.812858   交易流水＿转账
# 10886  your fund transfer for rs.30.26 on 37-51-36 is...  4.172960   交易流水＿转账
# 10887  you need an otp to confirm mobile no. for icic...  3.770474   交易流水＿转账
# 10888  update: your salary of inr 7,78,094.27 is cred...  3.989988   交易流水＿转账
# 10889  greetings from rbl bank! your nach mandate is ...  3.237433   交易流水＿转账
# 10890  dear customer,for the month of aug-0509 your a...  3.176403   交易流水＿转账
# 10891  transaction of rs 155 has been made on kotak c...  4.564495   交易流水＿转账
# 10892  a charge of rs. 360.11 has been initiated on y...  4.741939   交易流水＿转账
# 10893  rs 2041.69 debited from a/c **9461 on 94-14-29...  4.335785   交易流水＿转账
# 10894  otp for mobile number verification for your hd...  3.684203   交易流水＿转账
# 10895  dear sbi cardholder,payment of rs.18769.59 via...  3.121553   交易流水＿转账
# 10896  dear customer,for the month of aug-6471 your a...  3.290618   交易流水＿转账
# 10897  you have initiated a txn of inr 54.27 at munic...  4.176892   交易流水＿转账
# 10898  you have successfully done a airtel dth rechar...  5.094767   交易流水＿转账
# 10899  your pos claim for rs.9453.34 /- dated 33-50-5...  3.495241   交易流水＿转账
#
#            label
# 0        交易流水＿转账
# 1       信用卡＿还款提醒
# 2      账号异常＿扣款失败
# 3      账号异常＿扣款失败
# 4        交易流水＿转账
# 5        交易流水＿转账
# 6       信用卡＿还款提醒
# 7        交易流水＿转账
# 8        交易流水＿转账
# 9        交易流水＿转账
# 10       交易流水＿转账
# 11       交易流水＿转账
# 12       交易流水＿余额
# 13       交易流水＿转账
# 14       交易流水＿转账
# 15       交易流水＿转账
# 16       交易流水＿转账
# 17       交易流水＿转账
# 18      信用卡＿还款提醒
# 19      信用卡＿还款提醒
# 20       交易流水＿转账
# 21     账号异常＿余额不足
# 22      信用卡＿还款提醒
# 23       交易流水＿转账
# 24      信用卡＿还款提醒
# 25       交易流水＿转账
# 26       交易流水＿转账
# 27       交易流水＿转账
# 28      信用卡＿还款提醒
# 29     sms_other
# ...          ...
# 10870  贷前申请＿申请交互
# 10871    交易流水＿转账
# 10872    交易流水＿转账
# 10873    交易流水＿转账
# 10874    交易流水＿转账
# 10875  sms_other
# 10876    交易流水＿转账
# 10877    交易流水＿转账
# 10878    交易流水＿转账
# 10879  贷后提醒＿逾期催收
# 10880    交易流水＿转账
# 10881    交易流水＿转账
# 10882  sms_other
# 10883    交易流水＿转账
# 10884    交易流水＿转账
# 10885    交易流水＿转账
# 10886    交易流水＿转账
# 10887  贷前申请＿申请交互
# 10888    交易流水＿转账
# 10889    交易流水＿转账
# 10890  账号异常＿余额不足
# 10891    交易流水＿转账
# 10892    交易流水＿转账
# 10893    交易流水＿转账
# 10894  贷前申请＿申请交互
# 10895    交易流水＿转账
# 10896  账号异常＿余额不足
# 10897    交易流水＿转账
# 10898    交易流水＿转账
# 10899    交易流水＿转账
#
# [10900 rows x 4 columns]

# %%
# valid 
Res = pd.DataFrame(columns=['true', 'pred'])

true, pred = get_clf_prediction(model, X_word_val, X_char_val, y_val)

Res['true'] = true
Res['pred'] = pred

entitys = Res.true.unique()
records = []
for i in entitys:
    tmp = evaluate(Res, i)
    records.append(tmp)
record = pd.DataFrame.from_records(records)
record.columns =['cls','精确率','召回率', 'F1', 'support']
record = record.set_index('cls')
record = record.sort_index()
record

# %%
grouped_te = Test_DF.groupby('sent_id').apply(lambda x: [(w.lower(), t) for w,t in zip(x.token.tolist(), x.lable.tolist())])
sentences_te = [s for s in grouped_te]

X_word_te = [[word2idx.get(w[0], word2idx['UNK']) for w in s] for s in sentences_te]
X_word_te = pad_sequences(maxlen=max_len, sequences=X_word_te, value=word2idx['PAD'],padding='post',truncating='post')

X_char_te = get_X_char(sentences_te)
y_te = [[tag2idx[w[1]] for w in s] for s in sentences_te]
y_te = pad_sequences(maxlen=max_len, sequences=y_te, value=tag2idx['other'],padding='post',truncating='post')

# %%
# test
Res = pd.DataFrame(columns=['true', 'pred'])
true, pred = get_prediction(model, X_word_te, X_char_te, y_te)
Res['true'] = true
Res['pred'] = pred

entitys = Res.true.unique()
records = []
for i in entitys:
    tmp = evaluate(Res, i)
    records.append(tmp)
record = pd.DataFrame.from_records(records)
record.columns =['cls','精确率','召回率', 'F1','support']
record = record.set_index('cls')
record = record.sort_index()
record

# %%
grouped_te = Test_DF.groupby('sent_id').apply(lambda x: [(w.lower(), t) for w,t in zip(x.token.tolist(), x.lable.tolist())])
sentences_te = [s for s in grouped_te]

X_word_te = [[word2idx.get(w[0], word2idx['UNK']) for w in s] for s in sentences_te]
X_word_te = pad_sequences(maxlen=max_len, sequences=X_word_te, value=word2idx['PAD'],padding='post',truncating='post')

X_char_te = get_X_char(sentences_te)
y_te = [[tag2idx[w[1]] for w in s] for s in sentences_te]
y_te = pad_sequences(maxlen=max_len, sequences=y_te, value=tag2idx['other'],padding='post',truncating='post')

# %%
gsm_path = 'gsm_templates_df.csv'
gsm_templates_df = pd.read_csv(gsm_path)
gsm_templates_df = gsm_templates_df[~gsm_templates_df.label.isnull()]
print(gsm_templates_df.shape)

# %%
test_100example = gsm_templates_df.sample(n=100)
gsm_templates_df = gsm_templates_df[~gsm_templates_df.index.isin(test_100example.index)]
print(gsm_templates_df.shape)

# %%
def result(G, output, label_idx, idx2label):
    score, pred = output.max(dim=-1)
    sms = [G.node[i]['text'] for i in label_idx]
    df = pd.DataFrame()
    df['sms']= sms
    df['score']=score.data
    df['pred']=[idx2label[i] for i in pred.numpy()]
    df['label']=[g4.node[i]['label'] for i in label_idx]
    return df

# %%
result(g4, val_output, val, idx2label)

# %%
idx2label[np.argmax(graphsage.forward([3]).squeeze(0).data.numpy())]

# %%
def get_clf_prediction(model, X_word, X_char, y):
    print('X shape:{}, y_shape:{}'.format(len(X_word), len(y)))
    y_pred = model.predict([X_word,
                            np.array(X_char).reshape((len(X_char),
                                                         max_len, max_len_char))])
    pred = [idx2label[i] for i in np.argmax(y_pred,axis=-1)]
    true = [idx2label[i] for i in y]
    return true, pred

def get_pr(Res, cls):
    #某类 正确识别数量/该类 总识别数量
    tmp  = Res[Res.true == cls]
    a = sum(tmp.true.values == tmp.pred.values)
    b = Res[Res.pred == cls].shape[0]
    pr = a/b
    return pr

def get_rc(Res, cls):
    #某类 正确识别数量/该类 总数量
    tmp  = Res[Res.true == cls]
    support = tmp.shape[0]
    a = sum(tmp.true.values == tmp.pred.values)
    b = Res[Res.true == cls].shape[0]
    rc = a/b
    return rc,support

def get_f1(pr, rc):
    # f1 = (2*pr*rc)/(pr+rc)
    f1 = (2*pr*rc)/(pr+rc)
    return f1

def evaluate(Res, cls):
    pr = get_pr(Res, cls)
    rc, support = get_rc(Res, cls)
    f1 = get_f1(pr, rc)
    return [cls, pr, rc, f1, support]
