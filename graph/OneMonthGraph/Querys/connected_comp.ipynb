# %%
import requests
import json
import pandas as pd
import numpy as np
from urllib.parse import urljoin
import time
import logging
import csv
from tqdm import tqdm
import glob

GRAPHSQL_URL = "http://192.168.20.241:9000/query/OneMonthNet/"

############################ util functions ############################
def query_graphsql_ori(query_name, para_string):
    remaining_url = "{}?{}".format(query_name, para_string)
    url=urljoin(GRAPHSQL_URL, remaining_url)
    print('query:{}\nparas:{}\nrequest for url: {}'.format(query_name, para_string.split('&'), url))
    print('---------------------------------------------------------------------------------------------------')
    result = requests.get(url)
    result_json = json.loads(result.text)
    return result_json


def query_graphsql(query_name, para_string):
    remaining_url = "{}?{}".format(query_name, para_string)
    url=urljoin(GRAPHSQL_URL, remaining_url)
    st = time.time()
    print('query:{}\nparas:{}\nrequest for url: {}'.format(query_name, para_string.split('&'), url))
    print('---------------------------------------------------------------------------------------------------')
    try:
        result = requests.get(url)
        result_json = json.loads(result.text)
        if result_json['error']:
            logging.error(result_json['message'])
            print('run query failed')
            return None
        print('run query finish, use {} seconds\n\n'.format(time.time() - st))
        return result_json
    except Exception as e:
        print('failed')
        
        
def _update_max_min_date(node_name):
    '''
    get the max & min date for the given node type based on its history update dates;
    para: node_name: 'Device'; check all the node_name type in gsql graph schema: OneMonthNet;
    '''
    query_name = 'update_max_min_date'
    paras = 'node={}'.format(node_name)
    return query_graphsql(query_name, paras)


def _node_cutoff_filter(start_time, end_time, node_type):
    '''
    note that call _update_max_min_date before run this query;
    select those nodes with given node_type exist between start_time and end_time;
    paras:start_time:'2019-06-01 18:42:22'
    paras:end_time:'2019-07-01 18:42:22'
    paras:node_type:'User'; check all the node_name type in gsql graph schema: OneMonthNet;
    '''
    query_name = 'node_cutoff_filter'
    paras = 'start_t={}&end_t={}&node={}'.format(start_time, end_time, node_type) 
    return query_graphsql(query_name, paras)
    
    
########################################################################

# def label_get(start_date):
#     'old version and has been deprecated now, pls use label_get2 query;'
#     query_name = 'label_get'
#     paras = 'start_date={}'.format(start_date) 
#     return query_graphsql(query_name, paras)


def label_get2(start_date, end_date, loanstyle):
    '''
    get loans with the given loanstyle whose fundtime between start_date & end_date;
    paras: start_date: '2019-06-01 00:00:00'
    paras: end_date: '2019-07-01 00:00:00'
    paras: loanstyle: '绿卡30天1期'
    '''
    query_name = 'label_get2'
    paras = 'start_date={}&end_date={}&loan_type={}'.format(start_date, end_date, loanstyle) 
    return query_graphsql(query_name, paras)['results'][0]['loanlabelSHOW']


#1
def reset(node):
    '''
    '''
    query_name = 'reset'
    paras = 'node={}'.format(node) 
    return query_graphsql(query_name, paras)


#2
def pageRank_train(start_t, end_t, node, maxChange, maxIter, damping, query_name):
    '''
    '''
    paras = 'start_t={}&end_t={}&node={}&maxChange={}&maxIter={}&damping={}'.format(start_t, end_t, node, maxChange,maxIter,damping) 
    return query_graphsql(query_name, paras)


#3
def pageRank_appr_files(file_abs_path, query_name):
    '''
    draft 1 for pageRank in cashbus graph; 
    Only works for user-device relationship(single edge type & double vertex type);
    Only output nodes(type: user or device) with pg_score !=0;
    '''
    paras = 'file_path={}'.format(file_abs_path) 
    return query_graphsql(query_name, paras) 

    
def pyG_prepare():
    query_name = 'pyG_pre'
    paras = ''
    return query_graphsql(query_name, paras) 


#2
def connected_comp_train(start_t, end_t, node):
    '''
    res = connected_comp_train('20190517', '20190610', 'PhoneNumber')
    '''
    query_name='conn_comp'
    paras = 'start_t={}&end_t={}&node={}'.format(start_t, end_t, node) 
    return query_graphsql(query_name, paras)


#3
def connected_comp_appr_files(file_abs_path):
    '''
    draft 1 for pageRank in cashbus graph; 
    Only works for user-device relationship(single edge type & double vertex type);
    Only output nodes(type: user or device) with pg_score != 0;
    '''
    paras = 'file_path={}'.format(file_abs_path)
    query_name = 'conn_comp_check'
    return query_graphsql(query_name, paras)


def train(st, et, node_type, reset_bool):
    """
    paras: st: start time of a period, only node within the restriction will be trained and given a pgscore;
    paras: et: end time of the period;
    paras: node_type: determine which nodetype will be trained;
    """
    assert node_type in ["Device", "PhoneNumber"]
    if reset_bool:
        reset(node_type)
    pageRank_train(st, 
                   et, 
                   node_type, 
                   10, 3, 0.6,
                   "pageRank_train_{}".format(node_type.lower()))
    return None


def test_with_local_files(nodetype, file_path):
    """
    paras: node_type: determine which nodetype will be test;
    paras: file_path: only provide a path to save test nodes id;
    """
    test_res2 = pageRank_appr_files(file_path, 
                                    "pageRank_appr_files_{}".format(nodetype.lower()))
    user_pg_res = [i['attributes'] for i in test_res2['results'][0]['test_set']]
    user_pg_df2 = pd.DataFrame.from_dict(user_pg_res)
    user_pg_df2.rename(columns={'prim_id': 'username'}, inplace=True)
    return test_res2, user_pg_df2

# %%
res = connected_comp_train('20190604', '20190610', 'PhoneNumber')
# Out:
# query:conn_comp
# paras:['start_t=20190604', 'end_t=20190610', 'node=PhoneNumber']
# request for url: http://192.168.20.241:9000/query/OneMonthNet/conn_comp?start_t=20190604&end_t=20190610&node=PhoneNumber
# ---------------------------------------------------------------------------------------------------
# run query finish, use 514.5107645988464 seconds

# %%
test_day_file = '/home/tigergraph/GraphProject/OneMonthGraph/Querys/G_algorithm/pagerank/dir_phone/cc_test_{}_{}.txt'.format('2019-06-11 00:00:00', '2019-06-12 00:00:00')

# %%
test_cc = connected_comp_appr_files(test_day_file)
# Out:
# query:conn_comp_check
# paras:['file_path=/home/tigergraph/GraphProject/OneMonthGraph/Querys/G_algorithm/pagerank/dir_phone/cc_test_2019-06-11 00:00:00_2019-06-12 00:00:00.txt']
# request for url: http://192.168.20.241:9000/query/OneMonthNet/conn_comp_check?file_path=/home/tigergraph/GraphProject/OneMonthGraph/Querys/G_algorithm/pagerank/dir_phone/cc_test_2019-06-11 00:00:00_2019-06-12 00:00:00.txt
# ---------------------------------------------------------------------------------------------------
# run query finish, use 0.4313061237335205 seconds

# %%
test_cc['results'][0]['vv']
# Out:
# [{'v_id': '18105972345',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '18105972345',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [29403608,
#     27293586,
#     25213522,
#     24165028,
#     24165026,
#     21019360,
#     0,
#     30456164,
#     11549679]}},
#  {'v_id': '13981682202',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '13981682202',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [28361076, 10485822, 8408556, 0, 19957416]}},
#  {'v_id': '18981847226',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '18981847226',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [0]}},
#  {'v_id': '18065666612',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '18065666612',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [31471524,
#     13645690,
#     30451660,
#     11573300,
#     0,
#     15757155,
#     17873488,
#     24132620]}},
#  {'v_id': '13416964479',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '13416964479',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [31483096,
#     1089671,
#     0,
#     47597,
#     10536208,
#     2121494,
#     17861432,
#     26235764]}},
#  {'v_id': '13826280246',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '13826280246',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [30455496,
#     29407252,
#     29407250,
#     28340424,
#     30455494,
#     0,
#     3170110,
#     6311412,
#     15754502,
#     19969814,
#     26214656]}},
#  {'v_id': '13834799876',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '13834799876',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [25177992, 0]}},
#  {'v_id': '18280168793',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '18280168793',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [8428751,
#     30448636,
#     0,
#     32545904,
#     4220132,
#     5283047,
#     18914830]}},
#  {'v_id': '15959144712',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '15959144712',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [0, 24172332]}},
#  {'v_id': '16607676563',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '16607676563',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [26222350, 26222344, 0]}},
#  {'v_id': '15853995672',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '15853995672',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [0, 16819500]}},
#  {'v_id': '14751918877',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '14751918877',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [0, 10542795, 2768251, 19975638]}},
#  {'v_id': '15002031693',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '15002031693',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [0, 1081438]}},
#  {'v_id': '18867009881',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '18867009881',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [31495376, 0, 1048802, 16815360, 15728843, 23076990]}},
#  {'v_id': '15026724842',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '15026724842',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [0, 3191401, 14731448]}},
#  {'v_id': '15014890796',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '15014890796',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [32548924, 31509614, 0, 12615422, 22079024, 17832144]}},
#  {'v_id': '18476705822',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '18476705822',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [25215560, 0, 10535547, 18924820]}},
#  {'v_id': '15013185142',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '15013185142',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [0]}},
#  {'v_id': '17713567053',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '17713567053',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [24152644, 15764239, 0, 6342890]}},
#  {'v_id': '13413547704',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '13413547704',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [1098449, 0, 12633188, 20996064]}},
#  {'v_id': '15258730092',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '15258730092',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [30464116, 0, 14739025]}},
#  {'v_id': '13221611070',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '13221611070',
#    'datetime_set': [20190614, 20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [0, 13904920]}},
#  {'v_id': '18030822267',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '18030822267',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [31492836,
#     29395820,
#     26225904,
#     21016632,
#     29395816,
#     4229903,
#     18910328,
#     4229900,
#     22069004,
#     0,
#     9441610,
#     10521162,
#     28363100,
#     19958532,
#     18910330,
#     12631237]}},
#  {'v_id': '13318762942',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '13318762942',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [0]}},
#  {'v_id': '18259685235',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '18259685235',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [10492773, 0, 18881748, 5250299, 14687168]}},
#  {'v_id': '18681683388',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '18681683388',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [0]}},
#  {'v_id': '18821715099',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '18821715099',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [5266006, 1054855, 0]}},
#  {'v_id': '13803678748',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '13803678748',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [0]}},
#  {'v_id': '13522378208',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '13522378208',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [0, 4233650, 25217412, 26259416]}},
#  {'v_id': '13767493528',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '13767493528',
#    'datetime_set': [20190527, 20190611],
#    'temp_save_bool': True,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [29368192, 7387608, 35402, 0, 12589237]}},
#  {'v_id': '15151065191',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '15151065191',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [29375328, 0]}},
#  {'v_id': '15984415289',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '15984415289',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [24125256, 0]}},
#  {'v_id': '17614144137',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '17614144137',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [0]}},
#  {'v_id': '17876709912',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '17876709912',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [32550748, 12607060, 0, 25185564]}},
#  {'v_id': '18607073666',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '18607073666',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [0]}},
#  {'v_id': '15195544755',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '15195544755',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [25206916,
#     8420302,
#     7381405,
#     7371482,
#     6306877,
#     0,
#     32546972,
#     12602504,
#     12613703,
#     13637860,
#     13646766,
#     20986796,
#     17866938,
#     18889772]}},
#  {'v_id': '17346545046',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '17346545046',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [30453472, 29373432, 26222516, 21016656, 0]}},
#  {'v_id': '13987586405',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '13987586405',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [0]}},
#  {'v_id': '15327365969',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '15327365969',
#    'datetime_set': [20190520, 20190611],
#    'temp_save_bool': True,
#    'temp_pgscore': 0,
#    'cc_id': 15728849,
#    '@node_cluster_id': [31488782, 29360354, 0, 3177229, 23100420, 25197292]}},
#  {'v_id': '18861771136',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '18861771136',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [0]}},
#  {'v_id': '15154555581',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '15154555581',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [0]}},
#  {'v_id': '18054077798',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '18054077798',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [30444320,
#     25201364,
#     26250136,
#     5278589,
#     2139269,
#     29395892,
#     26265820,
#     22055416,
#     0,
#     18910428]}},
#  {'v_id': '13664376607',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '13664376607',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [9461573, 0]}},
#  {'v_id': '18653461998',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '18653461998',
#    'datetime_set': [20190526, 20190611],
#    'temp_save_bool': True,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [27319456,
#     6346589,
#     30461044,
#     0,
#     9493856,
#     30461904,
#     11550195,
#     12622118,
#     29397594,
#     12638043]}},
#  {'v_id': '18640488478',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '18640488478',
#    'datetime_set': [20190616, 20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [13632014,
#     12632592,
#     7344474,
#     0,
#     4249049,
#     14731923,
#     5259072,
#     17834404,
#     9482323,
#     17850200,
#     5251692,
#     20980264,
#     21021472,
#     22028692,
#     27271708]}},
#  {'v_id': '15119151086',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '15119151086',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [32529078, 0]}},
#  {'v_id': '13646204876',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '13646204876',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [0]}},
#  {'v_id': '18260921971',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '18260921971',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [0]}},
#  {'v_id': '13768325533',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '13768325533',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [0, 597, 14688710]}},
#  {'v_id': '18666215028',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '18666215028',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [0]}},
#  {'v_id': '18083401222',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '18083401222',
#    'datetime_set': [20190530, 20190523, 20190611],
#    'temp_save_bool': True,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [32553726,
#     30456350,
#     1049237,
#     25209576,
#     29408038,
#     24165122,
#     23116834,
#     19948884,
#     18922836,
#     18922832,
#     19970616,
#     18918720,
#     8436509,
#     18916652,
#     17873604,
#     16825132,
#     6339066,
#     19968084,
#     5290960,
#     4228993,
#     26220416,
#     2141079,
#     7388059,
#     0,
#     5290954,
#     3183522,
#     31505078,
#     1095920,
#     8436507,
#     20990932,
#     41044,
#     9481052,
#     6339068,
#     11582444,
#     3165713,
#     11582445,
#     15776481,
#     16813080]}},
#  {'v_id': '13581825920',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '13581825920',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [0]}},
#  {'v_id': '15982488597',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '15982488597',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [0]}},
#  {'v_id': '18506833719',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '18506833719',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [29391712,
#     29388544,
#     6340997,
#     24167040,
#     1063712,
#     17833728,
#     1097773,
#     19970438,
#     0,
#     3161035,
#     3173991,
#     8411739,
#     13673090,
#     25194084,
#     15778381]}},
#  {'v_id': '18677440058',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '18677440058',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [9476972,
#     7352490,
#     0,
#     27263024,
#     17865526,
#     19962594,
#     22035254,
#     9476973,
#     26220156]}},
#  {'v_id': '18668747222',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '18668747222',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [0]}},
#  {'v_id': '18325359568',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '18325359568',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [0]}},
#  {'v_id': '18032423852',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '18032423852',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [7391624, 25194376, 0, 31508620, 5294374, 11585874]}},
#  {'v_id': '15623079616',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '15623079616',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [0, 13674066]}},
#  {'v_id': '13889636258',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '13889636258',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [0]}},
#  {'v_id': '18262959097',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '18262959097',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [0, 16784492]}},
#  {'v_id': '18376703621',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '18376703621',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [54218, 0]}},
#  {'v_id': '13774885339',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '13774885339',
#    'datetime_set': [20190606, 20190611],
#    'temp_save_bool': True,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [31462380, 24125404, 25201174, 23099932, 0]}},
#  {'v_id': '13600673592',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '13600673592',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [2118, 23070922, 0, 26216584]}},
#  {'v_id': '13727696681',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '13727696681',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [28345056, 0, 17876058]}},
#  {'v_id': '18691719535',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '18691719535',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [27297848, 25165872, 22050852, 0, 11586829, 20971558]}},
#  {'v_id': '13691111295',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '13691111295',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [0]}},
#  {'v_id': '15915614667',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '15915614667',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [0, 18921868]}},
#  {'v_id': '15213681591',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '15213681591',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [32529938, 24141076, 0]}},
#  {'v_id': '18957980891',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '18957980891',
#    'datetime_set': [20190612, 20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [13660250,
#     26243158,
#     12641057,
#     11584435,
#     10525768,
#     3161317,
#     0,
#     14708484,
#     14731000,
#     19945360,
#     7399722,
#     6336248,
#     25224372,
#     27294544,
#     18921208,
#     27322924,
#     11585395,
#     4222776,
#     28358068,
#     29382488]}},
#  {'v_id': '15561837357',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '15561837357',
#    'datetime_set': [20190520, 20190611],
#    'temp_save_bool': True,
#    'temp_pgscore': 0,
#    'cc_id': 20971862,
#    '@node_cluster_id': [33089274,
#     28320816,
#     25748880,
#     25733020,
#     10020497,
#     8958264,
#     27319168,
#     0,
#     7912293,
#     16312271,
#     1631374,
#     20506804,
#     23652702,
#     23636888,
#     23652700,
#     18393162,
#     23636886,
#     27271576]}},
#  {'v_id': '15982248948',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '15982248948',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [0, 15779628, 19948796]}},
#  {'v_id': '18726387003',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '18726387003',
#    'datetime_set': [20190528, 20190614, 20190611],
#    'temp_save_bool': True,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [8394122, 0, 4226579, 26240384]}},
#  {'v_id': '18483613818',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '18483613818',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [20990632, 0, 7390052, 49683, 3195484]}},
#  {'v_id': '13554481612',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '13554481612',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [13639682, 0, 14699623]}},
#  {'v_id': '13739792402',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '13739792402',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [0]}},
#  {'v_id': '13607749362',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '13607749362',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [18874452, 0]}},
#  {'v_id': '13532201831',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '13532201831',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [10493455, 0, 23113764]}},
#  {'v_id': '18505932877',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '18505932877',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [0, 15771070]}},
#  {'v_id': '15251832606',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '15251832606',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [27286504, 20979674, 0, 13654976, 15751983]}},
#  {'v_id': '15013402144',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '15013402144',
#    'datetime_set': [20190607, 20190611],
#    'temp_save_bool': True,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [29410536, 26254170, 0]}},
#  {'v_id': '15587507388',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '15587507388',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [0]}},
#  {'v_id': '13724714274',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '13724714274',
#    'datetime_set': [20190518, 20190611],
#    'temp_save_bool': True,
#    'temp_pgscore': 0,
#    'cc_id': 9437290,
#    '@node_cluster_id': [0]}},
#  {'v_id': '13674805189',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '13674805189',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [0, 6321665]}},
#  {'v_id': '17608889585',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '17608889585',
#    'datetime_set': [20190520, 20190613, 20190611],
#    'temp_save_bool': True,
#    'temp_pgscore': 0,
#    'cc_id': 9437365,
#    '@node_cluster_id': [12627570, 0, 32517388, 16822126, 15750963, 21224098]}},
#  {'v_id': '13463009789',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '13463009789',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [30444136,
#     29405020,
#     28317872,
#     0,
#     9472729,
#     12632304,
#     2132717,
#     16826904]}},
#  {'v_id': '15967186514',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '15967186514',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [0]}},
#  {'v_id': '17705501386',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '17705501386',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [0]}},
#  {'v_id': '18379704385',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '18379704385',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [0]}},
#  {'v_id': '13302621555',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '13302621555',
#    'datetime_set': [20190613, 20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [2100868, 15732308, 0, 2100870]}},
#  {'v_id': '18103641819',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '18103641819',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [31468924, 5290876, 0, 9472996, 12627716]}},
#  {'v_id': '13005023767',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '13005023767',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [30409056, 0, 4194624, 14680373]}},
#  {'v_id': '15024567399',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '15024567399',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [32536988, 0]}},
#  {'v_id': '18887029782',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '18887029782',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [7340423, 0, 6291840, 3146082, 32506248, 4194653]}},
#  {'v_id': '15903118855',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '15903118855',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [0]}},
#  {'v_id': '13631177362',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '13631177362',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [0, 3161585, 11574039]}},
#  {'v_id': '13417130716',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '13417130716',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [0]}},
#  {'v_id': '17858863533',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '17858863533',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [29405024, 7346454, 0, 53254, 3173969, 14724634]}},
#  {'v_id': '18955124894',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '18955124894',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [0, 10536771, 29399556, 16812642]}},
#  {'v_id': '17623255182',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '17623255182',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [0, 44687, 23113856]}},
#  {'v_id': '15210462974',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '15210462974',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [32505908,
#     0,
#     16783644,
#     12589222,
#     16799684,
#     19937156,
#     32529872,
#     19946796]}},
#  {'v_id': '13542885382',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '13542885382',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [31504, 0]}},
#  {'v_id': '13790423055',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '13790423055',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [0, 23097210, 30416918, 31515808]}},
#  {'v_id': '15912587974',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '15912587974',
#    'datetime_set': [20190616, 20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [0]}},
#  {'v_id': '18942250444',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '18942250444',
#    'datetime_set': [20190614, 20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [0]}},
#  {'v_id': '13101938368',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '13101938368',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [0]}},
#  {'v_id': '13707952940',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '13707952940',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [0]}},
#  {'v_id': '18072673110',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '18072673110',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [29406480, 28359602, 28320014, 0]}},
#  {'v_id': '13876119705',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '13876119705',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [0, 26273586]}},
#  {'v_id': '18770067649',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '18770067649',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [12631976,
#     11567882,
#     9490661,
#     2097515,
#     0,
#     18930466,
#     23124616,
#     5290940,
#     24168288,
#     25166164,
#     31512930]}},
#  {'v_id': '18710380385',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '18710380385',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [2112718, 0, 18896452, 21023620]}},
#  {'v_id': '15328846996',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '15328846996',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [0, 17857316]}},
#  {'v_id': '15990993846',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '15990993846',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [29368634, 0, 29366588]}},
#  {'v_id': '13450804482',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '13450804482',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [0, 15757363]}},
#  {'v_id': '15112848634',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '15112848634',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [0, 6300254, 22035734]}},
#  {'v_id': '13756124383',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '13756124383',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [0, 15763765]}},
#  {'v_id': '13531205265',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '13531205265',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [0]}},
#  {'v_id': '13689035579',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '13689035579',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [29383996,
#     24126140,
#     19931848,
#     8752,
#     1104557,
#     31469084,
#     6300505,
#     0,
#     15771070,
#     16836348]}},
#  {'v_id': '18679486021',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '18679486021',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [0]}},
#  {'v_id': '15927544251',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '15927544251',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [8422467, 5289311, 1087253, 2122542, 0]}},
#  {'v_id': '18962150515',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '18962150515',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [0]}},
#  {'v_id': '13627304457',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '13627304457',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [16804232, 0, 29417936]}},
#  {'v_id': '13837545180',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '13837545180',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [0, 17857500]}},
#  {'v_id': '18871948916',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '18871948916',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [28326320,
#     27291734,
#     7369053,
#     7369042,
#     0,
#     28347564,
#     2125854,
#     1076973,
#     14718186,
#     21000352]}},
#  {'v_id': '15630663421',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '15630663421',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [0]}},
#  {'v_id': '13332110123',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '13332110123',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [32520612,
#     24133432,
#     21013608,
#     21013604,
#     5284790,
#     0,
#     10527550,
#     11543405]}},
#  {'v_id': '13132288222',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '13132288222',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [32546700,
#     23109940,
#     10486521,
#     23088730,
#     5267549,
#     0,
#     4235193,
#     14720716,
#     27303612,
#     19956492]}},
#  {'v_id': '18228934042',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '18228934042',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [0]}},
#  {'v_id': '15812047530',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '15812047530',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [0, 14694593]}},
#  {'v_id': '13928680814',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '13928680814',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [28357200, 0, 20996216]}},
#  {'v_id': '15007546126',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '15007546126',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [0, 15740957]}},
#  {'v_id': '15200457878',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '15200457878',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [0]}},
#  {'v_id': '15282186336',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '15282186336',
#    'datetime_set': [20190604, 20190611],
#    'temp_save_bool': True,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [26229092, 25222744, 0]}},
#  {'v_id': '13867239857',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '13867239857',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [5301109, 0, 11593245, 28340468, 21000344]}},
#  {'v_id': '13501302155',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '13501302155',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [0]}},
#  {'v_id': '15877561610',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '15877561610',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [32510572,
#     12583342,
#     8389050,
#     0,
#     3150403,
#     5247662,
#     13636136,
#     4194743,
#     19923334]}},
#  {'v_id': '15857916202',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '15857916202',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [32534614, 20996832, 0, 13660354, 16819496]}},
#  {'v_id': '15680502389',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '15680502389',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [0]}},
#  {'v_id': '18900245132',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '18900245132',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [30408716,
#     27304412,
#     26271480,
#     7371026,
#     7346419,
#     0,
#     4249513,
#     3174086,
#     28338622,
#     11577673,
#     13651336,
#     13688966,
#     17880834,
#     8446922,
#     17884036]}},
#  {'v_id': '15970480908',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '15970480908',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [28351788, 0, 22071488]}},
#  {'v_id': '15999895526',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '15999895526',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [7348308, 7348306, 0, 17833976, 23076900]}},
#  {'v_id': '15992299926',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '15992299926',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [0]}},
#  {'v_id': '15108270706',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '15108270706',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [0, 3180231, 10514134]}},
#  {'v_id': '15158490910',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '15158490910',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [4236684, 0, 21002342]}},
#  {'v_id': '13134964345',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '13134964345',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [25174212, 18908120, 4205842, 0]}},
#  {'v_id': '13893731132',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '13893731132',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [24131864, 0, 12636697]}},
#  {'v_id': '18663933560',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '18663933560',
#    'datetime_set': [20190614, 20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [32557212, 0, 24158890, 25201454]}},
#  {'v_id': '13417516742',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '13417516742',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [9487678, 4194410, 0, 1048711, 21022064, 20977444]}},
#  {'v_id': '15024197433',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '15024197433',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [25185542, 0]}},
#  {'v_id': '17680704649',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '17680704649',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [19931278, 0]}},
#  {'v_id': '15135564804',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '15135564804',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [0, 11549826, 15779393]}},
#  {'v_id': '13510704272',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '13510704272',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [5299588, 3174213, 0]}},
#  {'v_id': '15110257999',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '15110257999',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [16811728,
#     4194662,
#     6325910,
#     30443224,
#     6300076,
#     0,
#     12589448,
#     12605107]}},
#  {'v_id': '15883418063',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '15883418063',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [0]}},
#  {'v_id': '15892590721',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '15892590721',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [0]}},
#  {'v_id': '15007147600',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '15007147600',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [1099956, 0, 16814444, 18919756, 25173796]}},
#  {'v_id': '18172382393',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '18172382393',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [5290821, 0]}},
#  {'v_id': '18677208404',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '18677208404',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [23101132, 0, 15728923]}},
#  {'v_id': '18200440988',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '18200440988',
#    'datetime_set': [20190525, 20190611],
#    'temp_save_bool': True,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [28356836, 0, 13647132]}},
#  {'v_id': '15391767688',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '15391767688',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [32557676,
#     32541568,
#     35617,
#     23120852,
#     0,
#     11586419,
#     16822284]}},
#  {'v_id': '13865616209',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '13865616209',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [25217512, 2125925, 31485980, 0, 12611410, 13631881]}},
#  {'v_id': '18785624002',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '18785624002',
#    'datetime_set': [20190610, 20190521, 20190611],
#    'temp_save_bool': True,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [22020552, 0, 21022692, 24119544, 29411304, 32547078]}},
#  {'v_id': '13620563568',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '13620563568',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [32530426, 0]}},
#  {'v_id': '18707401118',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '18707401118',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [26243274, 4250580, 0]}},
#  {'v_id': '15865927960',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '15865927960',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [0]}},
#  {'v_id': '19817551820',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '19817551820',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [0, 13660544, 15645501, 5290030, 24176684]}},
#  {'v_id': '13872118893',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '13872118893',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [23097540,
#     22023058,
#     9459100,
#     6300291,
#     0,
#     23123272,
#     15776426]}},
#  {'v_id': '13798558572',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '13798558572',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [7385133, 4244856, 0]}},
#  {'v_id': '18688851530',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '18688851530',
#    'datetime_set': [20190612, 20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [32557160, 0]}},
#  {'v_id': '18857341001',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '18857341001',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [26243200,
#     22055452,
#     0,
#     2147013,
#     8432131,
#     9472946,
#     1083867,
#     12636896,
#     4251318,
#     14736658]}},
#  {'v_id': '18608524528',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '18608524528',
#    'datetime_set': [20190607, 20190611],
#    'temp_save_bool': True,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [7346538, 0]}},
#  {'v_id': '13543037717',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '13543037717',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [32554448,
#     6348579,
#     29397984,
#     6319772,
#     0,
#     11587500,
#     6332931,
#     19975264]}},
#  {'v_id': '18960062623',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '18960062623',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [0, 4253111, 22028216, 5292095]}},
#  {'v_id': '15942382080',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '15942382080',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [0,
#     4245182,
#     13654004,
#     27269464,
#     14706283,
#     16828102,
#     17841328]}},
#  {'v_id': '13553210030',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '13553210030',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [23113582, 23113516, 1075210, 0, 2141782, 14688199]}},
#  {'v_id': '15935487396',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '15935487396',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [32521298, 0]}},
#  {'v_id': '15888373888',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '15888373888',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [2130494,
#     0,
#     1083858,
#     11570232,
#     24152860,
#     5278606,
#     26250160,
#     32534592]}},
#  {'v_id': '13826022108',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '13826022108',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [32552792,
#     30427924,
#     27309848,
#     29372156,
#     12629614,
#     0,
#     19969728]}},
#  {'v_id': '13727916316',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '13727916316',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [29403292,
#     27279060,
#     0,
#     10536087,
#     31497304,
#     16797344,
#     11579198]}},
#  {'v_id': '15799045260',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '15799045260',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [8389126, 2097641, 0]}},
#  {'v_id': '13713485554',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '13713485554',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [32541310, 31507092, 2105258, 0, 15778879]}},
#  {'v_id': '17755610711',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '17755610711',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [28363042, 8428094, 4240076, 7375942, 0]}},
#  {'v_id': '15343031698',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '15343031698',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [13663199,
#     9468760,
#     3177247,
#     0,
#     22023604,
#     23100436,
#     23100440,
#     24148788,
#     30437048]}},
#  {'v_id': '13567373419',
#   'v_type': 'PhoneNumber',
# ...
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [27291970, 0]}},
#  {'v_id': '15296369646',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '15296369646',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [0, 5294476]}},
#  {'v_id': '13382751920',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '13382751920',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [0]}},
#  {'v_id': '18508524007',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '18508524007',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [26261398, 0]}},
#  {'v_id': '18307762540',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '18307762540',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [0]}},
#  {'v_id': '17754051809',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '17754051809',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [8424494, 0, 16831936, 17880330]}},
#  {'v_id': '18219109910',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '18219109910',
#    'datetime_set': [20190615, 20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [0, 11570509, 16787356]}},
#  {'v_id': '17693639400',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '17693639400',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [0]}},
#  {'v_id': '13975701233',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '13975701233',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [17875754, 11592480, 0, 22049136, 22075820, 24165134]}},
#  {'v_id': '17601279436',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '17601279436',
#    'datetime_set': [20190609, 20190611],
#    'temp_save_bool': True,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [0]}},
#  {'v_id': '15597998466',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '15597998466',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [0]}},
#  {'v_id': '18276482658',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '18276482658',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [0]}},
#  {'v_id': '18270262123',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '18270262123',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [0]}},
#  {'v_id': '13671592773',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '13671592773',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [26215432, 0, 3151297]}},
#  {'v_id': '18797002341',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '18797002341',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [28330288, 0, 17844456, 19923986]}},
#  {'v_id': '13690174919',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '13690174919',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [32565000, 0]}},
#  {'v_id': '15119409308',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '15119409308',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [0, 4223621, 18904156]}},
#  {'v_id': '15058601881',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '15058601881',
#    'datetime_set': [20190609, 20190611],
#    'temp_save_bool': True,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [28328578,
#     10521889,
#     10521400,
#     2133551,
#     2150038,
#     17826936,
#     0,
#     17859664,
#     19936680]}},
#  {'v_id': '18685290773',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '18685290773',
#    'datetime_set': [20190616, 20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [0, 19940224]}},
#  {'v_id': '13755308812',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '13755308812',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [0, 1060452]}},
#  {'v_id': '15170672394',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '15170672394',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [0]}},
#  {'v_id': '18841482277',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '18841482277',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [28333826,
#     10507204,
#     9494245,
#     8445432,
#     8442991,
#     2098864,
#     0,
#     3200512,
#     14736749,
#     18925016,
#     9463817,
#     24139384,
#     25203300]}},
#  {'v_id': '18278328755',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '18278328755',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [32546080, 40094, 9459, 0, 17826860, 24157440]}},
#  {'v_id': '18205279721',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '18205279721',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [0]}},
#  {'v_id': '13923288219',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '13923288219',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [28356492,
#     21010706,
#     17851796,
#     16819126,
#     19975952,
#     9461899,
#     5272441,
#     0,
#     15753339,
#     7360585,
#     31493660,
#     7374340,
#     9488750,
#     9466687,
#     6344223,
#     11576647,
#     12619114,
#     12624693,
#     13641269,
#     13682848]}},
#  {'v_id': '17604606539',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '17604606539',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [0, 11241, 20984394]}},
#  {'v_id': '13299504620',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '13299504620',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [31460382, 0]}},
#  {'v_id': '15271864600',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '15271864600',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [0, 25213784]}},
#  {'v_id': '13998814928',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '13998814928',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [32520840, 11549303, 0, 20986532, 26229504, 29375028]}},
#  {'v_id': '15929991035',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '15929991035',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [0, 16783142, 26267722, 27305884, 28327568, 30440384]}},
#  {'v_id': '13990957345',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '13990957345',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [20986188, 0]}},
#  {'v_id': '13999521819',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '13999521819',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [0, 8389248, 24131944]}},
#  {'v_id': '15357358733',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '15357358733',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [26246238, 0]}},
#  {'v_id': '18845299392',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '18845299392',
#    'datetime_set': [20190601, 20190611],
#    'temp_save_bool': True,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [0]}},
#  {'v_id': '18689884538',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '18689884538',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [32506678,
#     7356694,
#     0,
#     28369546,
#     12583676,
#     12621104,
#     18920256]}},
#  {'v_id': '13822904587',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '13822904587',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [0, 3194752, 11591555]}},
#  {'v_id': '18845260011',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '18845260011',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [0]}},
#  {'v_id': '13267773430',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '13267773430',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [0, 22023892]}},
#  {'v_id': '13961239490',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '13961239490',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [0, 10518044, 13656127]}},
#  {'v_id': '18595589326',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '18595589326',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [0]}},
#  {'v_id': '17868864820',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '17868864820',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [0]}},
#  {'v_id': '17740175660',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '17740175660',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [4214440, 0, 38200, 27300294]}},
#  {'v_id': '15043254103',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '15043254103',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [0]}},
#  {'v_id': '18826849615',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '18826849615',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [23091946,
#     0,
#     5266247,
#     11557576,
#     26231168,
#     8412058,
#     16800532]}},
#  {'v_id': '15167088253',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '15167088253',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [29389136,
#     32541808,
#     23097732,
#     29396176,
#     7369378,
#     24153166,
#     2157297,
#     0,
#     4254186,
#     28340824,
#     12611658,
#     5294474,
#     9472403,
#     12618688,
#     8424773,
#     18910756,
#     19950862,
#     19974192,
#     21000676]}},
#  {'v_id': '13129780585',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '13129780585',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [0]}},
#  {'v_id': '18859139796',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '18859139796',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [0]}},
#  {'v_id': '15911683148',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '15911683148',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [0, 17865972, 23110788, 26256264]}},
#  {'v_id': '13913069599',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '13913069599',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [27279356, 11558850, 0, 12614360, 15760390, 25212124]}},
#  {'v_id': '13578209623',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '13578209623',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [31512300, 31466314, 0, 6320359, 2111722]}},
#  {'v_id': '13934339255',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '13934339255',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [0, 19944892]}},
#  {'v_id': '18683661112',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '18683661112',
#    'datetime_set': [20190518, 20190611],
#    'temp_save_bool': True,
#    'temp_pgscore': 0,
#    'cc_id': 14681622,
#    '@node_cluster_id': [25697304, 0]}},
#  {'v_id': '18388439737',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '18388439737',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [24172618,
#     6346438,
#     4227923,
#     19282,
#     0,
#     9470816,
#     10541074]}},
#  {'v_id': '18784159227',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '18784159227',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [26262424,
#     5294164,
#     2148212,
#     18926004,
#     0,
#     9488285,
#     29411316,
#     12599078,
#     18926008,
#     17842134]}},
#  {'v_id': '18859225473',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '18859225473',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [32562898, 27298866, 0, 11591447, 17882796]}},
#  {'v_id': '13737734267',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '13737734267',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [31506738, 0]}},
#  {'v_id': '13530583917',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '13530583917',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [50234, 0, 10494531, 12588134, 18903720]}},
#  {'v_id': '15270869647',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '15270869647',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [0,
#     4220184,
#     4216204,
#     26262944,
#     12640297,
#     4251672,
#     18875160,
#     18932532,
#     20987792]}},
#  {'v_id': '13835161706',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '13835161706',
#    'datetime_set': [20190612, 20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [0, 15764809]}},
#  {'v_id': '15158798369',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '15158798369',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [32535012, 11563475, 0, 23124626, 24133440]}},
#  {'v_id': '17751562226',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '17751562226',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [0, 17840512]}},
#  {'v_id': '17786468771',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '17786468771',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [32512080,
#     8394833,
#     0,
#     14685889,
#     16783450,
#     16783440,
#     22026172]}},
#  {'v_id': '15964596393',
#   'v_type': 'PhoneNumber',
#   'attributes': {'prim_id': '15964596393',
#    'datetime_set': [20190611],
#    'temp_save_bool': False,
#    'temp_pgscore': 0,
#    'cc_id': 0,
#    '@node_cluster_id': [0]}},
#  ...]

# %%
label1 = pd.read_csv('/data-0/gsm/qb_one_month/loan_label_1_1901_1907.csv')
label2 = pd.read_csv('/data-0/gsm/qb_one_month/loan_label_2_new_1901_1907.csv')
label2.columns = list(label1.columns)+['nouse']
loan_detail_08_09_df = pd.read_csv('/data-0/qibo/Gdata/oneMonth/qb_temp_loan_detail_08_09.csv')
loan_detail_08_09_df.username = loan_detail_08_09_df.username.astype(str)

def test_loan_info(loanstyle, st, et):
    # 给定两个时间范围，给出所在时间内的 funded loan 信息；
    temp1 = label1[(label1.funddate<et)&(label1.funddate>=st)]
    temp2 = label2[(label2.funddate<et)&(label2.funddate>=st)]
    final = temp1.append(temp2)
    if loanstyle == 'all':
        return final
    return final[final.loanstyle == loanstyle]

def source_table(loanstyle, st, et):
    #xiaomajie biao;
    test_funded_loans = loan_detail_08_09_df[(loan_detail_08_09_df.fundtime>=st)&(loan_detail_08_09_df.fundtime<et)]
    #label 表;
    test_label = test_loan_info(loanstyle, st, et)
    #merge;
    table3 = pd.merge(test_funded_loans, test_label, on='loanid')
    return table3

def final_process(source_df, save_path=None):
    ori, RES_phone = test_with_local_files(nodetype = "PhoneNumber", file_path = test_day_file)
    final = pd.merge(source_df, RES_phone, on='username')
    final = final[~final.default_now.isnull()]
    if save_dir is not None:
        final.to_csv(save_path)
    return final

source_df = source_table('绿卡30天1期', test_st, test_et)
# Out:
# -------------------------------------------
# NameError Traceback (most recent call last)
# <ipython-input-17-d841bc5e3981> in <module>()
#      31     return final
#      32
# ---> 33 source_df = source_table('绿卡30天1期', test_st, test_et)
#
# NameError: name 'test_st' is not defined

# %%
test_st='2019-06-11 00:00:00'
test_et='2019-06-12 00:00:00'
save_dir = '/home/tigergraph/GraphProject/OneMonthGraph/Querys/G_algorithm/pagerank/dir_phone/save_df/'
final_save_path = save_dir + "cc_{}_{}.csv".format(test_st, test_et)

####################### test step:   #####################
source_df = source_table('绿卡30天1期', test_st, test_et)

test_day_file = '/home/tigergraph/GraphProject/OneMonthGraph/Querys/G_algorithm/pagerank/dir_phone/cc_test_{}_{}.txt'.format(test_st, test_et)
with open(test_day_file, 'w') as f1:
    csv_out = csv.writer(f1)
    for i in tqdm(source_df.username.unique()):
        csv_out.writerow([i])
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py:6692: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)
# 100%|██████████| 4602/4602 [00:00<00:00, 972157.49it/s]

# %%
results = connected_comp_appr_files(test_day_file)['results'][0]['vv']
# Out:
# query:conn_comp_check
# paras:['file_path=/home/tigergraph/GraphProject/OneMonthGraph/Querys/G_algorithm/pagerank/dir_phone/cc_test_2019-06-11 00:00:00_2019-06-12 00:00:00.txt']
# request for url: http://192.168.20.241:9000/query/OneMonthNet/conn_comp_check?file_path=/home/tigergraph/GraphProject/OneMonthGraph/Querys/G_algorithm/pagerank/dir_phone/cc_test_2019-06-11 00:00:00_2019-06-12 00:00:00.txt
# ---------------------------------------------------------------------------------------------------
# run query finish, use 0.2819373607635498 seconds

# %%
results = [[i['v_id'], i['attributes']['cc_id']] for i in connected_comp_appr_files(test_day_file)['results'][0]['vv']]
# Out:
# query:conn_comp_check
# paras:['file_path=/home/tigergraph/GraphProject/OneMonthGraph/Querys/G_algorithm/pagerank/dir_phone/cc_test_2019-06-11 00:00:00_2019-06-12 00:00:00.txt']
# request for url: http://192.168.20.241:9000/query/OneMonthNet/conn_comp_check?file_path=/home/tigergraph/GraphProject/OneMonthGraph/Querys/G_algorithm/pagerank/dir_phone/cc_test_2019-06-11 00:00:00_2019-06-12 00:00:00.txt
# ---------------------------------------------------------------------------------------------------
# run query finish, use 0.2990140914916992 seconds

# %%
dic = {}
for i in res:
    if i[1] not in dic:
        dic[i[1]]=1
    else:
        dic[i[1]]+=1

# %%
dic
# Out:
# {0: 3654,
#  15728849: 1,
#  27263156: 1,
#  20971862: 1,
#  9437290: 1,
#  26214740: 1,
#  9437365: 1,
#  26214992: 1,
#  4195047: 1,
#  4195696: 1,
#  4196265: 1,
#  24117626: 1,
#  20972292: 1,
#  15729711: 1,
#  16778060: 1,
#  2097831: 1,
#  2097900: 1,
#  24117902: 1,
#  17826590: 1,
#  11535777: 1,
#  27263328: 1,
#  23069412: 1,
#  4720226: 1,
#  11535888: 1,
#  24118898: 1,
#  4724682: 1,
#  12584672: 1,
#  26215708: 1,
#  1049530: 1,
#  4725873: 1,
#  12584742: 1,
#  3147246: 1,
#  4759627: 1,
#  2098240: 1,
#  3147296: 1,
#  16778970: 1,
#  17827344: 1,
#  29362372: 1,
#  16779110: 1,
#  2163: 1,
#  6293254: 1,
#  2768055: 1,
#  22021900: 1,
#  22021920: 1,
#  13632986: 1,
#  25167108: 1,
#  9191799: 1,
#  22022092: 1,
#  1387879: 1,
#  17827504: 1,
#  19924704: 1,
#  3570413: 1,
#  3638895: 1,
#  3676047: 1,
#  3676120: 1,
#  15742009: 1,
#  26216228: 1,
#  26216248: 1,
#  28313588: 1,
#  9438499: 1,
#  5122674: 1,
#  11017423: 1,
#  11538342: 1,
#  16153537: 1,
#  16222511: 1,
#  16223389: 1,
#  26216512: 1,
#  142551: 1,
#  16259027: 1,
#  11051883: 1,
#  11053045: 1,
#  11057601: 1,
#  2630839: 1,
#  2663151: 1,
#  20973848: 1,
#  28313622: 1,
#  567394: 1,
#  16260408: 1,
#  26216692: 1,
#  24152298: 1,
#  24541324: 1,
#  11289397: 1,
#  22074396: 1,
#  24544060: 1,
#  32507872: 1,
#  11843908: 1,
#  24611176: 1,
#  28313754: 1,
#  28313984: 1,
#  11960945: 1,
#  12029030: 1,
#  12054583: 1,
#  12065640: 1,
#  12065668: 1,
#  12066745: 1,
#  12067311: 1,
#  2664080: 1,
#  2664338: 1,
#  24623260: 1,
#  29788268: 1,
#  29854636: 1,
#  29892760: 1,
#  16294672: 1,
#  6861027: 1,
#  6863687: 1,
#  22445700: 1,
#  11415174: 1,
#  26640724: 1,
#  27264822: 1,
#  19931132: 1,
#  14681622: 1,
#  3971536: 1,
#  21502552: 1,
#  19299772: 1,
#  26745194: 1,
#  13147778: 1,
#  13184105: 1,
#  26746480: 1,
#  31458990: 1,
#  2923621: 1,
#  28804956: 1,
#  17271400: 1,
#  3025649: 1,
#  20348152: 1,
#  20488564: 1,
#  20489672: 1,
#  3056625: 1,
#  17272478: 1,
#  17272574: 1,
#  18250736: 1,
#  18318876: 1,
#  18319578: 1,
#  18320012: 1,
#  1478912: 1,
#  7091486: 1,
#  7091805: 1,
#  14195811: 1,
#  14197382: 1,
#  14197694: 1,
#  670271: 1,
#  30312164: 1,
#  21773232: 1,
#  21800840: 1,
#  3876598: 1,
#  19676650: 1,
#  19676746: 1,
#  19676788: 1,
#  19676828: 1,
#  19803200: 1,
#  17363984: 1,
#  25168090: 1,
#  1578818: 1,
#  32930384: 1,
#  1600519: 1,
#  23112688: 1,
#  23562908: 1,
#  23636740: 1,
#  12339731: 1,
#  12340476: 1,
#  27016428: 1,
#  27724036: 1,
#  27756748: 1,
#  15405572: 1,
#  17704546: 1,
#  1614018: 1,
#  27756864: 1,
#  27792862: 1,
#  9861324: 1,
#  9865699: 1,
#  25070468: 1,
#  9964766: 1,
#  33433790: 1,
#  1850543: 1,
#  23871192: 1,
#  13513075: 1,
#  5244693: 1,
#  23871304: 1,
#  23871764: 1,
#  25658632: 1,
#  23873828: 1,
#  25697264: 1,
#  28064314: 1,
#  28064504: 1,
#  15174323: 1,
#  28191290: 1,
#  7764881: 1,
#  15247725: 1,
#  7834846: 1,
#  7908585: 1,
#  25968288: 1,
#  10365122: 1,
#  26092364: 1,
#  5245329: 1,
#  22170524: 1,
#  15607681: 1,
#  31886372: 1,
#  5666847: 1,
#  5667181: 1,
#  5775312: 1,
#  32260124: 1,
#  5776823: 1,
#  6056225: 1,
#  6063872: 1,
#  6170921: 1}

# %%
####################### paras:       #####################
train_st = "2019-05-13 00:00:00"
train_et = "2019-06-12 00:00:00" 
test_st='2019-06-13 00:00:00'
test_et='2019-06-14 00:00:00'
save_dir = '/home/tigergraph/GraphProject/OneMonthGraph/Querys/G_algorithm/pagerank/dir_device/save_df/'
final_save_path = save_dir + "{}_{}.csv".format(test_st, test_et)

####################### train step:  #####################
train(st=train_st, et=train_et, node_type="Device", reset_bool=True)

####################### test step:   #####################
source_df = source_table('绿卡30天1期', test_st, test_et)
test_day_file = '/home/tigergraph/GraphProject/OneMonthGraph/Querys/G_algorithm/pagerank/dir_device/save_test_txt/test_{}_{}.txt'.format(test_st, test_et)
with open(test_day_file, 'w') as f1:
    csv_out = csv.writer(f1)
    for i in tqdm(source_df.username.unique()):
        csv_out.writerow([i])
        
####################### final step:  ######################   
result = final_process(source_df, final_save_path)
